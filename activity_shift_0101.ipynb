# %%
# =========================
# A1 Pairwise (4C2) Full Code
# - Unseen Activity + Seen Subject
# - Train on activity A (all subjects) using windowed samples
# - Test on activity B (all subjects) using windowing inference
# - k_hat / entropy는 "full-trial 1회 forward"로 기록
# - 4C2=6 pairs, BIDIRECTIONAL=True -> 총 12 실험
# - 결과는 마지막에 한 번만 출력
# =========================

import os
import glob
import random
import numpy as np
import pandas as pd

from scipy.ndimage import gaussian_filter1d

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from itertools import combinations


# ---------------------------------------------------------------------
# 1) Strict Seeding
# ---------------------------------------------------------------------
def set_strict_seed(seed: int):
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


# ---------------------------------------------------------------------
# 2) Data Loading
# ---------------------------------------------------------------------
def load_mhealth_dataset(data_dir, target_activities_map, column_names):
    full_dataset = {}
    file_list = sorted(glob.glob(os.path.join(data_dir, "mHealth_subject*.log")))

    if not file_list:
        print(f"[Warning] No mHealth logs found in {data_dir}")
        return {}

    for file_path in file_list:
        file_name = os.path.basename(file_path)
        subj_part = file_name.split('.')[0]
        try:
            subj_id_num = int(''.join(filter(str.isdigit, subj_part)))
            subj_key = f"subject{subj_id_num}"
        except:
            subj_key = subj_part

        try:
            df = pd.read_csv(file_path, sep="\t", header=None)
            df = df.iloc[:, :len(column_names)]
            df.columns = column_names

            subj_data = {}
            for label_code, activity_name in target_activities_map.items():
                activity_df = df[df['activity_id'] == label_code].copy()
                if not activity_df.empty:
                    subj_data[activity_name] = activity_df.drop(columns=['activity_id'])

            full_dataset[subj_key] = subj_data
        except Exception as e:
            print(f"Error loading {file_name}: {e}")
            pass

    return full_dataset


def prepare_trial_list(label_config, full_data, target_map, feature_map):
    trial_list = []
    for subj, act_id, gt_count in label_config:
        act_name = target_map.get(act_id)
        feats = feature_map.get(act_id)

        if subj in full_data and act_name in full_data[subj]:
            raw_df = full_data[subj][act_name][feats]
            raw_np = raw_df.values.astype(np.float32)

            # Z-score (trial-wise)
            mean = raw_np.mean(axis=0)
            std = raw_np.std(axis=0) + 1e-6
            norm_np = (raw_np - mean) / std

            trial_list.append({
                'data': norm_np,              # (T,C)
                'count': float(gt_count),      # trial total count
                'meta': f"{subj}_{act_name}",
                'subj': subj,
                'act_id': act_id,
            })
        else:
            # 데이터가 없으면 skip
            pass

    return trial_list


# ---------------------------------------------------------------------
# 2.5) Windowing
# ---------------------------------------------------------------------
def trial_list_to_windows(trial_list, fs, win_sec=8.0, stride_sec=4.0, drop_last=True):
    """
    TRAIN 전용: trial -> sliding windows
    window 라벨은 trial 평균 rate로부터 생성:
      rate_trial = count_total / total_duration
      count_window = rate_trial * window_duration
    """
    win_len = int(round(win_sec * fs))
    stride = int(round(stride_sec * fs))
    assert win_len > 0 and stride > 0

    windows = []
    for item in trial_list:
        x = item["data"]  # (T,C)
        T = x.shape[0]
        total_count = float(item["count"])
        meta = item["meta"]

        total_dur = max(T / float(fs), 1e-6)
        rate_trial = total_count / total_dur  # reps/s

        if T < win_len:
            win_dur = T / float(fs)
            windows.append({
                "data": x,
                "count": rate_trial * win_dur,
                "meta": f"{meta}__win[0:{T}]",
            })
            continue

        last_start = T - win_len
        starts = list(range(0, last_start + 1, stride))

        for st in starts:
            ed = st + win_len
            win_dur = win_len / float(fs)
            windows.append({
                "data": x[st:ed],
                "count": rate_trial * win_dur,
                "meta": f"{meta}__win[{st}:{ed}]",
            })

        if not drop_last:
            last_st = starts[-1] + stride
            if last_st < T:
                ed = T
                win_dur = (ed - last_st) / float(fs)
                windows.append({
                    "data": x[last_st:ed],
                    "count": rate_trial * win_dur,
                    "meta": f"{meta}__win[{last_st}:{ed}]",
                })

    return windows


def predict_count_by_windowing(model, x_np, fs, win_sec, stride_sec, device, tau=1.0, batch_size=64):
    """
    TEST 전용: trial -> windows inference -> window rate 평균 -> total count
    x_np: (T,C) numpy (정규화된 상태)
    """
    win_len = int(round(win_sec * fs))
    stride = int(round(stride_sec * fs))
    T = x_np.shape[0]
    total_dur = T / float(fs)

    # short trial -> 1회 forward
    if T <= win_len:
        x_tensor = torch.tensor(x_np, dtype=torch.float32).transpose(0, 1).unsqueeze(0).to(device)  # (1,C,T)
        with torch.no_grad():
            rate_hat, _, _, _ = model(x_tensor, mask=None, tau=tau)
        pred_count = float(rate_hat.item() * total_dur)
        return pred_count

    starts = list(range(0, T - win_len + 1, stride))
    windows = np.stack([x_np[st:st + win_len] for st in starts], axis=0)  # (N, win_len, C)
    xw = torch.tensor(windows, dtype=torch.float32).permute(0, 2, 1).to(device)  # (N,C,win_len)

    rates = []
    model.eval()
    with torch.no_grad():
        for i in range(0, xw.shape[0], batch_size):
            xb = xw[i:i + batch_size]
            r_hat, _, _, _ = model(xb, mask=None, tau=tau)
            rates.append(r_hat.detach().cpu().numpy())

    rates = np.concatenate(rates, axis=0)  # (N,)
    rate_mean = float(rates.mean())
    pred_count = rate_mean * total_dur
    return float(pred_count)


# ---------------------------------------------------------------------
# 2.8) Dataset / Collate
# ---------------------------------------------------------------------
class TrialDataset(Dataset):
    def __init__(self, trial_list):
        self.trials = trial_list

    def __len__(self):
        return len(self.trials)

    def __getitem__(self, idx):
        item = self.trials[idx]
        data = torch.tensor(item['data'], dtype=torch.float32).transpose(0, 1)  # (C, T)
        count = torch.tensor(item['count'], dtype=torch.float32)
        return data, count, item['meta']


def collate_variable_length(batch):
    max_len = max([x[0].shape[1] for x in batch])
    C = batch[0][0].shape[0]

    padded_data, masks, counts, metas, lengths = [], [], [], [], []
    for data, count, meta in batch:
        T = data.shape[1]
        lengths.append(T)

        pad_size = max_len - T
        if pad_size > 0:
            pad = torch.zeros(C, pad_size)
            d_padded = torch.cat([data, pad], dim=1)
            mask = torch.cat([torch.ones(T), torch.zeros(pad_size)], dim=0)
        else:
            d_padded = data
            mask = torch.ones(T)

        padded_data.append(d_padded)
        masks.append(mask)
        counts.append(count)
        metas.append(meta)

    return {
        "data": torch.stack(padded_data),         # (B, C, T_max)
        "mask": torch.stack(masks),               # (B, T_max)
        "count": torch.stack(counts),             # (B,)
        "length": torch.tensor(lengths, dtype=torch.float32),  # (B,)
        "meta": metas
    }


# ---------------------------------------------------------------------
# 3) Model
# ---------------------------------------------------------------------
class ManifoldEncoder(nn.Module):
    def __init__(self, input_ch, hidden_dim=128, latent_dim=16):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv1d(input_ch, hidden_dim, 5, padding=2),
            nn.ReLU(),
            nn.Conv1d(hidden_dim, hidden_dim, 5, padding=2),
            nn.ReLU(),
            nn.Conv1d(hidden_dim, latent_dim, 1)
        )

    def forward(self, x):
        z = self.net(x)            # (B,D,T)
        z = z.transpose(1, 2)      # (B,T,D)
        return z


class ManifoldDecoder(nn.Module):
    def __init__(self, latent_dim, hidden_dim, out_ch):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv1d(latent_dim, hidden_dim, 5, padding=2),
            nn.ReLU(),
            nn.Conv1d(hidden_dim, hidden_dim, 5, padding=2),
            nn.ReLU(),
            nn.Conv1d(hidden_dim, out_ch, 1)
        )

    def forward(self, z):
        zt = z.transpose(1, 2)     # (B,D,T)
        x_hat = self.net(zt)       # (B,C,T)
        return x_hat


class MultiRateHead(nn.Module):
    def __init__(self, latent_dim=16, hidden=64, K_max=6):
        super().__init__()
        self.K_max = K_max
        self.net = nn.Sequential(
            nn.Linear(latent_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1 + K_max)  # [amp | phase_logits...]
        )

    def forward(self, z, tau=1.0):
        out = self.net(z)                     # (B,T,1+K)
        amp = F.softplus(out[..., 0])         # (B,T) >=0
        phase_logits = out[..., 1:]           # (B,T,K)
        phase = F.softmax(phase_logits / tau, dim=-1)
        return amp, phase, phase_logits


class KAutoCountModel(nn.Module):
    def __init__(self, input_ch, hidden_dim=128, latent_dim=16, K_max=6):
        super().__init__()
        self.encoder = ManifoldEncoder(input_ch, hidden_dim, latent_dim)
        self.decoder = ManifoldDecoder(latent_dim, hidden_dim, input_ch)
        self.rate_head = MultiRateHead(latent_dim, hidden=hidden_dim, K_max=K_max)
        self._init_weights()

    def _init_weights(self):
        for m in self.modules():
            if isinstance(m, (nn.Conv1d, nn.Linear)):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)

        with torch.no_grad():
            b = self.rate_head.net[-1].bias
            b.zero_()
            b[0].fill_(-2.0)

    @staticmethod
    def _masked_mean_time(x, mask=None, eps=1e-6):
        if mask is None:
            return x.mean(dim=1)
        if x.dim() == 2:
            m = mask.to(dtype=x.dtype, device=x.device)
            return (x * m).sum(dim=1) / (m.sum(dim=1) + eps)
        elif x.dim() == 3:
            m = mask.to(dtype=x.dtype, device=x.device).unsqueeze(-1)
            return (x * m).sum(dim=1) / (m.sum(dim=1) + eps)
        else:
            raise ValueError(f"Unsupported dim for masked mean: {x.dim()}")

    def forward(self, x, mask=None, tau=1.0):
        z = self.encoder(x)              # (B,T,D)
        x_hat = self.decoder(z)          # (B,C,T)

        amp_t, phase_p, phase_logits = self.rate_head(z, tau=tau)
        micro_rate_t = amp_t             # (B,T)

        p_bar = self._masked_mean_time(phase_p, mask)           # (B,K)
        k_hat = 1.0 / (p_bar.pow(2).sum(dim=1) + 1e-6)          # (B,)

        rep_rate_t = micro_rate_t / (k_hat.unsqueeze(1) + 1e-6) # (B,T)
        if mask is not None:
            rep_rate_t = rep_rate_t * mask

        if mask is None:
            avg_rep_rate = rep_rate_t.mean(dim=1)
        else:
            avg_rep_rate = (rep_rate_t * mask).sum(dim=1) / (mask.sum(dim=1) + 1e-6)

        aux = {
            "phase_p": phase_p,          # (B,T,K)
            "rep_rate_t": rep_rate_t,    # (B,T)
            "k_hat": k_hat,              # (B,)
        }
        return avg_rep_rate, z, x_hat, aux


# ---------------------------------------------------------------------
# 4) Loss utils
# ---------------------------------------------------------------------
def masked_recon_mse(x_hat, x, mask, eps=1e-6):
    mask = mask.to(dtype=x.dtype, device=x.device)
    mask_bc = mask.unsqueeze(1)              # (B,1,T)
    se = (x_hat - x) ** 2                    # (B,C,T)
    se = se * mask_bc
    denom = (mask.sum() * x.shape[1]) + eps
    return se.sum() / denom


def temporal_smoothness(v, mask=None, eps=1e-6):
    dv = torch.abs(v[:, 1:] - v[:, :-1])
    if mask is None:
        return dv.mean()
    m = mask[:, 1:] * mask[:, :-1]
    m = m.to(dtype=dv.dtype, device=dv.device)
    return (dv * m).sum() / (m.sum() + eps)


def phase_entropy_loss(phase_p, mask=None, eps=1e-8):
    ent = -(phase_p * (phase_p + eps).log()).sum(dim=-1)  # (B,T)
    if mask is None:
        return ent.mean()
    ent = ent * mask
    return ent.sum() / (mask.sum() + eps)


def effK_usage_loss(phase_p, mask=None, eps=1e-6):
    if mask is None:
        p_bar = phase_p.mean(dim=1)
    else:
        m = mask.to(dtype=phase_p.dtype, device=phase_p.device).unsqueeze(-1)
        p_bar = (phase_p * m).sum(dim=1) / (m.sum(dim=1) + eps)
    effK = 1.0 / (p_bar.pow(2).sum(dim=1) + eps)
    return effK.mean()


def compute_phase_entropy_mean(phase_p_np, eps=1e-8):
    phase_p_np = np.asarray(phase_p_np, dtype=np.float32)  # (T,K)
    ent_t = -(phase_p_np * np.log(phase_p_np + eps)).sum(axis=1)
    return float(ent_t.mean())


# ---------------------------------------------------------------------
# 5) Train
# ---------------------------------------------------------------------
def train_one_epoch(model, loader, optimizer, config, device):
    model.train()
    fs = config["fs"]
    tau = config.get("tau", 1.0)

    lam_recon = config.get("lambda_recon", 1.0)
    lam_smooth = config.get("lambda_smooth", 0.05)
    lam_phase_ent = config.get("lambda_phase_ent", 0.01)
    lam_effk = config.get("lambda_effk", 0.005)

    for batch in loader:
        x = batch["data"].to(device)
        mask = batch["mask"].to(device)
        y_count = batch["count"].to(device)
        length = batch["length"].to(device)

        duration = torch.clamp(length / fs, min=1e-6)
        y_rate = y_count / duration

        optimizer.zero_grad()
        rate_hat, _, x_hat, aux = model(x, mask, tau=tau)

        loss_rate = F.mse_loss(rate_hat, y_rate)
        loss_recon = masked_recon_mse(x_hat, x, mask)
        loss_smooth = temporal_smoothness(aux["rep_rate_t"], mask)
        loss_phase_ent = phase_entropy_loss(aux["phase_p"], mask)
        loss_effk = effK_usage_loss(aux["phase_p"], mask)

        loss = (loss_rate
                + lam_recon * loss_recon
                + lam_smooth * loss_smooth
                + lam_phase_ent * loss_phase_ent
                + lam_effk * loss_effk)

        loss.backward()
        optimizer.step()


# ---------------------------------------------------------------------
# 6) Main (4C2 Pairwise A1)
# ---------------------------------------------------------------------
def main():
    CONFIG = {
        "seed": 42,
        "data_dir": "/content/drive/MyDrive/Colab Notebooks/HAR_data/MHEALTHDATASET",
        "fs": 50,
        "epochs": 100,
        "lr": 5e-4,
        "batch_size": 64,

        # windowing
        "win_sec": 8.0,
        "stride_sec": 4.0,
        "drop_last": True,

        # model
        "hidden_dim": 128,
        "latent_dim": 16,
        "K_max": 6,

        # loss
        "lambda_recon": 1.0,
        "lambda_smooth": 0.05,
        "lambda_phase_ent": 0.01,
        "lambda_effk": 0.0075,

        "tau": 1.0,

        "BIDIRECTIONAL": True,

        "COLUMN_NAMES": [
            'acc_chest_x', 'acc_chest_y', 'acc_chest_z',
            'ecg_1', 'ecg_2',
            'acc_ankle_x', 'acc_ankle_y', 'acc_ankle_z',
            'gyro_ankle_x', 'gyro_ankle_y', 'gyro_ankle_z',
            'mag_ankle_x', 'mag_ankle_y', 'mag_ankle_z',
            'acc_arm_x', 'acc_arm_y', 'acc_arm_z',
            'gyro_arm_x', 'gyro_arm_y', 'gyro_arm_z',
            'mag_arm_x', 'mag_arm_y', 'mag_arm_z',
            'activity_id'
        ],
        "TARGET_ACTIVITIES_MAP": {
            6: 'Waist bends forward',
            7: 'Frontal elevation of arms',
            8: 'Knees bending',
            10: 'Jogging',
            11: 'Running',
            12: 'Jump front & back'
        },

        # ✅ 모든 activity에서 동일 feature list여야 pairwise 전이가 깔끔함(입력차원 고정)
        "ACT_FEATURE_MAP": {
            6: ['acc_chest_x', 'acc_chest_y', 'acc_chest_z',
                'acc_ankle_x', 'acc_ankle_y', 'acc_ankle_z',
                'gyro_ankle_x', 'gyro_ankle_y', 'gyro_ankle_z',
                'acc_arm_x', 'acc_arm_y', 'acc_arm_z',
                'gyro_arm_x', 'gyro_arm_y', 'gyro_arm_z'],
            7: ['acc_chest_x', 'acc_chest_y', 'acc_chest_z',
                'acc_ankle_x', 'acc_ankle_y', 'acc_ankle_z',
                'gyro_ankle_x', 'gyro_ankle_y', 'gyro_ankle_z',
                'acc_arm_x', 'acc_arm_y', 'acc_arm_z',
                'gyro_arm_x', 'gyro_arm_y', 'gyro_arm_z'],
            8: ['acc_chest_x', 'acc_chest_y', 'acc_chest_z',
                'acc_ankle_x', 'acc_ankle_y', 'acc_ankle_z',
                'gyro_ankle_x', 'gyro_ankle_y', 'gyro_ankle_z',
                'acc_arm_x', 'acc_arm_y', 'acc_arm_z',
                'gyro_arm_x', 'gyro_arm_y', 'gyro_arm_z'],
            10: ['acc_chest_x', 'acc_chest_y', 'acc_chest_z',
                'acc_ankle_x', 'acc_ankle_y', 'acc_ankle_z',
                'gyro_ankle_x', 'gyro_ankle_y', 'gyro_ankle_z',
                'acc_arm_x', 'acc_arm_y', 'acc_arm_z',
                'gyro_arm_x', 'gyro_arm_y', 'gyro_arm_z'],
            11: ['acc_chest_x', 'acc_chest_y', 'acc_chest_z',
                'acc_ankle_x', 'acc_ankle_y', 'acc_ankle_z',
                'gyro_ankle_x', 'gyro_ankle_y', 'gyro_ankle_z',
                'acc_arm_x', 'acc_arm_y', 'acc_arm_z',
                'gyro_arm_x', 'gyro_arm_y', 'gyro_arm_z'],
            12: ['acc_chest_x', 'acc_chest_y', 'acc_chest_z',
                 'acc_ankle_x', 'acc_ankle_y', 'acc_ankle_z',
                 'gyro_ankle_x', 'gyro_ankle_y', 'gyro_ankle_z',
                 'acc_arm_x', 'acc_arm_y', 'acc_arm_z',
                 'gyro_arm_x', 'gyro_arm_y', 'gyro_arm_z'],
        },

        # COUNT_TABLE[act_id][subject] = GT count
        "COUNT_TABLE": {
            6: {
                "subject1": 21, "subject2": 19, "subject3": 21, "subject4": 20, "subject5": 20,
                "subject6": 20, "subject7": 20, "subject8": 21, "subject9": 21, "subject10": 20,
            },
            7: {
                "subject1": 20, "subject2": 20, "subject3": 20, "subject4": 20, "subject5": 20,
                "subject6": 20, "subject7": 20, "subject8": 19, "subject9": 19, "subject10": 20,
            },
            8: {
                "subject1": 20, "subject2": 21, "subject3": 21, "subject4": 19, "subject5": 20,
                "subject6": 20, "subject7": 21, "subject8": 21, "subject9": 21, "subject10": 21,
            },
            10: {
                "subject1": 157, "subject2": 161, "subject3": 154, "subject4": 154, "subject5": 160,
                "subject6": 156, "subject7": 153, "subject8": 160, "subject9": 166, "subject10": 156,
            },
            11: {
                "subject1": 165, "subject2": 158, "subject3": 174, "subject4": 163, "subject5": 157,
                "subject6": 172, "subject7": 149, "subject8": 166, "subject9": 174, "subject10": 172,
            },
            12: {
                "subject1": 20, "subject2": 22, "subject3": 21, "subject4": 21, "subject5": 20,
                "subject6": 21, "subject7": 19, "subject8": 20, "subject9": 20, "subject10": 20,
            },
        }
    }

    # -----------------------------
    # sanity: feature 동일성 체크
    # -----------------------------
    feats_ref = None
    for act_id, feats in CONFIG["ACT_FEATURE_MAP"].items():
        if feats_ref is None:
            feats_ref = tuple(feats)
        elif tuple(feats) != feats_ref:
            raise ValueError(f"[ERROR] ACT_FEATURE_MAP must be identical across activities. mismatch at act_id={act_id}")

    set_strict_seed(CONFIG["seed"])
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    full_data = load_mhealth_dataset(CONFIG["data_dir"], CONFIG["TARGET_ACTIVITIES_MAP"], CONFIG["COLUMN_NAMES"])
    if not full_data:
        print("[ERROR] dataset load failed")
        return

    subjects = [f"subject{i}" for i in range(1, 11)]
    act_ids = sorted(list(CONFIG["TARGET_ACTIVITIES_MAP"].keys()))  # 4 activities
    pairs = list(combinations(act_ids, 2))  # 4C2 = 6

    # 실험 방향 리스트(6 or 12)
    exp_dirs = []
    for a, b in pairs:
        exp_dirs.append((a, b))
        if CONFIG["BIDIRECTIONAL"]:
            exp_dirs.append((b, a))

    # 결과 저장(마지막에 한 번에 출력)
    final_blocks = []
    exp_idx = 0

    def build_labels(act_id):
        labels = []
        for s in subjects:
            if act_id not in CONFIG["COUNT_TABLE"]:
                continue
            if s not in CONFIG["COUNT_TABLE"][act_id]:
                continue
            labels.append((s, act_id, CONFIG["COUNT_TABLE"][act_id][s]))
        return labels

    for train_act, test_act in exp_dirs:
        # COUNT_TABLE 누락이면 해당 실험 skip (전 조합 원하면 반드시 채워야 함)
        train_labels = build_labels(train_act)
        test_labels  = build_labels(test_act)

        if len(train_labels) == 0 or len(test_labels) == 0:
            # skip silently (원하면 아래 print로 바꿔도 됨)
            continue

        # seed per experiment
        set_strict_seed(CONFIG["seed"])

        # trial-level
        train_trials = prepare_trial_list(train_labels, full_data, CONFIG["TARGET_ACTIVITIES_MAP"], CONFIG["ACT_FEATURE_MAP"])
        test_trials  = prepare_trial_list(test_labels,  full_data, CONFIG["TARGET_ACTIVITIES_MAP"], CONFIG["ACT_FEATURE_MAP"])

        if len(train_trials) == 0 or len(test_trials) == 0:
            continue

        # train -> windows
        train_windows = trial_list_to_windows(
            train_trials,
            fs=CONFIG["fs"],
            win_sec=CONFIG["win_sec"],
            stride_sec=CONFIG["stride_sec"],
            drop_last=CONFIG["drop_last"]
        )
        if len(train_windows) == 0:
            continue

        g = torch.Generator()
        g.manual_seed(CONFIG["seed"])
        train_loader = DataLoader(
            TrialDataset(train_windows),
            batch_size=CONFIG["batch_size"],
            shuffle=True,
            collate_fn=collate_variable_length,
            generator=g,
            num_workers=0
        )

        input_ch = train_windows[0]["data"].shape[1]
        model = KAutoCountModel(
            input_ch=input_ch,
            hidden_dim=CONFIG["hidden_dim"],
            latent_dim=CONFIG["latent_dim"],
            K_max=CONFIG["K_max"]
        ).to(device)

        optimizer = torch.optim.Adam(model.parameters(), lr=CONFIG["lr"])
        scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.5)

        # ------------------
        # train (no prints)
        # ------------------
        for epoch in range(CONFIG["epochs"]):
            train_one_epoch(model, train_loader, optimizer, CONFIG, device)
            scheduler.step()

        model.eval()

        # ------------------
        # test (all subjects)
        # ------------------
        exp_idx += 1
        train_name = CONFIG["TARGET_ACTIVITIES_MAP"][train_act]
        test_name = CONFIG["TARGET_ACTIVITIES_MAP"][test_act]

        block_lines = []
        abs_errs = []

        for item in test_trials:
            subj = item["subj"]
            x_np = item["data"]  # (T,C)
            gt = float(item["count"])

            # windowing inference for count
            pred = predict_count_by_windowing(
                model,
                x_np=x_np,
                fs=CONFIG["fs"],
                win_sec=CONFIG["win_sec"],
                stride_sec=CONFIG["stride_sec"],
                device=device,
                tau=CONFIG.get("tau", 1.0),
                batch_size=CONFIG.get("batch_size", 64)
            )
            diff = pred - gt
            abs_errs.append(abs(diff))

            # full-trial forward for k_hat & entropy
            x_tensor = torch.tensor(x_np, dtype=torch.float32).transpose(0, 1).unsqueeze(0).to(device)
            with torch.no_grad():
                _, _, _, aux = model(x_tensor, mask=None, tau=CONFIG.get("tau", 1.0))

            phase_p = aux["phase_p"].squeeze(0).detach().cpu().numpy()  # (T,K)
            k_hat = float(aux["k_hat"].item())
            ent = compute_phase_entropy_mean(phase_p)

            # requested format
            line = (f"{subj} | GT={gt:.0f} | Pred(win)={pred:.2f} | Diff={diff:+.2f} | "
                    f"k_hat(full)={k_hat:.2f} | phase_entropy(full)={ent:.3f}")
            block_lines.append(line)

        mae = float(np.mean(abs_errs)) if len(abs_errs) > 0 else float("nan")

        final_blocks.append({
            "idx": exp_idx,
            "title": f"{train_name} -> {test_name}",
            "lines": block_lines,
            "mae": mae
        })

    # -----------------------------
    # print ONCE at the end
    # -----------------------------
    print("\n" + "=" * 110)
    print("A1 Pairwise Activity Transfer Results (4C2 pairs, windowing inference)")
    print("=" * 110)

    if len(final_blocks) == 0:
        print("[No results] COUNT_TABLE이 충분히 채워졌는지 확인해줘. (7/8/12도 subject1~10 GT 필요)")
        print("=" * 110)
        return

    for b in final_blocks:
        print(f"\n{b['idx']}. {b['title']}  |  MAE={b['mae']:.3f}")
        for ln in b["lines"]:
            print(ln)

    maes = [b["mae"] for b in final_blocks if np.isfinite(b["mae"])]
    if len(maes) > 0:
        print("\n" + "-" * 110)
        print(f"Overall Avg MAE={float(np.mean(maes)):.3f} | Std={float(np.std(maes)):.3f} | #experiments={len(maes)}")
        print("-" * 110)

    print("=" * 110)


if __name__ == "__main__":
    main()
# Out:
# ==============================================================================================================
# A1 Pairwise Activity Transfer Results (4C2 pairs, windowing inference)
# ==============================================================================================================
#
# 1. Waist bends forward -> Frontal elevation of arms  |  MAE=6.116
# subject1 | GT=20 | Pred(win)=28.56 | Diff=+8.56 | k_hat(full)=1.01 | phase_entropy(full)=0.037
# subject2 | GT=20 | Pred(win)=28.16 | Diff=+8.16 | k_hat(full)=1.04 | phase_entropy(full)=0.095
# subject3 | GT=20 | Pred(win)=24.36 | Diff=+4.36 | k_hat(full)=1.03 | phase_entropy(full)=0.064
# subject4 | GT=20 | Pred(win)=27.53 | Diff=+7.53 | k_hat(full)=1.02 | phase_entropy(full)=0.043
# subject5 | GT=20 | Pred(win)=24.78 | Diff=+4.78 | k_hat(full)=1.02 | phase_entropy(full)=0.049
# subject6 | GT=20 | Pred(win)=16.36 | Diff=-3.64 | k_hat(full)=1.01 | phase_entropy(full)=0.029
# subject7 | GT=20 | Pred(win)=20.95 | Diff=+0.95 | k_hat(full)=1.02 | phase_entropy(full)=0.045
# subject8 | GT=19 | Pred(win)=33.71 | Diff=+14.71 | k_hat(full)=1.01 | phase_entropy(full)=0.034
# subject9 | GT=19 | Pred(win)=26.44 | Diff=+7.44 | k_hat(full)=1.01 | phase_entropy(full)=0.037
# subject10 | GT=20 | Pred(win)=21.04 | Diff=+1.04 | k_hat(full)=1.01 | phase_entropy(full)=0.038
#
# 2. Frontal elevation of arms -> Waist bends forward  |  MAE=3.490
# subject1 | GT=21 | Pred(win)=17.20 | Diff=-3.80 | k_hat(full)=1.00 | phase_entropy(full)=0.014
# subject2 | GT=19 | Pred(win)=21.18 | Diff=+2.18 | k_hat(full)=1.02 | phase_entropy(full)=0.048
# subject3 | GT=21 | Pred(win)=22.41 | Diff=+1.41 | k_hat(full)=1.01 | phase_entropy(full)=0.025
# subject4 | GT=20 | Pred(win)=22.12 | Diff=+2.12 | k_hat(full)=1.01 | phase_entropy(full)=0.032
# subject5 | GT=20 | Pred(win)=17.96 | Diff=-2.04 | k_hat(full)=1.00 | phase_entropy(full)=0.016
# subject6 | GT=20 | Pred(win)=14.14 | Diff=-5.86 | k_hat(full)=1.01 | phase_entropy(full)=0.023
# subject7 | GT=20 | Pred(win)=19.13 | Diff=-0.87 | k_hat(full)=1.02 | phase_entropy(full)=0.044
# subject8 | GT=21 | Pred(win)=15.64 | Diff=-5.36 | k_hat(full)=1.01 | phase_entropy(full)=0.020
# subject9 | GT=21 | Pred(win)=14.62 | Diff=-6.38 | k_hat(full)=1.01 | phase_entropy(full)=0.026
# subject10 | GT=20 | Pred(win)=15.11 | Diff=-4.89 | k_hat(full)=1.03 | phase_entropy(full)=0.072
#
# 3. Waist bends forward -> Knees bending  |  MAE=4.536
# subject1 | GT=20 | Pred(win)=28.70 | Diff=+8.70 | k_hat(full)=1.01 | phase_entropy(full)=0.024
# subject2 | GT=21 | Pred(win)=23.65 | Diff=+2.65 | k_hat(full)=1.02 | phase_entropy(full)=0.042
# subject3 | GT=21 | Pred(win)=28.59 | Diff=+7.59 | k_hat(full)=1.01 | phase_entropy(full)=0.028
# subject4 | GT=19 | Pred(win)=29.33 | Diff=+10.33 | k_hat(full)=1.01 | phase_entropy(full)=0.034
# subject5 | GT=20 | Pred(win)=25.35 | Diff=+5.35 | k_hat(full)=1.01 | phase_entropy(full)=0.022
# subject6 | GT=20 | Pred(win)=22.68 | Diff=+2.68 | k_hat(full)=1.00 | phase_entropy(full)=0.010
# subject7 | GT=21 | Pred(win)=19.19 | Diff=-1.81 | k_hat(full)=1.02 | phase_entropy(full)=0.060
# subject8 | GT=21 | Pred(win)=23.34 | Diff=+2.34 | k_hat(full)=1.01 | phase_entropy(full)=0.038
# subject9 | GT=21 | Pred(win)=20.75 | Diff=-0.25 | k_hat(full)=1.02 | phase_entropy(full)=0.046
# subject10 | GT=21 | Pred(win)=17.34 | Diff=-3.66 | k_hat(full)=1.03 | phase_entropy(full)=0.072
#
# 4. Knees bending -> Waist bends forward  |  MAE=5.713
# subject1 | GT=21 | Pred(win)=13.80 | Diff=-7.20 | k_hat(full)=1.02 | phase_entropy(full)=0.055
# subject2 | GT=19 | Pred(win)=17.36 | Diff=-1.64 | k_hat(full)=1.02 | phase_entropy(full)=0.047
# subject3 | GT=21 | Pred(win)=18.19 | Diff=-2.81 | k_hat(full)=1.01 | phase_entropy(full)=0.039
# subject4 | GT=20 | Pred(win)=17.08 | Diff=-2.92 | k_hat(full)=1.01 | phase_entropy(full)=0.036
# subject5 | GT=20 | Pred(win)=12.85 | Diff=-7.15 | k_hat(full)=1.02 | phase_entropy(full)=0.051
# subject6 | GT=20 | Pred(win)=13.23 | Diff=-6.77 | k_hat(full)=1.01 | phase_entropy(full)=0.026
# subject7 | GT=20 | Pred(win)=16.78 | Diff=-3.22 | k_hat(full)=1.01 | phase_entropy(full)=0.040
# subject8 | GT=21 | Pred(win)=9.75 | Diff=-11.25 | k_hat(full)=1.02 | phase_entropy(full)=0.045
# subject9 | GT=21 | Pred(win)=11.63 | Diff=-9.37 | k_hat(full)=1.02 | phase_entropy(full)=0.050
# subject10 | GT=20 | Pred(win)=15.19 | Diff=-4.81 | k_hat(full)=1.01 | phase_entropy(full)=0.037
#
# 5. Waist bends forward -> Jogging  |  MAE=129.731
# subject1 | GT=157 | Pred(win)=26.76 | Diff=-130.24 | k_hat(full)=1.01 | phase_entropy(full)=0.030
# subject2 | GT=161 | Pred(win)=28.82 | Diff=-132.18 | k_hat(full)=1.01 | phase_entropy(full)=0.019
# subject3 | GT=154 | Pred(win)=26.69 | Diff=-127.31 | k_hat(full)=1.01 | phase_entropy(full)=0.033
# subject4 | GT=154 | Pred(win)=27.18 | Diff=-126.82 | k_hat(full)=1.01 | phase_entropy(full)=0.034
# subject5 | GT=160 | Pred(win)=25.97 | Diff=-134.03 | k_hat(full)=1.01 | phase_entropy(full)=0.025
# subject6 | GT=156 | Pred(win)=33.35 | Diff=-122.65 | k_hat(full)=1.01 | phase_entropy(full)=0.031
# subject7 | GT=153 | Pred(win)=26.38 | Diff=-126.62 | k_hat(full)=1.01 | phase_entropy(full)=0.034
# subject8 | GT=160 | Pred(win)=26.03 | Diff=-133.97 | k_hat(full)=1.01 | phase_entropy(full)=0.030
# subject9 | GT=166 | Pred(win)=28.21 | Diff=-137.79 | k_hat(full)=1.01 | phase_entropy(full)=0.027
# subject10 | GT=156 | Pred(win)=30.30 | Diff=-125.70 | k_hat(full)=1.01 | phase_entropy(full)=0.032
#
# 6. Jogging -> Waist bends forward  |  MAE=101.476
# subject1 | GT=21 | Pred(win)=118.67 | Diff=+97.67 | k_hat(full)=1.14 | phase_entropy(full)=0.229
# subject2 | GT=19 | Pred(win)=147.58 | Diff=+128.58 | k_hat(full)=1.26 | phase_entropy(full)=0.315
# subject3 | GT=21 | Pred(win)=162.43 | Diff=+141.43 | k_hat(full)=1.12 | phase_entropy(full)=0.220
# subject4 | GT=20 | Pred(win)=150.98 | Diff=+130.98 | k_hat(full)=1.19 | phase_entropy(full)=0.291
# subject5 | GT=20 | Pred(win)=109.51 | Diff=+89.51 | k_hat(full)=1.20 | phase_entropy(full)=0.260
# subject6 | GT=20 | Pred(win)=102.99 | Diff=+82.99 | k_hat(full)=1.23 | phase_entropy(full)=0.303
# subject7 | GT=20 | Pred(win)=122.76 | Diff=+102.76 | k_hat(full)=1.27 | phase_entropy(full)=0.361
# subject8 | GT=21 | Pred(win)=93.87 | Diff=+72.87 | k_hat(full)=1.17 | phase_entropy(full)=0.267
# subject9 | GT=21 | Pred(win)=123.33 | Diff=+102.33 | k_hat(full)=1.19 | phase_entropy(full)=0.294
# subject10 | GT=20 | Pred(win)=85.65 | Diff=+65.65 | k_hat(full)=1.45 | phase_entropy(full)=0.427
#
# 7. Waist bends forward -> Running  |  MAE=137.258
# subject1 | GT=165 | Pred(win)=24.68 | Diff=-140.32 | k_hat(full)=1.02 | phase_entropy(full)=0.037
# subject2 | GT=158 | Pred(win)=28.37 | Diff=-129.63 | k_hat(full)=1.01 | phase_entropy(full)=0.024
# subject3 | GT=174 | Pred(win)=27.77 | Diff=-146.23 | k_hat(full)=1.03 | phase_entropy(full)=0.051
# subject4 | GT=163 | Pred(win)=29.30 | Diff=-133.70 | k_hat(full)=1.02 | phase_entropy(full)=0.054
# subject5 | GT=157 | Pred(win)=28.69 | Diff=-128.31 | k_hat(full)=1.02 | phase_entropy(full)=0.047
# subject6 | GT=172 | Pred(win)=27.14 | Diff=-144.86 | k_hat(full)=1.01 | phase_entropy(full)=0.023
# subject7 | GT=149 | Pred(win)=28.90 | Diff=-120.10 | k_hat(full)=1.01 | phase_entropy(full)=0.028
# subject8 | GT=166 | Pred(win)=24.97 | Diff=-141.03 | k_hat(full)=1.01 | phase_entropy(full)=0.033
# subject9 | GT=174 | Pred(win)=27.27 | Diff=-146.73 | k_hat(full)=1.03 | phase_entropy(full)=0.059
# subject10 | GT=172 | Pred(win)=30.32 | Diff=-141.68 | k_hat(full)=1.01 | phase_entropy(full)=0.027
#
# 8. Running -> Waist bends forward  |  MAE=125.013
# subject1 | GT=21 | Pred(win)=149.24 | Diff=+128.24 | k_hat(full)=1.65 | phase_entropy(full)=0.488
# subject2 | GT=19 | Pred(win)=167.45 | Diff=+148.45 | k_hat(full)=1.76 | phase_entropy(full)=0.374
# subject3 | GT=21 | Pred(win)=189.23 | Diff=+168.23 | k_hat(full)=1.43 | phase_entropy(full)=0.447
# subject4 | GT=20 | Pred(win)=167.73 | Diff=+147.73 | k_hat(full)=1.75 | phase_entropy(full)=0.465
# subject5 | GT=20 | Pred(win)=145.16 | Diff=+125.16 | k_hat(full)=1.59 | phase_entropy(full)=0.413
# subject6 | GT=20 | Pred(win)=113.93 | Diff=+93.93 | k_hat(full)=1.82 | phase_entropy(full)=0.420
# subject7 | GT=20 | Pred(win)=169.25 | Diff=+149.25 | k_hat(full)=1.66 | phase_entropy(full)=0.475
# subject8 | GT=21 | Pred(win)=123.65 | Diff=+102.65 | k_hat(full)=1.55 | phase_entropy(full)=0.456
# subject9 | GT=21 | Pred(win)=124.03 | Diff=+103.03 | k_hat(full)=1.81 | phase_entropy(full)=0.385
# subject10 | GT=20 | Pred(win)=103.47 | Diff=+83.47 | k_hat(full)=2.02 | phase_entropy(full)=0.418
#
# 9. Waist bends forward -> Jump front & back  |  MAE=11.469
# subject1 | GT=20 | Pred(win)=9.63 | Diff=-10.37 | k_hat(full)=1.02 | phase_entropy(full)=0.047
# subject2 | GT=22 | Pred(win)=8.47 | Diff=-13.53 | k_hat(full)=1.01 | phase_entropy(full)=0.027
# subject3 | GT=21 | Pred(win)=9.38 | Diff=-11.62 | k_hat(full)=1.01 | phase_entropy(full)=0.022
# subject4 | GT=21 | Pred(win)=9.25 | Diff=-11.75 | k_hat(full)=1.01 | phase_entropy(full)=0.033
# subject5 | GT=20 | Pred(win)=7.79 | Diff=-12.21 | k_hat(full)=1.03 | phase_entropy(full)=0.067
# subject6 | GT=21 | Pred(win)=9.21 | Diff=-11.79 | k_hat(full)=1.01 | phase_entropy(full)=0.027
# subject7 | GT=19 | Pred(win)=8.88 | Diff=-10.12 | k_hat(full)=1.01 | phase_entropy(full)=0.032
# subject8 | GT=20 | Pred(win)=8.11 | Diff=-11.89 | k_hat(full)=1.01 | phase_entropy(full)=0.025
# subject9 | GT=20 | Pred(win)=8.96 | Diff=-11.04 | k_hat(full)=1.02 | phase_entropy(full)=0.047
# subject10 | GT=20 | Pred(win)=9.63 | Diff=-10.37 | k_hat(full)=1.01 | phase_entropy(full)=0.024
#
# 10. Jump front & back -> Waist bends forward  |  MAE=30.594
# subject1 | GT=21 | Pred(win)=46.24 | Diff=+25.24 | k_hat(full)=2.02 | phase_entropy(full)=0.787
# subject2 | GT=19 | Pred(win)=65.07 | Diff=+46.07 | k_hat(full)=2.21 | phase_entropy(full)=0.882
# subject3 | GT=21 | Pred(win)=69.25 | Diff=+48.25 | k_hat(full)=1.99 | phase_entropy(full)=0.910
# subject4 | GT=20 | Pred(win)=63.47 | Diff=+43.47 | k_hat(full)=2.38 | phase_entropy(full)=0.961
# subject5 | GT=20 | Pred(win)=52.16 | Diff=+32.16 | k_hat(full)=2.09 | phase_entropy(full)=0.811
# subject6 | GT=20 | Pred(win)=38.30 | Diff=+18.30 | k_hat(full)=2.49 | phase_entropy(full)=0.943
# subject7 | GT=20 | Pred(win)=49.02 | Diff=+29.02 | k_hat(full)=2.78 | phase_entropy(full)=0.974
# subject8 | GT=21 | Pred(win)=39.39 | Diff=+18.39 | k_hat(full)=2.13 | phase_entropy(full)=0.837
# subject9 | GT=21 | Pred(win)=39.37 | Diff=+18.37 | k_hat(full)=2.23 | phase_entropy(full)=0.800
# subject10 | GT=20 | Pred(win)=46.68 | Diff=+26.68 | k_hat(full)=2.19 | phase_entropy(full)=0.857
#
# 11. Frontal elevation of arms -> Knees bending  |  MAE=2.275
# subject1 | GT=20 | Pred(win)=24.42 | Diff=+4.42 | k_hat(full)=1.00 | phase_entropy(full)=0.014
# subject2 | GT=21 | Pred(win)=23.17 | Diff=+2.17 | k_hat(full)=1.01 | phase_entropy(full)=0.039
# subject3 | GT=21 | Pred(win)=22.01 | Diff=+1.01 | k_hat(full)=1.01 | phase_entropy(full)=0.030
# subject4 | GT=19 | Pred(win)=19.86 | Diff=+0.86 | k_hat(full)=1.01 | phase_entropy(full)=0.033
# subject5 | GT=20 | Pred(win)=19.23 | Diff=-0.77 | k_hat(full)=1.01 | phase_entropy(full)=0.035
# subject6 | GT=20 | Pred(win)=15.92 | Diff=-4.08 | k_hat(full)=1.01 | phase_entropy(full)=0.017
# subject7 | GT=21 | Pred(win)=19.29 | Diff=-1.71 | k_hat(full)=1.02 | phase_entropy(full)=0.042
# subject8 | GT=21 | Pred(win)=17.52 | Diff=-3.48 | k_hat(full)=1.01 | phase_entropy(full)=0.022
# subject9 | GT=21 | Pred(win)=19.58 | Diff=-1.42 | k_hat(full)=1.01 | phase_entropy(full)=0.030
# subject10 | GT=21 | Pred(win)=18.17 | Diff=-2.83 | k_hat(full)=1.02 | phase_entropy(full)=0.050
#
# 12. Knees bending -> Frontal elevation of arms  |  MAE=3.168
# subject1 | GT=20 | Pred(win)=21.15 | Diff=+1.15 | k_hat(full)=1.02 | phase_entropy(full)=0.047
# subject2 | GT=20 | Pred(win)=23.59 | Diff=+3.59 | k_hat(full)=1.03 | phase_entropy(full)=0.073
# subject3 | GT=20 | Pred(win)=18.79 | Diff=-1.21 | k_hat(full)=1.02 | phase_entropy(full)=0.062
# subject4 | GT=20 | Pred(win)=19.15 | Diff=-0.85 | k_hat(full)=1.02 | phase_entropy(full)=0.046
# subject5 | GT=20 | Pred(win)=20.37 | Diff=+0.37 | k_hat(full)=1.02 | phase_entropy(full)=0.047
# subject6 | GT=20 | Pred(win)=12.01 | Diff=-7.99 | k_hat(full)=1.01 | phase_entropy(full)=0.041
# subject7 | GT=20 | Pred(win)=17.71 | Diff=-2.29 | k_hat(full)=1.02 | phase_entropy(full)=0.049
# subject8 | GT=19 | Pred(win)=27.37 | Diff=+8.37 | k_hat(full)=1.02 | phase_entropy(full)=0.052
# subject9 | GT=19 | Pred(win)=18.31 | Diff=-0.69 | k_hat(full)=1.02 | phase_entropy(full)=0.046
# subject10 | GT=20 | Pred(win)=14.84 | Diff=-5.16 | k_hat(full)=1.01 | phase_entropy(full)=0.036
#
# 13. Frontal elevation of arms -> Jogging  |  MAE=136.715
# subject1 | GT=157 | Pred(win)=20.24 | Diff=-136.76 | k_hat(full)=1.01 | phase_entropy(full)=0.020
# subject2 | GT=161 | Pred(win)=21.52 | Diff=-139.48 | k_hat(full)=1.00 | phase_entropy(full)=0.014
# subject3 | GT=154 | Pred(win)=21.98 | Diff=-132.02 | k_hat(full)=1.01 | phase_entropy(full)=0.023
# subject4 | GT=154 | Pred(win)=20.64 | Diff=-133.36 | k_hat(full)=1.01 | phase_entropy(full)=0.027
# subject5 | GT=160 | Pred(win)=19.66 | Diff=-140.34 | k_hat(full)=1.01 | phase_entropy(full)=0.017
# subject6 | GT=156 | Pred(win)=23.23 | Diff=-132.77 | k_hat(full)=1.01 | phase_entropy(full)=0.019
# subject7 | GT=153 | Pred(win)=18.95 | Diff=-134.05 | k_hat(full)=1.01 | phase_entropy(full)=0.022
# subject8 | GT=160 | Pred(win)=20.34 | Diff=-139.66 | k_hat(full)=1.01 | phase_entropy(full)=0.018
# subject9 | GT=166 | Pred(win)=22.44 | Diff=-143.56 | k_hat(full)=1.01 | phase_entropy(full)=0.023
# subject10 | GT=156 | Pred(win)=20.86 | Diff=-135.14 | k_hat(full)=1.02 | phase_entropy(full)=0.036
#
# 14. Jogging -> Frontal elevation of arms  |  MAE=116.720
# subject1 | GT=20 | Pred(win)=154.07 | Diff=+134.07 | k_hat(full)=1.14 | phase_entropy(full)=0.235
# subject2 | GT=20 | Pred(win)=144.69 | Diff=+124.69 | k_hat(full)=1.38 | phase_entropy(full)=0.397
# subject3 | GT=20 | Pred(win)=154.30 | Diff=+134.30 | k_hat(full)=1.17 | phase_entropy(full)=0.259
# subject4 | GT=20 | Pred(win)=148.53 | Diff=+128.53 | k_hat(full)=1.15 | phase_entropy(full)=0.232
# subject5 | GT=20 | Pred(win)=129.63 | Diff=+109.63 | k_hat(full)=1.23 | phase_entropy(full)=0.321
# subject6 | GT=20 | Pred(win)=93.91 | Diff=+73.91 | k_hat(full)=1.17 | phase_entropy(full)=0.254
# subject7 | GT=20 | Pred(win)=125.68 | Diff=+105.68 | k_hat(full)=1.30 | phase_entropy(full)=0.352
# subject8 | GT=19 | Pred(win)=155.07 | Diff=+136.07 | k_hat(full)=1.20 | phase_entropy(full)=0.291
# subject9 | GT=19 | Pred(win)=131.34 | Diff=+112.34 | k_hat(full)=1.20 | phase_entropy(full)=0.276
# subject10 | GT=20 | Pred(win)=127.99 | Diff=+107.99 | k_hat(full)=1.24 | phase_entropy(full)=0.301
#
# 15. Frontal elevation of arms -> Running  |  MAE=143.870
# subject1 | GT=165 | Pred(win)=20.99 | Diff=-144.01 | k_hat(full)=1.01 | phase_entropy(full)=0.018
# subject2 | GT=158 | Pred(win)=21.42 | Diff=-136.58 | k_hat(full)=1.01 | phase_entropy(full)=0.017
# subject3 | GT=174 | Pred(win)=22.79 | Diff=-151.21 | k_hat(full)=1.01 | phase_entropy(full)=0.018
# subject4 | GT=163 | Pred(win)=23.17 | Diff=-139.83 | k_hat(full)=1.01 | phase_entropy(full)=0.026
# subject5 | GT=157 | Pred(win)=19.62 | Diff=-137.38 | k_hat(full)=1.01 | phase_entropy(full)=0.017
# subject6 | GT=172 | Pred(win)=21.91 | Diff=-150.09 | k_hat(full)=1.00 | phase_entropy(full)=0.006
# subject7 | GT=149 | Pred(win)=18.53 | Diff=-130.47 | k_hat(full)=1.00 | phase_entropy(full)=0.012
# subject8 | GT=166 | Pred(win)=22.95 | Diff=-143.05 | k_hat(full)=1.01 | phase_entropy(full)=0.016
# subject9 | GT=174 | Pred(win)=20.87 | Diff=-153.13 | k_hat(full)=1.00 | phase_entropy(full)=0.013
# subject10 | GT=172 | Pred(win)=19.04 | Diff=-152.96 | k_hat(full)=1.00 | phase_entropy(full)=0.010
#
# 16. Running -> Frontal elevation of arms  |  MAE=135.415
# subject1 | GT=20 | Pred(win)=185.78 | Diff=+165.78 | k_hat(full)=1.55 | phase_entropy(full)=0.417
# subject2 | GT=20 | Pred(win)=154.80 | Diff=+134.80 | k_hat(full)=2.07 | phase_entropy(full)=0.443
# subject3 | GT=20 | Pred(win)=177.77 | Diff=+157.77 | k_hat(full)=1.74 | phase_entropy(full)=0.407
# subject4 | GT=20 | Pred(win)=174.56 | Diff=+154.56 | k_hat(full)=1.64 | phase_entropy(full)=0.463
# subject5 | GT=20 | Pred(win)=151.12 | Diff=+131.12 | k_hat(full)=1.73 | phase_entropy(full)=0.488
# subject6 | GT=20 | Pred(win)=109.74 | Diff=+89.74 | k_hat(full)=1.76 | phase_entropy(full)=0.463
# subject7 | GT=20 | Pred(win)=132.53 | Diff=+112.53 | k_hat(full)=1.85 | phase_entropy(full)=0.421
# subject8 | GT=19 | Pred(win)=179.78 | Diff=+160.78 | k_hat(full)=1.65 | phase_entropy(full)=0.424
# subject9 | GT=19 | Pred(win)=149.62 | Diff=+130.62 | k_hat(full)=1.80 | phase_entropy(full)=0.485
# subject10 | GT=20 | Pred(win)=136.44 | Diff=+116.44 | k_hat(full)=1.85 | phase_entropy(full)=0.448
#
# 17. Frontal elevation of arms -> Jump front & back  |  MAE=13.475
# subject1 | GT=20 | Pred(win)=7.01 | Diff=-12.99 | k_hat(full)=1.01 | phase_entropy(full)=0.020
# subject2 | GT=22 | Pred(win)=6.58 | Diff=-15.42 | k_hat(full)=1.01 | phase_entropy(full)=0.023
# subject3 | GT=21 | Pred(win)=6.88 | Diff=-14.12 | k_hat(full)=1.00 | phase_entropy(full)=0.011
# subject4 | GT=21 | Pred(win)=7.65 | Diff=-13.35 | k_hat(full)=1.00 | phase_entropy(full)=0.012
# subject5 | GT=20 | Pred(win)=6.47 | Diff=-13.53 | k_hat(full)=1.01 | phase_entropy(full)=0.020
# subject6 | GT=21 | Pred(win)=7.71 | Diff=-13.29 | k_hat(full)=1.00 | phase_entropy(full)=0.011
# subject7 | GT=19 | Pred(win)=6.57 | Diff=-12.43 | k_hat(full)=1.01 | phase_entropy(full)=0.018
# subject8 | GT=20 | Pred(win)=6.82 | Diff=-13.18 | k_hat(full)=1.01 | phase_entropy(full)=0.020
# subject9 | GT=20 | Pred(win)=6.74 | Diff=-13.26 | k_hat(full)=1.00 | phase_entropy(full)=0.016
# subject10 | GT=20 | Pred(win)=6.83 | Diff=-13.17 | k_hat(full)=1.00 | phase_entropy(full)=0.011
#
# 18. Jump front & back -> Frontal elevation of arms  |  MAE=34.504
# subject1 | GT=20 | Pred(win)=60.56 | Diff=+40.56 | k_hat(full)=2.32 | phase_entropy(full)=0.864
# subject2 | GT=20 | Pred(win)=62.55 | Diff=+42.55 | k_hat(full)=2.77 | phase_entropy(full)=0.975
# subject3 | GT=20 | Pred(win)=52.18 | Diff=+32.18 | k_hat(full)=2.70 | phase_entropy(full)=0.996
# subject4 | GT=20 | Pred(win)=57.89 | Diff=+37.89 | k_hat(full)=2.36 | phase_entropy(full)=0.898
# subject5 | GT=20 | Pred(win)=53.27 | Diff=+33.27 | k_hat(full)=2.57 | phase_entropy(full)=0.926
# subject6 | GT=20 | Pred(win)=37.77 | Diff=+17.77 | k_hat(full)=2.43 | phase_entropy(full)=0.925
# subject7 | GT=20 | Pred(win)=52.87 | Diff=+32.87 | k_hat(full)=2.52 | phase_entropy(full)=0.861
# subject8 | GT=19 | Pred(win)=60.73 | Diff=+41.73 | k_hat(full)=2.55 | phase_entropy(full)=0.896
# subject9 | GT=19 | Pred(win)=53.30 | Diff=+34.30 | k_hat(full)=2.43 | phase_entropy(full)=0.906
# subject10 | GT=20 | Pred(win)=51.90 | Diff=+31.90 | k_hat(full)=2.51 | phase_entropy(full)=0.896
#
# 19. Knees bending -> Jogging  |  MAE=137.272
# subject1 | GT=157 | Pred(win)=16.94 | Diff=-140.06 | k_hat(full)=1.02 | phase_entropy(full)=0.056
# subject2 | GT=161 | Pred(win)=19.57 | Diff=-141.43 | k_hat(full)=1.02 | phase_entropy(full)=0.057
# subject3 | GT=154 | Pred(win)=20.84 | Diff=-133.16 | k_hat(full)=1.01 | phase_entropy(full)=0.041
# subject4 | GT=154 | Pred(win)=20.81 | Diff=-133.19 | k_hat(full)=1.01 | phase_entropy(full)=0.040
# subject5 | GT=160 | Pred(win)=21.06 | Diff=-138.94 | k_hat(full)=1.02 | phase_entropy(full)=0.042
# subject6 | GT=156 | Pred(win)=21.22 | Diff=-134.78 | k_hat(full)=1.02 | phase_entropy(full)=0.045
# subject7 | GT=153 | Pred(win)=20.95 | Diff=-132.05 | k_hat(full)=1.01 | phase_entropy(full)=0.029
# subject8 | GT=160 | Pred(win)=17.46 | Diff=-142.54 | k_hat(full)=1.01 | phase_entropy(full)=0.041
# subject9 | GT=166 | Pred(win)=22.92 | Diff=-143.08 | k_hat(full)=1.01 | phase_entropy(full)=0.037
# subject10 | GT=156 | Pred(win)=22.51 | Diff=-133.49 | k_hat(full)=1.01 | phase_entropy(full)=0.039
#
# 20. Jogging -> Knees bending  |  MAE=115.056
# subject1 | GT=20 | Pred(win)=166.98 | Diff=+146.98 | k_hat(full)=1.10 | phase_entropy(full)=0.175
# subject2 | GT=21 | Pred(win)=141.83 | Diff=+120.83 | k_hat(full)=1.23 | phase_entropy(full)=0.303
# subject3 | GT=21 | Pred(win)=154.86 | Diff=+133.86 | k_hat(full)=1.13 | phase_entropy(full)=0.202
# subject4 | GT=19 | Pred(win)=153.05 | Diff=+134.05 | k_hat(full)=1.17 | phase_entropy(full)=0.242
# subject5 | GT=20 | Pred(win)=136.64 | Diff=+116.64 | k_hat(full)=1.10 | phase_entropy(full)=0.182
# subject6 | GT=20 | Pred(win)=112.03 | Diff=+92.03 | k_hat(full)=1.16 | phase_entropy(full)=0.263
# subject7 | GT=21 | Pred(win)=115.03 | Diff=+94.03 | k_hat(full)=1.29 | phase_entropy(full)=0.381
# subject8 | GT=21 | Pred(win)=122.97 | Diff=+101.97 | k_hat(full)=1.15 | phase_entropy(full)=0.255
# subject9 | GT=21 | Pred(win)=133.99 | Diff=+112.99 | k_hat(full)=1.33 | phase_entropy(full)=0.397
# subject10 | GT=21 | Pred(win)=118.18 | Diff=+97.18 | k_hat(full)=1.36 | phase_entropy(full)=0.414
#
# 21. Knees bending -> Running  |  MAE=147.189
# subject1 | GT=165 | Pred(win)=18.44 | Diff=-146.56 | k_hat(full)=1.03 | phase_entropy(full)=0.063
# subject2 | GT=158 | Pred(win)=19.61 | Diff=-138.39 | k_hat(full)=1.03 | phase_entropy(full)=0.062
# subject3 | GT=174 | Pred(win)=17.12 | Diff=-156.88 | k_hat(full)=1.01 | phase_entropy(full)=0.042
# subject4 | GT=163 | Pred(win)=16.84 | Diff=-146.16 | k_hat(full)=1.02 | phase_entropy(full)=0.064
# subject5 | GT=157 | Pred(win)=18.33 | Diff=-138.67 | k_hat(full)=1.01 | phase_entropy(full)=0.036
# subject6 | GT=172 | Pred(win)=18.90 | Diff=-153.10 | k_hat(full)=1.01 | phase_entropy(full)=0.022
# subject7 | GT=149 | Pred(win)=15.56 | Diff=-133.44 | k_hat(full)=1.01 | phase_entropy(full)=0.038
# subject8 | GT=166 | Pred(win)=18.16 | Diff=-147.84 | k_hat(full)=1.02 | phase_entropy(full)=0.045
# subject9 | GT=174 | Pred(win)=19.19 | Diff=-154.81 | k_hat(full)=1.02 | phase_entropy(full)=0.048
# subject10 | GT=172 | Pred(win)=15.96 | Diff=-156.04 | k_hat(full)=1.01 | phase_entropy(full)=0.032
#
# 22. Running -> Knees bending  |  MAE=135.772
# subject1 | GT=20 | Pred(win)=217.66 | Diff=+197.66 | k_hat(full)=1.28 | phase_entropy(full)=0.327
# subject2 | GT=21 | Pred(win)=176.69 | Diff=+155.69 | k_hat(full)=1.67 | phase_entropy(full)=0.368
# subject3 | GT=21 | Pred(win)=190.16 | Diff=+169.16 | k_hat(full)=1.50 | phase_entropy(full)=0.346
# subject4 | GT=19 | Pred(win)=192.73 | Diff=+173.73 | k_hat(full)=1.48 | phase_entropy(full)=0.358
# subject5 | GT=20 | Pred(win)=160.57 | Diff=+140.57 | k_hat(full)=1.46 | phase_entropy(full)=0.340
# subject6 | GT=20 | Pred(win)=107.71 | Diff=+87.71 | k_hat(full)=1.88 | phase_entropy(full)=0.451
# subject7 | GT=21 | Pred(win)=120.47 | Diff=+99.47 | k_hat(full)=2.06 | phase_entropy(full)=0.540
# subject8 | GT=21 | Pred(win)=124.70 | Diff=+103.70 | k_hat(full)=1.60 | phase_entropy(full)=0.421
# subject9 | GT=21 | Pred(win)=138.04 | Diff=+117.04 | k_hat(full)=2.07 | phase_entropy(full)=0.441
# subject10 | GT=21 | Pred(win)=133.98 | Diff=+112.98 | k_hat(full)=1.94 | phase_entropy(full)=0.436
#
# 23. Knees bending -> Jump front & back  |  MAE=14.331
# subject1 | GT=20 | Pred(win)=6.16 | Diff=-13.84 | k_hat(full)=1.02 | phase_entropy(full)=0.062
# subject2 | GT=22 | Pred(win)=6.34 | Diff=-15.66 | k_hat(full)=1.02 | phase_entropy(full)=0.063
# subject3 | GT=21 | Pred(win)=6.53 | Diff=-14.47 | k_hat(full)=1.03 | phase_entropy(full)=0.077
# subject4 | GT=21 | Pred(win)=6.42 | Diff=-14.58 | k_hat(full)=1.04 | phase_entropy(full)=0.084
# subject5 | GT=20 | Pred(win)=5.32 | Diff=-14.68 | k_hat(full)=1.03 | phase_entropy(full)=0.082
# subject6 | GT=21 | Pred(win)=6.48 | Diff=-14.52 | k_hat(full)=1.03 | phase_entropy(full)=0.077
# subject7 | GT=19 | Pred(win)=6.03 | Diff=-12.97 | k_hat(full)=1.03 | phase_entropy(full)=0.086
# subject8 | GT=20 | Pred(win)=5.41 | Diff=-14.59 | k_hat(full)=1.05 | phase_entropy(full)=0.107
# subject9 | GT=20 | Pred(win)=5.85 | Diff=-14.15 | k_hat(full)=1.05 | phase_entropy(full)=0.095
# subject10 | GT=20 | Pred(win)=6.15 | Diff=-13.85 | k_hat(full)=1.02 | phase_entropy(full)=0.059
#
# 24. Jump front & back -> Knees bending  |  MAE=39.265
# subject1 | GT=20 | Pred(win)=82.56 | Diff=+62.56 | k_hat(full)=1.78 | phase_entropy(full)=0.766
# subject2 | GT=21 | Pred(win)=61.41 | Diff=+40.41 | k_hat(full)=2.46 | phase_entropy(full)=0.951
# subject3 | GT=21 | Pred(win)=59.90 | Diff=+38.90 | k_hat(full)=2.17 | phase_entropy(full)=0.906
# subject4 | GT=19 | Pred(win)=57.86 | Diff=+38.86 | k_hat(full)=2.41 | phase_entropy(full)=0.935
# subject5 | GT=20 | Pred(win)=63.35 | Diff=+43.35 | k_hat(full)=1.88 | phase_entropy(full)=0.831
# subject6 | GT=20 | Pred(win)=43.58 | Diff=+23.58 | k_hat(full)=2.22 | phase_entropy(full)=0.918
# subject7 | GT=21 | Pred(win)=49.34 | Diff=+28.34 | k_hat(full)=2.30 | phase_entropy(full)=0.951
# subject8 | GT=21 | Pred(win)=42.58 | Diff=+21.58 | k_hat(full)=2.39 | phase_entropy(full)=0.969
# subject9 | GT=21 | Pred(win)=75.27 | Diff=+54.27 | k_hat(full)=2.07 | phase_entropy(full)=0.832
# subject10 | GT=21 | Pred(win)=61.81 | Diff=+40.81 | k_hat(full)=2.08 | phase_entropy(full)=0.866
#
# 25. Jogging -> Running  |  MAE=12.577
# subject1 | GT=165 | Pred(win)=167.17 | Diff=+2.17 | k_hat(full)=1.10 | phase_entropy(full)=0.165
# subject2 | GT=158 | Pred(win)=166.68 | Diff=+8.68 | k_hat(full)=1.17 | phase_entropy(full)=0.229
# subject3 | GT=174 | Pred(win)=144.65 | Diff=-29.35 | k_hat(full)=1.22 | phase_entropy(full)=0.247
# subject4 | GT=163 | Pred(win)=149.13 | Diff=-13.87 | k_hat(full)=1.25 | phase_entropy(full)=0.276
# subject5 | GT=157 | Pred(win)=149.85 | Diff=-7.15 | k_hat(full)=1.21 | phase_entropy(full)=0.280
# subject6 | GT=172 | Pred(win)=162.22 | Diff=-9.78 | k_hat(full)=1.20 | phase_entropy(full)=0.261
# subject7 | GT=149 | Pred(win)=141.91 | Diff=-7.09 | k_hat(full)=1.17 | phase_entropy(full)=0.254
# subject8 | GT=166 | Pred(win)=169.35 | Diff=+3.35 | k_hat(full)=1.12 | phase_entropy(full)=0.189
# subject9 | GT=174 | Pred(win)=186.51 | Diff=+12.51 | k_hat(full)=1.11 | phase_entropy(full)=0.182
# subject10 | GT=172 | Pred(win)=140.18 | Diff=-31.82 | k_hat(full)=1.24 | phase_entropy(full)=0.255
#
# 26. Running -> Jogging  |  MAE=19.973
# subject1 | GT=157 | Pred(win)=157.45 | Diff=+0.45 | k_hat(full)=1.79 | phase_entropy(full)=0.274
# subject2 | GT=161 | Pred(win)=155.84 | Diff=-5.16 | k_hat(full)=1.89 | phase_entropy(full)=0.283
# subject3 | GT=154 | Pred(win)=186.40 | Diff=+32.40 | k_hat(full)=1.77 | phase_entropy(full)=0.302
# subject4 | GT=154 | Pred(win)=193.11 | Diff=+39.11 | k_hat(full)=1.73 | phase_entropy(full)=0.263
# subject5 | GT=160 | Pred(win)=183.81 | Diff=+23.81 | k_hat(full)=1.71 | phase_entropy(full)=0.263
# subject6 | GT=156 | Pred(win)=166.48 | Diff=+10.48 | k_hat(full)=1.88 | phase_entropy(full)=0.352
# subject7 | GT=153 | Pred(win)=168.18 | Diff=+15.18 | k_hat(full)=1.79 | phase_entropy(full)=0.300
# subject8 | GT=160 | Pred(win)=170.51 | Diff=+10.51 | k_hat(full)=1.70 | phase_entropy(full)=0.351
# subject9 | GT=166 | Pred(win)=193.00 | Diff=+27.00 | k_hat(full)=1.69 | phase_entropy(full)=0.238
# subject10 | GT=156 | Pred(win)=191.63 | Diff=+35.63 | k_hat(full)=1.72 | phase_entropy(full)=0.244
#
# 27. Jogging -> Jump front & back  |  MAE=29.225
# subject1 | GT=20 | Pred(win)=49.27 | Diff=+29.27 | k_hat(full)=1.29 | phase_entropy(full)=0.341
# subject2 | GT=22 | Pred(win)=51.56 | Diff=+29.56 | k_hat(full)=1.15 | phase_entropy(full)=0.245
# subject3 | GT=21 | Pred(win)=49.57 | Diff=+28.57 | k_hat(full)=1.19 | phase_entropy(full)=0.269
# subject4 | GT=21 | Pred(win)=53.20 | Diff=+32.20 | k_hat(full)=1.18 | phase_entropy(full)=0.281
# subject5 | GT=20 | Pred(win)=39.90 | Diff=+19.90 | k_hat(full)=1.46 | phase_entropy(full)=0.455
# subject6 | GT=21 | Pred(win)=49.08 | Diff=+28.08 | k_hat(full)=1.18 | phase_entropy(full)=0.250
# subject7 | GT=19 | Pred(win)=49.38 | Diff=+30.38 | k_hat(full)=1.22 | phase_entropy(full)=0.321
# subject8 | GT=20 | Pred(win)=54.75 | Diff=+34.75 | k_hat(full)=1.11 | phase_entropy(full)=0.201
# subject9 | GT=20 | Pred(win)=49.86 | Diff=+29.86 | k_hat(full)=1.30 | phase_entropy(full)=0.376
# subject10 | GT=20 | Pred(win)=49.68 | Diff=+29.68 | k_hat(full)=1.26 | phase_entropy(full)=0.317
#
# 28. Jump front & back -> Jogging  |  MAE=90.493
# subject1 | GT=157 | Pred(win)=57.67 | Diff=-99.33 | k_hat(full)=2.30 | phase_entropy(full)=0.890
# subject2 | GT=161 | Pred(win)=68.55 | Diff=-92.45 | k_hat(full)=2.14 | phase_entropy(full)=0.818
# subject3 | GT=154 | Pred(win)=62.08 | Diff=-91.92 | k_hat(full)=2.39 | phase_entropy(full)=0.870
# subject4 | GT=154 | Pred(win)=66.45 | Diff=-87.55 | k_hat(full)=2.23 | phase_entropy(full)=0.806
# subject5 | GT=160 | Pred(win)=70.01 | Diff=-89.99 | k_hat(full)=2.17 | phase_entropy(full)=0.774
# subject6 | GT=156 | Pred(win)=71.26 | Diff=-84.74 | k_hat(full)=2.21 | phase_entropy(full)=0.871
# subject7 | GT=153 | Pred(win)=63.48 | Diff=-89.52 | k_hat(full)=2.31 | phase_entropy(full)=0.793
# subject8 | GT=160 | Pred(win)=61.11 | Diff=-98.89 | k_hat(full)=2.24 | phase_entropy(full)=0.906
# subject9 | GT=166 | Pred(win)=80.22 | Diff=-85.78 | k_hat(full)=1.91 | phase_entropy(full)=0.718
# subject10 | GT=156 | Pred(win)=71.24 | Diff=-84.76 | k_hat(full)=2.12 | phase_entropy(full)=0.745
#
# 29. Running -> Jump front & back  |  MAE=36.049
# subject1 | GT=20 | Pred(win)=51.03 | Diff=+31.03 | k_hat(full)=1.98 | phase_entropy(full)=0.424
# subject2 | GT=22 | Pred(win)=61.44 | Diff=+39.44 | k_hat(full)=1.55 | phase_entropy(full)=0.414
# subject3 | GT=21 | Pred(win)=61.48 | Diff=+40.48 | k_hat(full)=1.61 | phase_entropy(full)=0.397
# subject4 | GT=21 | Pred(win)=52.49 | Diff=+31.49 | k_hat(full)=1.89 | phase_entropy(full)=0.434
# subject5 | GT=20 | Pred(win)=42.43 | Diff=+22.43 | k_hat(full)=2.19 | phase_entropy(full)=0.542
# subject6 | GT=21 | Pred(win)=59.92 | Diff=+38.92 | k_hat(full)=1.77 | phase_entropy(full)=0.439
# subject7 | GT=19 | Pred(win)=51.32 | Diff=+32.32 | k_hat(full)=1.87 | phase_entropy(full)=0.438
# subject8 | GT=20 | Pred(win)=73.78 | Diff=+53.78 | k_hat(full)=1.44 | phase_entropy(full)=0.356
# subject9 | GT=20 | Pred(win)=55.83 | Diff=+35.83 | k_hat(full)=1.85 | phase_entropy(full)=0.444
# subject10 | GT=20 | Pred(win)=54.78 | Diff=+34.78 | k_hat(full)=1.87 | phase_entropy(full)=0.439
#
# 30. Jump front & back -> Running  |  MAE=100.357
# subject1 | GT=165 | Pred(win)=59.26 | Diff=-105.74 | k_hat(full)=2.05 | phase_entropy(full)=0.834
# subject2 | GT=158 | Pred(win)=70.07 | Diff=-87.93 | k_hat(full)=2.10 | phase_entropy(full)=0.808
# subject3 | GT=174 | Pred(win)=63.15 | Diff=-110.85 | k_hat(full)=2.34 | phase_entropy(full)=0.853
# subject4 | GT=163 | Pred(win)=62.07 | Diff=-100.93 | k_hat(full)=2.43 | phase_entropy(full)=0.907
# subject5 | GT=157 | Pred(win)=64.27 | Diff=-92.73 | k_hat(full)=2.44 | phase_entropy(full)=0.867
# subject6 | GT=172 | Pred(win)=67.44 | Diff=-104.56 | k_hat(full)=2.24 | phase_entropy(full)=0.821
# subject7 | GT=149 | Pred(win)=62.20 | Diff=-86.80 | k_hat(full)=2.35 | phase_entropy(full)=0.862
# subject8 | GT=166 | Pred(win)=60.95 | Diff=-105.05 | k_hat(full)=2.27 | phase_entropy(full)=0.903
# subject9 | GT=174 | Pred(win)=72.08 | Diff=-101.92 | k_hat(full)=2.11 | phase_entropy(full)=0.830
# subject10 | GT=172 | Pred(win)=64.94 | Diff=-107.06 | k_hat(full)=2.32 | phase_entropy(full)=0.859
#
# --------------------------------------------------------------------------------------------------------------
# Overall Avg MAE=67.303 | Std=56.128 | #experiments=30
# --------------------------------------------------------------------------------------------------------------
# ==============================================================================================================
