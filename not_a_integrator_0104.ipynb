# %%
# =========================
# ✅ SINGLE-ACTIVITY LOSO ONLY (CSV 저장 X)  — A안 (Baseline은 windowing 사용 X)
#
# - Activity loop
# - For each activity and each fold, train ONE model only on that activity from 9 subjects (windows)
# - Test: evaluate that activity on held-out subject
#
# Integrator-defense modes:
#   orig / reverse / win_shuffle / block_shuffle / phase_randomize
#
# ✅ Baseline-A (Constant-rate integrator)  [ACT-ONLY + TRIAL-BASED]  ✅ windowing 사용 X
# - per-activity mean rate estimated from TRAIN TRIALS (NOT windows)
#   mean_rate = mean_i( count_i / duration_i ) over train trials
# - test count = mean_rate(act) * duration_test
# - ignores input/time order => (given same T) identical across modes
#
# =========================

import os
import glob
import random
import zlib
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader


# ---------------------------------------------------------------------
# 1) Strict Seeding
# ---------------------------------------------------------------------
def set_strict_seed(seed: int):
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


# ---------------------------------------------------------------------
# 2) Stable RNG helpers
# ---------------------------------------------------------------------
def _stable_seed_from_text(text: str, base_seed: int = 0) -> int:
    h = zlib.adler32(text.encode("utf-8"))
    return int((base_seed + h) % (2**31 - 1))


# ---------------------------------------------------------------------
# 3) Transformations (integrator-defense modes)
# ---------------------------------------------------------------------
def transform_reverse(x_np: np.ndarray) -> np.ndarray:
    return x_np[::-1].copy()


def transform_block_shuffle(x_np: np.ndarray, block_len: int, rng: np.random.RandomState) -> np.ndarray:
    """
    Split time into blocks, shuffle block order (keeps within-block local structure).
    x_np: (T,C)
    """
    x = np.asarray(x_np, dtype=np.float32)
    T, C = x.shape
    if block_len <= 1 or T <= block_len:
        return x.copy()

    n_blocks = int(np.ceil(T / block_len))
    blocks = []
    for bi in range(n_blocks):
        st = bi * block_len
        ed = min((bi + 1) * block_len, T)
        blocks.append(x[st:ed])

    perm = rng.permutation(len(blocks))
    out = np.concatenate([blocks[i] for i in perm], axis=0)

    if out.shape[0] != T:
        out = out[:T]
    return out.astype(np.float32, copy=False)


def transform_phase_randomize(x_np: np.ndarray, rng: np.random.RandomState) -> np.ndarray:
    """
    Phase randomization per channel:
    - preserve FFT magnitude
    - randomize phase (except DC & Nyquist), reconstruct real signal
    """
    x = np.asarray(x_np, dtype=np.float32)
    T, C = x.shape
    out = np.zeros_like(x)

    for c in range(C):
        sig = x[:, c].astype(np.float64)

        X = np.fft.rfft(sig)
        mag = np.abs(X)
        phase = np.angle(X)
        n = len(X)

        if n <= 2:
            rec = np.fft.irfft(X, n=T)
            out[:, c] = rec.astype(np.float32)
            continue

        rand_phase = rng.uniform(-np.pi, np.pi, size=n)
        rand_phase[0] = phase[0]
        rand_phase[-1] = phase[-1]

        newX = mag * (np.cos(rand_phase) + 1j * np.sin(rand_phase))
        rec = np.fft.irfft(newX, n=T)
        out[:, c] = rec.astype(np.float32)

    return out


# ---------------------------------------------------------------------
# 4) Data Loading
# ---------------------------------------------------------------------
def load_mhealth_dataset(data_dir, target_activities_map, column_names):
    full_dataset = {}
    file_list = sorted(glob.glob(os.path.join(data_dir, "mHealth_subject*.log")))

    if not file_list:
        print(f"[Warning] No mHealth logs found in {data_dir}")
        return {}

    print(f"Loading {len(file_list)} subjects from {data_dir}...")

    for file_path in file_list:
        file_name = os.path.basename(file_path)
        subj_part = file_name.split('.')[0]
        try:
            subj_id_num = int(''.join(filter(str.isdigit, subj_part)))
            subj_key = f"subject{subj_id_num}"
        except:
            subj_key = subj_part

        try:
            df = pd.read_csv(file_path, sep="\t", header=None)
            df = df.iloc[:, :len(column_names)]
            df.columns = column_names

            subj_data = {}
            for label_code, activity_name in target_activities_map.items():
                activity_df = df[df['activity_id'] == label_code].copy()
                if not activity_df.empty:
                    subj_data[activity_name] = activity_df.drop(columns=['activity_id'])

            full_dataset[subj_key] = subj_data
        except Exception as e:
            print(f"Error loading {file_name}: {e}")
            pass

    return full_dataset


def prepare_trial_list(label_config, full_data, target_map, feature_map):
    """
    label_config: list of (subj, act_id, gt_count)
    returns list of dict:
      data: (T,C) normalized per trial
      count: float
      subj, act_id, act_name, meta
    """
    trial_list = []
    for subj, act_id, gt_count in label_config:
        act_id = int(act_id)
        act_name = target_map.get(act_id)
        feats = feature_map.get(act_id)

        if subj in full_data and act_name in full_data[subj]:
            raw_df = full_data[subj][act_name][feats]
            raw_np = raw_df.values.astype(np.float32)

            # trial-wise z-score
            mean = raw_np.mean(axis=0)
            std = raw_np.std(axis=0) + 1e-6
            norm_np = (raw_np - mean) / std

            trial_list.append({
                "data": norm_np,
                "count": float(gt_count),
                "subj": subj,
                "act_id": act_id,
                "act_name": act_name,
                "meta": f"{subj}_{act_name}",
            })
        else:
            print(f"[Skip] Missing data for {subj} - act_id={act_id} ({act_name})")

    return trial_list


# ---------------------------------------------------------------------
# 5) Windowing (TRAIN)
# ---------------------------------------------------------------------
def trial_list_to_windows(trial_list, fs, win_sec=8.0, stride_sec=4.0, drop_last=True):
    """
    TRAIN: trial -> windows
    window label = trial avg rate * window duration
    """
    win_len = int(round(win_sec * fs))
    stride = int(round(stride_sec * fs))
    assert win_len > 0 and stride > 0

    windows = []
    for item in trial_list:
        x = item["data"]  # (T,C)
        T = x.shape[0]
        total_count = float(item["count"])
        meta = item["meta"]

        total_dur = max(T / float(fs), 1e-6)
        rate_trial = total_count / total_dur

        if T < win_len:
            win_dur = T / float(fs)
            windows.append({
                "data": x,
                "count": rate_trial * win_dur,
                "meta": f"{meta}__win[0:{T}]",
                "subj": item["subj"],
                "act_id": item["act_id"],
                "act_name": item["act_name"],
            })
            continue

        last_start = T - win_len
        starts = list(range(0, last_start + 1, stride))

        for st in starts:
            ed = st + win_len
            win_dur = win_len / float(fs)
            windows.append({
                "data": x[st:ed],
                "count": rate_trial * win_dur,
                "meta": f"{meta}__win[{st}:{ed}]",
                "subj": item["subj"],
                "act_id": item["act_id"],
                "act_name": item["act_name"],
            })

        if not drop_last:
            last_st = starts[-1] + stride
            if last_st < T:
                ed = T
                win_dur = (ed - last_st) / float(fs)
                windows.append({
                    "data": x[last_st:ed],
                    "count": rate_trial * win_dur,
                    "meta": f"{meta}__win[{last_st}:{ed}]",
                    "subj": item["subj"],
                    "act_id": item["act_id"],
                    "act_name": item["act_name"],
                })

    return windows


# ---------------------------------------------------------------------
# 6) Windowing inference (TEST) + win_shuffle
# ---------------------------------------------------------------------
def predict_count_by_windowing(
    model, x_np, fs, win_sec, stride_sec, device,
    tau=1.0, batch_size=64,
    win_shuffle=False, rng: np.random.RandomState = None
):
    """
    TEST: trial -> windows inference -> mean rate -> total count
    win_shuffle=True: shuffle time indices inside each window (strong order destruction).
    """
    win_len = int(round(win_sec * fs))
    stride = int(round(stride_sec * fs))
    T = x_np.shape[0]
    total_dur = T / float(fs)

    if T <= win_len:
        x_tensor = torch.tensor(x_np, dtype=torch.float32).transpose(0, 1).unsqueeze(0).to(device)  # (1,C,T)
        with torch.no_grad():
            rate_hat, _, _, _ = model(x_tensor, mask=None, tau=tau)
        pred_count = float(rate_hat.item() * total_dur)
        return pred_count, np.array([float(rate_hat.item())], dtype=np.float32)

    starts = list(range(0, T - win_len + 1, stride))
    windows = np.stack([x_np[st:st + win_len] for st in starts], axis=0)  # (N,W,C)

    if win_shuffle:
        assert rng is not None
        N, W, C = windows.shape
        for i in range(N):
            perm = rng.permutation(W)
            windows[i] = windows[i, perm, :]

    xw = torch.tensor(windows, dtype=torch.float32).permute(0, 2, 1).to(device)  # (N,C,W)

    rates = []
    model.eval()
    with torch.no_grad():
        for i in range(0, xw.shape[0], batch_size):
            xb = xw[i:i + batch_size]
            r_hat, _, _, _ = model(xb, mask=None, tau=tau)
            rates.append(r_hat.detach().cpu().numpy())

    rates = np.concatenate(rates, axis=0)
    rate_mean = float(rates.mean())
    pred_count = rate_mean * total_dur
    return float(pred_count), rates


# ---------------------------------------------------------------------
# 7) Dataset / Collate
# ---------------------------------------------------------------------
class TrialDataset(Dataset):
    def __init__(self, trial_list):
        self.trials = trial_list

    def __len__(self):
        return len(self.trials)

    def __getitem__(self, idx):
        item = self.trials[idx]
        data = torch.tensor(item['data'], dtype=torch.float32).transpose(0, 1)  # (C,T)
        count = torch.tensor(item['count'], dtype=torch.float32)
        return data, count, item['meta']


def collate_variable_length(batch):
    max_len = max([x[0].shape[1] for x in batch])
    C = batch[0][0].shape[0]

    padded_data, masks, counts, metas, lengths = [], [], [], [], []
    for data, count, meta in batch:
        T = data.shape[1]
        lengths.append(T)

        pad_size = max_len - T
        if pad_size > 0:
            pad = torch.zeros(C, pad_size)
            d_padded = torch.cat([data, pad], dim=1)
            mask = torch.cat([torch.ones(T), torch.zeros(pad_size)], dim=0)
        else:
            d_padded = data
            mask = torch.ones(T)

        padded_data.append(d_padded)
        masks.append(mask)
        counts.append(count)
        metas.append(meta)

    return {
        "data": torch.stack(padded_data),
        "mask": torch.stack(masks),
        "count": torch.stack(counts),
        "length": torch.tensor(lengths, dtype=torch.float32),
        "meta": metas
    }


# ---------------------------------------------------------------------
# 8) Model
# ---------------------------------------------------------------------
class ManifoldEncoder(nn.Module):
    def __init__(self, input_ch, hidden_dim=128, latent_dim=16):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv1d(input_ch, hidden_dim, 5, padding=2),
            nn.ReLU(),
            nn.Conv1d(hidden_dim, hidden_dim, 5, padding=2),
            nn.ReLU(),
            nn.Conv1d(hidden_dim, latent_dim, 1)
        )

    def forward(self, x):
        z = self.net(x)            # (B,D,T)
        z = z.transpose(1, 2)      # (B,T,D)
        return z


class ManifoldDecoder(nn.Module):
    def __init__(self, latent_dim, hidden_dim, out_ch):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv1d(latent_dim, hidden_dim, 5, padding=2),
            nn.ReLU(),
            nn.Conv1d(hidden_dim, hidden_dim, 5, padding=2),
            nn.ReLU(),
            nn.Conv1d(hidden_dim, out_ch, 1)
        )

    def forward(self, z):
        zt = z.transpose(1, 2)     # (B,D,T)
        x_hat = self.net(zt)       # (B,C,T)
        return x_hat


class MultiRateHead(nn.Module):
    def __init__(self, latent_dim=16, hidden=64, K_max=6):
        super().__init__()
        self.K_max = K_max
        self.net = nn.Sequential(
            nn.Linear(latent_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1 + K_max)  # [amp | phase_logits...]
        )

    def forward(self, z, tau=1.0):
        out = self.net(z)                     # (B,T,1+K)
        amp = F.softplus(out[..., 0])         # (B,T) >=0
        phase_logits = out[..., 1:]           # (B,T,K)
        phase = F.softmax(phase_logits / tau, dim=-1)
        return amp, phase, phase_logits


class KAutoCountModel(nn.Module):
    def __init__(self, input_ch, hidden_dim=128, latent_dim=16, K_max=6):
        super().__init__()
        self.encoder = ManifoldEncoder(input_ch, hidden_dim, latent_dim)
        self.decoder = ManifoldDecoder(latent_dim, hidden_dim, input_ch)
        self.rate_head = MultiRateHead(latent_dim, hidden=hidden_dim, K_max=K_max)
        self._init_weights()

    def _init_weights(self):
        for m in self.modules():
            if isinstance(m, (nn.Conv1d, nn.Linear)):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
        with torch.no_grad():
            b = self.rate_head.net[-1].bias
            b.zero_()
            b[0].fill_(-2.0)  # amp bias

    @staticmethod
    def _masked_mean_time(x, mask=None, eps=1e-6):
        if mask is None:
            return x.mean(dim=1)
        if x.dim() == 2:
            m = mask.to(dtype=x.dtype, device=x.device)
            return (x * m).sum(dim=1) / (m.sum(dim=1) + eps)
        elif x.dim() == 3:
            m = mask.to(dtype=x.dtype, device=x.device).unsqueeze(-1)
            return (x * m).sum(dim=1) / (m.sum(dim=1) + eps)
        else:
            raise ValueError(f"Unsupported dim for masked mean: {x.dim()}")

    def forward(self, x, mask=None, tau=1.0):
        z = self.encoder(x)              # (B,T,D)
        x_hat = self.decoder(z)          # (B,C,T)

        amp_t, phase_p, _ = self.rate_head(z, tau=tau)
        micro_rate_t = amp_t             # (B,T)

        p_bar = self._masked_mean_time(phase_p, mask)           # (B,K)
        k_hat = 1.0 / (p_bar.pow(2).sum(dim=1) + 1e-6)          # (B,)

        rep_rate_t = micro_rate_t / (k_hat.unsqueeze(1) + 1e-6) # (B,T)
        if mask is not None:
            rep_rate_t = rep_rate_t * mask

        if mask is None:
            avg_rep_rate = rep_rate_t.mean(dim=1)
        else:
            avg_rep_rate = (rep_rate_t * mask).sum(dim=1) / (mask.sum(dim=1) + 1e-6)

        aux = {
            "phase_p": phase_p,          # (B,T,K)
            "rep_rate_t": rep_rate_t,    # (B,T)
            "k_hat": k_hat,              # (B,)
        }
        return avg_rep_rate, z, x_hat, aux


# ---------------------------------------------------------------------
# 9) Loss utils
# ---------------------------------------------------------------------
def masked_recon_mse(x_hat, x, mask, eps=1e-6):
    mask = mask.to(dtype=x.dtype, device=x.device)
    mask_bc = mask.unsqueeze(1)              # (B,1,T)
    se = (x_hat - x) ** 2                    # (B,C,T)
    se = se * mask_bc
    denom = (mask.sum() * x.shape[1]) + eps
    return se.sum() / denom


def temporal_smoothness(v, mask=None, eps=1e-6):
    dv = torch.abs(v[:, 1:] - v[:, :-1])
    if mask is None:
        return dv.mean()
    m = mask[:, 1:] * mask[:, :-1]
    m = m.to(dtype=dv.dtype, device=dv.device)
    return (dv * m).sum() / (m.sum() + eps)


def phase_entropy_loss(phase_p, mask=None, eps=1e-8):
    ent = -(phase_p * (phase_p + eps).log()).sum(dim=-1)  # (B,T)
    if mask is None:
        return ent.mean()
    ent = ent * mask
    return ent.sum() / (mask.sum() + eps)


def effK_usage_loss(phase_p, mask=None, eps=1e-6):
    if mask is None:
        p_bar = phase_p.mean(dim=1)
    else:
        m = mask.to(dtype=phase_p.dtype, device=phase_p.device).unsqueeze(-1)
        p_bar = (phase_p * m).sum(dim=1) / (m.sum(dim=1) + eps)
    effK = 1.0 / (p_bar.pow(2).sum(dim=1) + eps)
    return effK.mean()


# ---------------------------------------------------------------------
# 10) Train
# ---------------------------------------------------------------------
def train_one_epoch(model, loader, optimizer, config, device):
    model.train()
    fs = config["fs"]
    tau = config.get("tau", 1.0)

    lam_recon = config.get("lambda_recon", 1.0)
    lam_smooth = config.get("lambda_smooth", 0.05)
    lam_phase_ent = config.get("lambda_phase_ent", 0.01)
    lam_effk = config.get("lambda_effk", 0.0075)

    for batch in loader:
        x = batch["data"].to(device)
        mask = batch["mask"].to(device)
        y_count = batch["count"].to(device)
        length = batch["length"].to(device)

        duration = torch.clamp(length / fs, min=1e-6)
        y_rate = y_count / duration

        optimizer.zero_grad()
        rate_hat, _, x_hat, aux = model(x, mask, tau=tau)

        loss_rate = F.mse_loss(rate_hat, y_rate)
        loss_recon = masked_recon_mse(x_hat, x, mask)
        loss_smooth = temporal_smoothness(aux["rep_rate_t"], mask)
        loss_phase_ent = phase_entropy_loss(aux["phase_p"], mask)
        loss_effk = effK_usage_loss(aux["phase_p"], mask)

        loss = (loss_rate
                + lam_recon * loss_recon
                + lam_smooth * loss_smooth
                + lam_phase_ent * loss_phase_ent
                + lam_effk * loss_effk)

        loss.backward()
        optimizer.step()


# ---------------------------------------------------------------------
# 11) Metrics helpers (entropy / effK)
# ---------------------------------------------------------------------
def compute_phase_entropy_mean(phase_p_np, eps=1e-8):
    phase_p_np = np.asarray(phase_p_np, dtype=np.float32)  # (T,K)
    ent_t = -(phase_p_np * np.log(phase_p_np + eps)).sum(axis=1)
    return float(ent_t.mean())


def compute_effK_from_phase_mean(phase_p_np, eps=1e-6):
    phase_p_np = np.asarray(phase_p_np, dtype=np.float32)  # (T,K)
    p_bar = phase_p_np.mean(axis=0)
    effK = 1.0 / (np.sum(p_bar ** 2) + eps)
    return float(effK)


# ---------------------------------------------------------------------
# 12) ✅ Baseline-A: TRIAL-BASED mean rate (windowing 사용 X)
# ---------------------------------------------------------------------
def estimate_baselineA_mean_rate_from_train_trials(train_trials, fs, eps=1e-6):
    """
    train_trials: list of dict (from prepare_trial_list)
      - each has: data (T,C), count (float)
    return: mean of TRIAL-level rates over ALL train trials
      rate_i = count_i / (T_i/fs)
    """
    rates = []
    for tr in train_trials:
        T = int(tr["data"].shape[0])
        dur = max(T / float(fs), eps)
        rates.append(float(tr["count"]) / dur)
    return float(np.mean(rates)) if len(rates) > 0 else 0.0


def baselineA_predict_count(mean_rate, T, fs):
    dur = max(T / float(fs), 1e-6)
    return float(mean_rate * dur)


# ---------------------------------------------------------------------
# 13) Core evaluator for ONE trial
# ---------------------------------------------------------------------
def eval_one_trial_all_modes(model, CONFIG, device, item, mean_rate_baseA, fold_idx, track_name="single"):
    MODES = ["orig", "reverse", "win_shuffle", "block_shuffle", "phase_randomize"]

    x_np_orig = item["data"]
    T = x_np_orig.shape[0]
    gt = float(item["count"])
    act_id = int(item["act_id"])
    act_name = item["act_name"]
    meta = item["meta"]
    test_subj = item["subj"]

    base_seed = int(CONFIG["seed"] + (fold_idx + 1) * 100000)
    rng_wshf  = np.random.RandomState(_stable_seed_from_text(meta + "__win_shuffle", base_seed))
    rng_bshf  = np.random.RandomState(_stable_seed_from_text(meta + "__block_shuffle", base_seed))
    rng_ph    = np.random.RandomState(_stable_seed_from_text(meta + "__phase_rand", base_seed))

    # ✅ Baseline-A: mode-agnostic (TRIAL-based mean rate)
    mean_rate_used = float(mean_rate_baseA)
    pred_base = baselineA_predict_count(mean_rate_used, T=T, fs=CONFIG["fs"])

    rows = []
    for mode in MODES:
        if mode == "orig":
            x_for_pred = x_np_orig
            win_shuffle = False
            rng = None
            x_for_aux = x_np_orig

        elif mode == "reverse":
            x_for_pred = transform_reverse(x_np_orig)
            win_shuffle = False
            rng = None
            x_for_aux = x_for_pred

        elif mode == "win_shuffle":
            x_for_pred = x_np_orig
            win_shuffle = True
            rng = rng_wshf
            perm = rng_wshf.permutation(x_np_orig.shape[0])
            x_for_aux = x_np_orig[perm].copy()

        elif mode == "block_shuffle":
            block_len = int(round(CONFIG["block_sec"] * CONFIG["fs"]))
            x_for_pred = transform_block_shuffle(x_np_orig, block_len=block_len, rng=rng_bshf)
            win_shuffle = False
            rng = None
            x_for_aux = x_for_pred

        elif mode == "phase_randomize":
            x_for_pred = transform_phase_randomize(x_np_orig, rng=rng_ph)
            win_shuffle = False
            rng = None
            x_for_aux = x_for_pred

        else:
            raise ValueError(mode)

        pred_ours, _ = predict_count_by_windowing(
            model,
            x_np=x_for_pred,
            fs=CONFIG["fs"],
            win_sec=CONFIG["win_sec"],
            stride_sec=CONFIG["stride_sec"],
            device=device,
            tau=CONFIG.get("tau", 1.0),
            batch_size=CONFIG.get("batch_size", 64),
            win_shuffle=win_shuffle,
            rng=rng
        )

        # aux (k_hat / entropy / effK) — full-trial 1회 forward
        x_tensor = torch.tensor(x_for_aux, dtype=torch.float32).transpose(0, 1).unsqueeze(0).to(device)
        with torch.no_grad():
            _, _, _, aux = model(x_tensor, mask=None, tau=CONFIG.get("tau", 1.0))
        k_hat = float(aux["k_hat"].item())
        phase_p = aux["phase_p"].squeeze(0).detach().cpu().numpy()  # (T,K)
        ent = compute_phase_entropy_mean(phase_p)
        effK = compute_effK_from_phase_mean(phase_p)

        dur = T / float(CONFIG["fs"])
        pred_rate = pred_ours / max(dur, 1e-6)
        gt_rate = gt / max(dur, 1e-6)

        abs_err = abs(pred_ours - gt)
        mape = abs_err / (abs(gt) + 1e-6) * 100.0
        bias = pred_ours - gt

        abs_err_b = abs(pred_base - gt)
        mape_b = abs_err_b / (abs(gt) + 1e-6) * 100.0
        bias_b = pred_base - gt

        rows.append({
            "track": track_name,
            "fold": fold_idx + 1,
            "test_subj": test_subj,
            "act_id": act_id,
            "act_name": act_name,
            "mode": mode,
            "T": int(T),
            "duration_sec": float(dur),
            "GT": float(gt),

            "Pred_ours": float(pred_ours),
            "MAE_ours": float(abs_err),
            "MAPE_ours": float(mape),
            "Bias_ours": float(bias),
            "GT_rate": float(gt_rate),
            "Pred_rate": float(pred_rate),
            "k_hat": float(k_hat),
            "entropy": float(ent),
            "effK": float(effK),

            "Pred_baseA": float(pred_base),
            "MAE_baseA": float(abs_err_b),
            "MAPE_baseA": float(mape_b),
            "Bias_baseA": float(bias_b),

            "BaseA_rate_trial": float(mean_rate_used),
        })

    return rows


# ---------------------------------------------------------------------
# 14) SINGLE-ACTIVITY LOSO (activity loop) ONLY
# ---------------------------------------------------------------------
def run_single_activity_loso_only(CONFIG, full_data, device, activity_specs):
    subjects = [f"subject{i}" for i in range(1, 11)]
    out_rows = []

    print("\n" + "=" * 140)
    print(" >>> SINGLE-ACTIVITY LOSO ONLY")
    print(" >>> Baseline-A: ACT-only + TRIAL-based mean rate (windowing 사용 X)")
    print("=" * 140)

    for spec in activity_specs:
        act_id = int(spec["act_id"])
        act_name = spec["act_name"]
        labels = spec["labels"]

        print("\n" + "-" * 140)
        print(f"[Single] Activity: {act_name} (id={act_id})")
        print("-" * 140)

        for fold_idx, test_subj in enumerate(subjects):
            set_strict_seed(CONFIG["seed"])

            train_labels = [t for t in labels if t[0] != test_subj]
            test_labels  = [t for t in labels if t[0] == test_subj]

            # Restrict maps to that activity only
            target_map_one = {act_id: act_name}
            feat_map_one   = {act_id: CONFIG["ACT_FEATURE_MAP"][act_id]}

            train_trials = prepare_trial_list(train_labels, full_data, target_map_one, feat_map_one)
            test_trials  = prepare_trial_list(test_labels,  full_data, target_map_one, feat_map_one)

            if len(train_trials) == 0 or len(test_trials) == 0:
                print(f"[Skip] Fold {fold_idx+1}: train_trials={len(train_trials)}, test_trials={len(test_trials)}")
                continue

            # ✅ OURS Train windows (contribution 유지)
            train_windows = trial_list_to_windows(
                train_trials, fs=CONFIG["fs"],
                win_sec=CONFIG["win_sec"], stride_sec=CONFIG["stride_sec"],
                drop_last=CONFIG["drop_last"]
            )

            # ✅ Baseline-A: TRIAL-based mean rate (windowing 사용 X)
            mean_rate_baseA = estimate_baselineA_mean_rate_from_train_trials(train_trials, fs=CONFIG["fs"])

            g = torch.Generator()
            g.manual_seed(CONFIG["seed"])

            train_loader = DataLoader(
                TrialDataset(train_windows),
                batch_size=CONFIG["batch_size"],
                shuffle=True,
                collate_fn=collate_variable_length,
                generator=g,
                num_workers=0
            )

            input_ch = train_windows[0]["data"].shape[1]
            model = KAutoCountModel(
                input_ch=input_ch,
                hidden_dim=CONFIG["hidden_dim"],
                latent_dim=CONFIG["latent_dim"],
                K_max=CONFIG["K_max"]
            ).to(device)

            optimizer = torch.optim.Adam(model.parameters(), lr=CONFIG["lr"])
            scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.5)

            for epoch in range(CONFIG["epochs"]):
                train_one_epoch(model, train_loader, optimizer, CONFIG, device)
                scheduler.step()

            model.eval()

            fold_rows = []
            for item in test_trials:
                fold_rows.extend(eval_one_trial_all_modes(
                    model=model, CONFIG=CONFIG, device=device,
                    item=item, mean_rate_baseA=mean_rate_baseA,
                    fold_idx=fold_idx, track_name="single"
                ))
            out_rows.extend(fold_rows)

            # Fold quick summary
            df_fold = pd.DataFrame(fold_rows)
            gsum = (df_fold.groupby("mode")
                    .agg(n=("MAE_ours", "count"),
                         MAE_ours=("MAE_ours", "mean"),
                         MAE_baseA=("MAE_baseA", "mean"),
                         baseA_rate_trial=("BaseA_rate_trial", "mean"))
                    .reset_index())
            mae0 = float(gsum[gsum["mode"] == "orig"]["MAE_ours"].values[0]) if (gsum["mode"] == "orig").any() else float("nan")

            base_rate = float(df_fold["BaseA_rate_trial"].iloc[0])
            print(f"[Fold {fold_idx+1:2d}] Test={test_subj} | BaseA mean_rate(TRIAL)={base_rate:.4f} reps/s")
            for _, rr in gsum.iterrows():
                d = float(rr["MAE_ours"]) - mae0 if np.isfinite(mae0) else float("nan")
                print(f"  {rr['mode']:14s} | MAE ours={rr['MAE_ours']:.3f} (Δ={d:+.3f}) | MAE baseA={rr['MAE_baseA']:.3f} | n={int(rr['n'])}")

    return pd.DataFrame(out_rows)


# ---------------------------------------------------------------------
# 15) Print-only summaries (NO CSV saving)
# ---------------------------------------------------------------------
def print_summaries(df_all: pd.DataFrame):
    if df_all is None or len(df_all) == 0:
        print("[Warn] No rows to summarize.")
        return

    # Per-activity, per-mode
    g_act = (df_all.groupby(["act_id", "act_name", "mode"])
             .agg(
                n=("MAE_ours", "count"),
                MAE_ours=("MAE_ours", "mean"),
                MAE_baseA=("MAE_baseA", "mean"),
                entropy=("entropy", "mean"),
                effK=("effK", "mean"),
                k_hat=("k_hat", "mean"),
                baseA_rate_trial=("BaseA_rate_trial", "mean"),
             )
             .reset_index())

    # Δ vs orig inside each activity
    blocks = []
    for (aid, aname), sdf in g_act.groupby(["act_id", "act_name"], sort=False):
        base = sdf[sdf["mode"] == "orig"]
        mae0 = float(base["MAE_ours"].values[0]) if len(base) > 0 else np.nan
        tmp = sdf.copy()
        tmp["dMAE_vs_orig"] = tmp["MAE_ours"] - mae0
        blocks.append(tmp)
    g_act2 = pd.concat(blocks, axis=0).reset_index(drop=True)

    # Overall by mode
    g_all = (df_all.groupby(["mode"])
             .agg(
                n=("MAE_ours", "count"),
                MAE_ours=("MAE_ours", "mean"),
                MAE_baseA=("MAE_baseA", "mean"),
                entropy=("entropy", "mean"),
                effK=("effK", "mean"),
                k_hat=("k_hat", "mean"),
                baseA_rate_trial=("BaseA_rate_trial", "mean"),
             )
             .reset_index())
    if (g_all["mode"] == "orig").any():
        mae0 = float(g_all[g_all["mode"] == "orig"]["MAE_ours"].values[0])
        g_all["dMAE_vs_orig"] = g_all["MAE_ours"] - mae0
    else:
        g_all["dMAE_vs_orig"] = np.nan

    print("\n" + "=" * 140)
    print("[OVERALL SUMMARY]  (Δ = MAE(mode) - MAE(orig))")
    with pd.option_context('display.max_rows', 200, 'display.max_columns', 80, 'display.width', 220):
        print(g_all.sort_values("mode").to_string(index=False))

    print("\n" + "=" * 140)
    print("[PER-ACTIVITY SUMMARY]  (Δ = MAE(mode) - MAE(orig within activity))")
    with pd.option_context('display.max_rows', 999, 'display.max_columns', 80, 'display.width', 240):
        print(g_act2.sort_values(["act_id", "mode"]).to_string(index=False))
    print("=" * 140)


# ---------------------------------------------------------------------
# 16) Main
# ---------------------------------------------------------------------
def main():
    BASE_CONFIG = {
        "seed": 42,
        "data_dir": "/content/drive/MyDrive/Colab Notebooks/HAR_data/MHEALTHDATASET",

        "COLUMN_NAMES": [
            'acc_chest_x', 'acc_chest_y', 'acc_chest_z',
            'ecg_1', 'ecg_2',
            'acc_ankle_x', 'acc_ankle_y', 'acc_ankle_z',
            'gyro_ankle_x', 'gyro_ankle_y', 'gyro_ankle_z',
            'mag_ankle_x', 'mag_ankle_y', 'mag_ankle_z',
            'acc_arm_x', 'acc_arm_y', 'acc_arm_z',
            'gyro_arm_x', 'gyro_arm_y', 'gyro_arm_z',
            'mag_arm_x', 'mag_arm_y', 'mag_arm_z',
            'activity_id'
        ],

        # training
        "epochs": 50,
        "lr": 5e-4,
        "batch_size": 64,
        "fs": 50,

        # windowing (OURS에만 사용)
        "win_sec": 8.0,
        "stride_sec": 4.0,
        "drop_last": True,

        # model
        "hidden_dim": 128,
        "latent_dim": 16,
        "K_max": 6,

        # loss weights
        "lambda_recon": 1.0,
        "lambda_smooth": 0.05,
        "lambda_phase_ent": 0.01,
        "lambda_effk": 0.0075,

        "tau": 1.0,

        # defense config
        "block_sec": 0.8,
    }

    DEFAULT_FEATS = [
        'acc_chest_x', 'acc_chest_y', 'acc_chest_z',
        'acc_ankle_x', 'acc_ankle_y', 'acc_ankle_z',
        'gyro_ankle_x', 'gyro_ankle_y', 'gyro_ankle_z',
        'acc_arm_x', 'acc_arm_y', 'acc_arm_z',
        'gyro_arm_x', 'gyro_arm_y', 'gyro_arm_z'
    ]

    ACTIVITY_SPECS = [
        {"act_id": 6,  "act_name": "Waist bends forward",       "labels": [
            ("subject1", 6, 21), ("subject2", 6, 19), ("subject3", 6, 21), ("subject4", 6, 20), ("subject5", 6, 20),
            ("subject6", 6, 20), ("subject7", 6, 20), ("subject8", 6, 21), ("subject9", 6, 21), ("subject10", 6, 20),
        ]},
        {"act_id": 7,  "act_name": "Frontal elevation of arms", "labels": [
            ("subject1", 7, 20), ("subject2", 7, 20), ("subject3", 7, 20), ("subject4", 7, 20), ("subject5", 7, 20),
            ("subject6", 7, 20), ("subject7", 7, 20), ("subject8", 7, 19), ("subject9", 7, 19), ("subject10", 7, 20),
        ]},
        {"act_id": 8,  "act_name": "Knees bending",             "labels": [
            ("subject1", 8, 20), ("subject2", 8, 21), ("subject3", 8, 21), ("subject4", 8, 19), ("subject5", 8, 20),
            ("subject6", 8, 20), ("subject7", 8, 21), ("subject8", 8, 21), ("subject9", 8, 21), ("subject10", 8, 21),
        ]},
        {"act_id": 12, "act_name": "Jump front & back",         "labels": [
            ("subject1", 12, 20), ("subject2", 12, 22), ("subject3", 12, 21), ("subject4", 12, 21), ("subject5", 12, 20),
            ("subject6", 12, 21), ("subject7", 12, 19), ("subject8", 12, 20), ("subject9", 12, 20), ("subject10", 12, 20),
        ]},
        {"act_id": 10, "act_name": "Jogging",                   "labels": [
            ("subject1", 10, 157), ("subject2", 10, 161), ("subject3", 10, 154), ("subject4", 10, 154), ("subject5", 10, 160),
            ("subject6", 10, 156), ("subject7", 10, 153), ("subject8", 10, 160), ("subject9", 10, 166), ("subject10", 10, 156),
        ]},
        {"act_id": 11, "act_name": "Running",                   "labels": [
            ("subject1", 11, 165), ("subject2", 11, 158), ("subject3", 11, 174), ("subject4", 11, 163), ("subject5", 11, 157),
            ("subject6", 11, 172), ("subject7", 11, 149), ("subject8", 11, 166), ("subject9", 11, 174), ("subject10", 11, 172),
        ]},
    ]

    # Maps (load 단계에서 필요)
    target_map = {int(s["act_id"]): s["act_name"] for s in ACTIVITY_SPECS}
    feat_map = {int(s["act_id"]): DEFAULT_FEATS for s in ACTIVITY_SPECS}

    CONFIG = dict(BASE_CONFIG)
    CONFIG["TARGET_ACTIVITIES_MAP"] = target_map
    CONFIG["ACT_FEATURE_MAP"] = feat_map

    set_strict_seed(CONFIG["seed"])
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Device: {device}")

    # Load full data once
    full_data = load_mhealth_dataset(CONFIG["data_dir"], CONFIG["TARGET_ACTIVITIES_MAP"], CONFIG["COLUMN_NAMES"])
    if not full_data:
        return

    # Run SINGLE only
    df_all = run_single_activity_loso_only(CONFIG, full_data, device, ACTIVITY_SPECS)

    # Print summaries (NO CSV saving)
    print_summaries(df_all)


if __name__ == "__main__":
    main()
# Out:
# Device: cuda
# Loading 10 subjects from /content/drive/MyDrive/Colab Notebooks/HAR_data/MHEALTHDATASET...
#
# ============================================================================================================================================
#  >>> SINGLE-ACTIVITY LOSO ONLY
#  >>> Baseline-A: ACT-only + TRIAL-based mean rate (windowing 사용 X)
# ============================================================================================================================================
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# [Single] Activity: Waist bends forward (id=6)
# --------------------------------------------------------------------------------------------------------------------------------------------
# [Fold  1] Test=subject1 | BaseA mean_rate(TRIAL)=0.3698 reps/s
#   block_shuffle  | MAE ours=1.820 (Δ=-0.318) | MAE baseA=1.718 | n=1
#   orig           | MAE ours=2.139 (Δ=+0.000) | MAE baseA=1.718 | n=1
#   phase_randomize | MAE ours=6.618 (Δ=+4.480) | MAE baseA=1.718 | n=1
#   reverse        | MAE ours=1.730 (Δ=-0.408) | MAE baseA=1.718 | n=1
#   win_shuffle    | MAE ours=3.910 (Δ=+1.771) | MAE baseA=1.718 | n=1
# [Fold  2] Test=subject2 | BaseA mean_rate(TRIAL)=0.3745 reps/s
#   block_shuffle  | MAE ours=5.833 (Δ=+0.664) | MAE baseA=4.772 | n=1
#   orig           | MAE ours=5.169 (Δ=+0.000) | MAE baseA=4.772 | n=1
#   phase_randomize | MAE ours=12.286 (Δ=+7.117) | MAE baseA=4.772 | n=1
#   reverse        | MAE ours=5.836 (Δ=+0.667) | MAE baseA=4.772 | n=1
#   win_shuffle    | MAE ours=10.337 (Δ=+5.168) | MAE baseA=4.772 | n=1
# [Fold  3] Test=subject3 | BaseA mean_rate(TRIAL)=0.3716 reps/s
#   block_shuffle  | MAE ours=8.680 (Δ=+0.234) | MAE baseA=2.974 | n=1
#   orig           | MAE ours=8.446 (Δ=+0.000) | MAE baseA=2.974 | n=1
#   phase_randomize | MAE ours=13.453 (Δ=+5.006) | MAE baseA=2.974 | n=1
#   reverse        | MAE ours=8.613 (Δ=+0.166) | MAE baseA=2.974 | n=1
#   win_shuffle    | MAE ours=11.863 (Δ=+3.417) | MAE baseA=2.974 | n=1
# [Fold  4] Test=subject4 | BaseA mean_rate(TRIAL)=0.3743 reps/s
#   block_shuffle  | MAE ours=3.335 (Δ=+0.185) | MAE baseA=4.916 | n=1
#   orig           | MAE ours=3.151 (Δ=+0.000) | MAE baseA=4.916 | n=1
#   phase_randomize | MAE ours=12.055 (Δ=+8.904) | MAE baseA=4.916 | n=1
#   reverse        | MAE ours=3.152 (Δ=+0.001) | MAE baseA=4.916 | n=1
#   win_shuffle    | MAE ours=10.537 (Δ=+7.386) | MAE baseA=4.916 | n=1
# [Fold  5] Test=subject5 | BaseA mean_rate(TRIAL)=0.3675 reps/s
#   block_shuffle  | MAE ours=6.113 (Δ=+0.582) | MAE baseA=0.325 | n=1
#   orig           | MAE ours=5.531 (Δ=+0.000) | MAE baseA=0.325 | n=1
#   phase_randomize | MAE ours=8.550 (Δ=+3.019) | MAE baseA=0.325 | n=1
#   reverse        | MAE ours=5.047 (Δ=-0.484) | MAE baseA=0.325 | n=1
#   win_shuffle    | MAE ours=5.801 (Δ=+0.270) | MAE baseA=0.325 | n=1
# [Fold  6] Test=subject6 | BaseA mean_rate(TRIAL)=0.3573 reps/s
#   block_shuffle  | MAE ours=6.303 (Δ=-0.523) | MAE baseA=4.266 | n=1
#   orig           | MAE ours=6.826 (Δ=+0.000) | MAE baseA=4.266 | n=1
#   phase_randomize | MAE ours=1.871 (Δ=-4.955) | MAE baseA=4.266 | n=1
#   reverse        | MAE ours=5.751 (Δ=-1.075) | MAE baseA=4.266 | n=1
#   win_shuffle    | MAE ours=1.975 (Δ=-4.851) | MAE baseA=4.266 | n=1
# [Fold  7] Test=subject7 | BaseA mean_rate(TRIAL)=0.3716 reps/s
#   block_shuffle  | MAE ours=4.771 (Δ=+0.276) | MAE baseA=2.829 | n=1
#   orig           | MAE ours=4.495 (Δ=+0.000) | MAE baseA=2.829 | n=1
#   phase_randomize | MAE ours=6.346 (Δ=+1.851) | MAE baseA=2.829 | n=1
#   reverse        | MAE ours=5.665 (Δ=+1.171) | MAE baseA=2.829 | n=1
#   win_shuffle    | MAE ours=8.700 (Δ=+4.205) | MAE baseA=2.829 | n=1
# [Fold  8] Test=subject8 | BaseA mean_rate(TRIAL)=0.3535 reps/s
#   block_shuffle  | MAE ours=4.765 (Δ=+0.151) | MAE baseA=5.793 | n=1
#   orig           | MAE ours=4.615 (Δ=+0.000) | MAE baseA=5.793 | n=1
#   phase_randomize | MAE ours=2.865 (Δ=-1.750) | MAE baseA=5.793 | n=1
#   reverse        | MAE ours=5.117 (Δ=+0.502) | MAE baseA=5.793 | n=1
#   win_shuffle    | MAE ours=2.574 (Δ=-2.040) | MAE baseA=5.793 | n=1
# [Fold  9] Test=subject9 | BaseA mean_rate(TRIAL)=0.3670 reps/s
#   block_shuffle  | MAE ours=7.974 (Δ=+0.062) | MAE baseA=0.046 | n=1
#   orig           | MAE ours=7.911 (Δ=+0.000) | MAE baseA=0.046 | n=1
#   phase_randomize | MAE ours=2.406 (Δ=-5.505) | MAE baseA=0.046 | n=1
#   reverse        | MAE ours=7.759 (Δ=-0.152) | MAE baseA=0.046 | n=1
#   win_shuffle    | MAE ours=8.382 (Δ=+0.470) | MAE baseA=0.046 | n=1
# [Fold 10] Test=subject10 | BaseA mean_rate(TRIAL)=0.3625 reps/s
#   block_shuffle  | MAE ours=0.194 (Δ=-0.471) | MAE baseA=2.178 | n=1
#   orig           | MAE ours=0.665 (Δ=+0.000) | MAE baseA=2.178 | n=1
#   phase_randomize | MAE ours=0.823 (Δ=+0.158) | MAE baseA=2.178 | n=1
#   reverse        | MAE ours=0.879 (Δ=+0.214) | MAE baseA=2.178 | n=1
#   win_shuffle    | MAE ours=2.091 (Δ=+1.426) | MAE baseA=2.178 | n=1
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# [Single] Activity: Frontal elevation of arms (id=7)
# --------------------------------------------------------------------------------------------------------------------------------------------
# [Fold  1] Test=subject1 | BaseA mean_rate(TRIAL)=0.3440 reps/s
#   block_shuffle  | MAE ours=0.050 (Δ=+0.032) | MAE baseA=1.134 | n=1
#   orig           | MAE ours=0.018 (Δ=+0.000) | MAE baseA=1.134 | n=1
#   phase_randomize | MAE ours=5.832 (Δ=+5.814) | MAE baseA=1.134 | n=1
#   reverse        | MAE ours=0.037 (Δ=+0.019) | MAE baseA=1.134 | n=1
#   win_shuffle    | MAE ours=1.937 (Δ=+1.919) | MAE baseA=1.134 | n=1
# [Fold  2] Test=subject2 | BaseA mean_rate(TRIAL)=0.3468 reps/s
#   block_shuffle  | MAE ours=1.940 (Δ=-0.698) | MAE baseA=3.081 | n=1
#   orig           | MAE ours=2.638 (Δ=+0.000) | MAE baseA=3.081 | n=1
#   phase_randomize | MAE ours=5.597 (Δ=+2.959) | MAE baseA=3.081 | n=1
#   reverse        | MAE ours=2.931 (Δ=+0.293) | MAE baseA=3.081 | n=1
#   win_shuffle    | MAE ours=1.568 (Δ=-1.069) | MAE baseA=3.081 | n=1
# [Fold  3] Test=subject3 | BaseA mean_rate(TRIAL)=0.3473 reps/s
#   block_shuffle  | MAE ours=4.912 (Δ=+0.454) | MAE baseA=3.468 | n=1
#   orig           | MAE ours=4.458 (Δ=+0.000) | MAE baseA=3.468 | n=1
#   phase_randomize | MAE ours=3.593 (Δ=-0.865) | MAE baseA=3.468 | n=1
#   reverse        | MAE ours=4.866 (Δ=+0.408) | MAE baseA=3.468 | n=1
#   win_shuffle    | MAE ours=1.928 (Δ=-2.530) | MAE baseA=3.468 | n=1
# [Fold  4] Test=subject4 | BaseA mean_rate(TRIAL)=0.3462 reps/s
#   block_shuffle  | MAE ours=1.273 (Δ=+0.202) | MAE baseA=2.693 | n=1
#   orig           | MAE ours=1.071 (Δ=+0.000) | MAE baseA=2.693 | n=1
#   phase_randomize | MAE ours=3.316 (Δ=+2.245) | MAE baseA=2.693 | n=1
#   reverse        | MAE ours=0.804 (Δ=-0.267) | MAE baseA=2.693 | n=1
#   win_shuffle    | MAE ours=2.394 (Δ=+1.323) | MAE baseA=2.693 | n=1
# [Fold  5] Test=subject5 | BaseA mean_rate(TRIAL)=0.3414 reps/s
#   block_shuffle  | MAE ours=1.223 (Δ=-0.110) | MAE baseA=0.417 | n=1
#   orig           | MAE ours=1.332 (Δ=+0.000) | MAE baseA=0.417 | n=1
#   phase_randomize | MAE ours=0.025 (Δ=-1.308) | MAE baseA=0.417 | n=1
#   reverse        | MAE ours=1.778 (Δ=+0.445) | MAE baseA=0.417 | n=1
#   win_shuffle    | MAE ours=0.206 (Δ=-1.126) | MAE baseA=0.417 | n=1
# [Fold  6] Test=subject6 | BaseA mean_rate(TRIAL)=0.3272 reps/s
#   block_shuffle  | MAE ours=6.548 (Δ=-0.207) | MAE baseA=6.264 | n=1
#   orig           | MAE ours=6.754 (Δ=+0.000) | MAE baseA=6.264 | n=1
#   phase_randomize | MAE ours=5.864 (Δ=-0.890) | MAE baseA=6.264 | n=1
#   reverse        | MAE ours=6.882 (Δ=+0.128) | MAE baseA=6.264 | n=1
#   win_shuffle    | MAE ours=7.277 (Δ=+0.523) | MAE baseA=6.264 | n=1
# [Fold  7] Test=subject7 | BaseA mean_rate(TRIAL)=0.3400 reps/s
#   block_shuffle  | MAE ours=0.278 (Δ=-0.276) | MAE baseA=1.200 | n=1
#   orig           | MAE ours=0.555 (Δ=+0.000) | MAE baseA=1.200 | n=1
#   phase_randomize | MAE ours=0.683 (Δ=+0.129) | MAE baseA=1.200 | n=1
#   reverse        | MAE ours=0.356 (Δ=-0.198) | MAE baseA=1.200 | n=1
#   win_shuffle    | MAE ours=0.650 (Δ=+0.096) | MAE baseA=1.200 | n=1
# [Fold  8] Test=subject8 | BaseA mean_rate(TRIAL)=0.3452 reps/s
#   block_shuffle  | MAE ours=3.313 (Δ=-0.069) | MAE baseA=1.858 | n=1
#   orig           | MAE ours=3.382 (Δ=+0.000) | MAE baseA=1.858 | n=1
#   phase_randomize | MAE ours=2.238 (Δ=-1.144) | MAE baseA=1.858 | n=1
#   reverse        | MAE ours=3.498 (Δ=+0.116) | MAE baseA=1.858 | n=1
#   win_shuffle    | MAE ours=0.743 (Δ=-2.639) | MAE baseA=1.858 | n=1
# [Fold  9] Test=subject9 | BaseA mean_rate(TRIAL)=0.3433 reps/s
#   block_shuffle  | MAE ours=0.865 (Δ=-0.065) | MAE baseA=0.687 | n=1
#   orig           | MAE ours=0.930 (Δ=+0.000) | MAE baseA=0.687 | n=1
#   phase_randomize | MAE ours=1.741 (Δ=+0.811) | MAE baseA=0.687 | n=1
#   reverse        | MAE ours=1.342 (Δ=+0.412) | MAE baseA=0.687 | n=1
#   win_shuffle    | MAE ours=0.132 (Δ=-0.798) | MAE baseA=0.687 | n=1
# [Fold 10] Test=subject10 | BaseA mean_rate(TRIAL)=0.3400 reps/s
#   block_shuffle  | MAE ours=1.463 (Δ=+0.093) | MAE baseA=1.200 | n=1
#   orig           | MAE ours=1.370 (Δ=+0.000) | MAE baseA=1.200 | n=1
#   phase_randomize | MAE ours=0.235 (Δ=-1.135) | MAE baseA=1.200 | n=1
#   reverse        | MAE ours=1.374 (Δ=+0.004) | MAE baseA=1.200 | n=1
#   win_shuffle    | MAE ours=1.557 (Δ=+0.186) | MAE baseA=1.200 | n=1
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# [Single] Activity: Knees bending (id=8)
# --------------------------------------------------------------------------------------------------------------------------------------------
# [Fold  1] Test=subject1 | BaseA mean_rate(TRIAL)=0.3607 reps/s
#   block_shuffle  | MAE ours=12.999 (Δ=-0.598) | MAE baseA=4.377 | n=1
#   orig           | MAE ours=13.597 (Δ=+0.000) | MAE baseA=4.377 | n=1
#   phase_randomize | MAE ours=4.438 (Δ=-9.160) | MAE baseA=4.377 | n=1
#   reverse        | MAE ours=14.305 (Δ=+0.708) | MAE baseA=4.377 | n=1
#   win_shuffle    | MAE ours=8.610 (Δ=-4.988) | MAE baseA=4.377 | n=1
# [Fold  2] Test=subject2 | BaseA mean_rate(TRIAL)=0.3596 reps/s
#   block_shuffle  | MAE ours=1.032 (Δ=-0.070) | MAE baseA=3.667 | n=1
#   orig           | MAE ours=1.102 (Δ=+0.000) | MAE baseA=3.667 | n=1
#   phase_randomize | MAE ours=7.584 (Δ=+6.481) | MAE baseA=3.667 | n=1
#   reverse        | MAE ours=1.053 (Δ=-0.049) | MAE baseA=3.667 | n=1
#   win_shuffle    | MAE ours=2.911 (Δ=+1.808) | MAE baseA=3.667 | n=1
# [Fold  3] Test=subject3 | BaseA mean_rate(TRIAL)=0.3569 reps/s
#   block_shuffle  | MAE ours=4.770 (Δ=-0.612) | MAE baseA=1.660 | n=1
#   orig           | MAE ours=5.382 (Δ=+0.000) | MAE baseA=1.660 | n=1
#   phase_randomize | MAE ours=2.964 (Δ=-2.418) | MAE baseA=1.660 | n=1
#   reverse        | MAE ours=4.464 (Δ=-0.918) | MAE baseA=1.660 | n=1
#   win_shuffle    | MAE ours=2.405 (Δ=-2.977) | MAE baseA=1.660 | n=1
# [Fold  4] Test=subject4 | BaseA mean_rate(TRIAL)=0.3598 reps/s
#   block_shuffle  | MAE ours=6.229 (Δ=+0.034) | MAE baseA=3.473 | n=1
#   orig           | MAE ours=6.195 (Δ=+0.000) | MAE baseA=3.473 | n=1
#   phase_randomize | MAE ours=2.934 (Δ=-3.262) | MAE baseA=3.473 | n=1
#   reverse        | MAE ours=6.111 (Δ=-0.084) | MAE baseA=3.473 | n=1
#   win_shuffle    | MAE ours=0.565 (Δ=-5.631) | MAE baseA=3.473 | n=1
# [Fold  5] Test=subject5 | BaseA mean_rate(TRIAL)=0.3527 reps/s
#   block_shuffle  | MAE ours=2.272 (Δ=-0.117) | MAE baseA=0.858 | n=1
#   orig           | MAE ours=2.389 (Δ=+0.000) | MAE baseA=0.858 | n=1
#   phase_randomize | MAE ours=0.614 (Δ=-1.775) | MAE baseA=0.858 | n=1
#   reverse        | MAE ours=2.551 (Δ=+0.162) | MAE baseA=0.858 | n=1
#   win_shuffle    | MAE ours=1.793 (Δ=-0.596) | MAE baseA=0.858 | n=1
# [Fold  6] Test=subject6 | BaseA mean_rate(TRIAL)=0.3454 reps/s
#   block_shuffle  | MAE ours=4.921 (Δ=+0.347) | MAE baseA=4.085 | n=1
#   orig           | MAE ours=4.574 (Δ=+0.000) | MAE baseA=4.085 | n=1
#   phase_randomize | MAE ours=4.987 (Δ=+0.412) | MAE baseA=4.085 | n=1
#   reverse        | MAE ours=4.783 (Δ=+0.208) | MAE baseA=4.085 | n=1
#   win_shuffle    | MAE ours=5.071 (Δ=+0.496) | MAE baseA=4.085 | n=1
# [Fold  7] Test=subject7 | BaseA mean_rate(TRIAL)=0.3522 reps/s
#   block_shuffle  | MAE ours=1.899 (Δ=-0.656) | MAE baseA=1.166 | n=1
#   orig           | MAE ours=2.555 (Δ=+0.000) | MAE baseA=1.166 | n=1
#   phase_randomize | MAE ours=1.515 (Δ=-1.040) | MAE baseA=1.166 | n=1
#   reverse        | MAE ours=3.420 (Δ=+0.864) | MAE baseA=1.166 | n=1
#   win_shuffle    | MAE ours=1.906 (Δ=-0.649) | MAE baseA=1.166 | n=1
# [Fold  8] Test=subject8 | BaseA mean_rate(TRIAL)=0.3480 reps/s
#   block_shuffle  | MAE ours=1.925 (Δ=-1.333) | MAE baseA=3.181 | n=1
#   orig           | MAE ours=3.257 (Δ=+0.000) | MAE baseA=3.181 | n=1
#   phase_randomize | MAE ours=4.046 (Δ=+0.789) | MAE baseA=3.181 | n=1
#   reverse        | MAE ours=5.495 (Δ=+2.237) | MAE baseA=3.181 | n=1
#   win_shuffle    | MAE ours=5.910 (Δ=+2.653) | MAE baseA=3.181 | n=1
# [Fold  9] Test=subject9 | BaseA mean_rate(TRIAL)=0.3543 reps/s
#   block_shuffle  | MAE ours=4.038 (Δ=-0.251) | MAE baseA=0.038 | n=1
#   orig           | MAE ours=4.289 (Δ=+0.000) | MAE baseA=0.038 | n=1
#   phase_randomize | MAE ours=3.327 (Δ=-0.963) | MAE baseA=0.038 | n=1
#   reverse        | MAE ours=4.488 (Δ=+0.199) | MAE baseA=0.038 | n=1
#   win_shuffle    | MAE ours=0.216 (Δ=-4.074) | MAE baseA=0.038 | n=1
# [Fold 10] Test=subject10 | BaseA mean_rate(TRIAL)=0.3529 reps/s
#   block_shuffle  | MAE ours=2.556 (Δ=+0.032) | MAE baseA=0.764 | n=1
#   orig           | MAE ours=2.524 (Δ=+0.000) | MAE baseA=0.764 | n=1
#   phase_randomize | MAE ours=0.964 (Δ=-1.560) | MAE baseA=0.764 | n=1
#   reverse        | MAE ours=3.456 (Δ=+0.932) | MAE baseA=0.764 | n=1
#   win_shuffle    | MAE ours=1.396 (Δ=-1.128) | MAE baseA=0.764 | n=1
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# [Single] Activity: Jump front & back (id=12)
# --------------------------------------------------------------------------------------------------------------------------------------------
# [Fold  1] Test=subject1 | BaseA mean_rate(TRIAL)=0.9931 reps/s
#   block_shuffle  | MAE ours=0.837 (Δ=-0.172) | MAE baseA=1.352 | n=1
#   orig           | MAE ours=1.008 (Δ=+0.000) | MAE baseA=1.352 | n=1
#   phase_randomize | MAE ours=2.224 (Δ=+1.216) | MAE baseA=1.352 | n=1
#   reverse        | MAE ours=0.393 (Δ=-0.616) | MAE baseA=1.352 | n=1
#   win_shuffle    | MAE ours=3.306 (Δ=+2.298) | MAE baseA=1.352 | n=1
# [Fold  2] Test=subject2 | BaseA mean_rate(TRIAL)=0.9771 reps/s
#   block_shuffle  | MAE ours=1.416 (Δ=+1.027) | MAE baseA=1.989 | n=1
#   orig           | MAE ours=0.389 (Δ=+0.000) | MAE baseA=1.989 | n=1
#   phase_randomize | MAE ours=0.602 (Δ=+0.213) | MAE baseA=1.989 | n=1
#   reverse        | MAE ours=0.939 (Δ=+0.551) | MAE baseA=1.989 | n=1
#   win_shuffle    | MAE ours=0.809 (Δ=+0.420) | MAE baseA=1.989 | n=1
# [Fold  3] Test=subject3 | BaseA mean_rate(TRIAL)=0.9825 reps/s
#   block_shuffle  | MAE ours=1.233 (Δ=+0.395) | MAE baseA=0.878 | n=1
#   orig           | MAE ours=0.838 (Δ=+0.000) | MAE baseA=0.878 | n=1
#   phase_randomize | MAE ours=0.395 (Δ=-0.444) | MAE baseA=0.878 | n=1
#   reverse        | MAE ours=4.095 (Δ=+3.257) | MAE baseA=0.878 | n=1
#   win_shuffle    | MAE ours=0.461 (Δ=-0.377) | MAE baseA=0.878 | n=1
# [Fold  4] Test=subject4 | BaseA mean_rate(TRIAL)=0.9825 reps/s
#   block_shuffle  | MAE ours=2.089 (Δ=+0.011) | MAE baseA=0.878 | n=1
#   orig           | MAE ours=2.078 (Δ=+0.000) | MAE baseA=0.878 | n=1
#   phase_randomize | MAE ours=0.895 (Δ=-1.183) | MAE baseA=0.878 | n=1
#   reverse        | MAE ours=0.046 (Δ=-2.032) | MAE baseA=0.878 | n=1
#   win_shuffle    | MAE ours=2.836 (Δ=+0.758) | MAE baseA=0.878 | n=1
# [Fold  5] Test=subject5 | BaseA mean_rate(TRIAL)=0.9880 reps/s
#   block_shuffle  | MAE ours=2.968 (Δ=-0.545) | MAE baseA=0.234 | n=1
#   orig           | MAE ours=3.513 (Δ=+0.000) | MAE baseA=0.234 | n=1
#   phase_randomize | MAE ours=2.732 (Δ=-0.781) | MAE baseA=0.234 | n=1
#   reverse        | MAE ours=4.743 (Δ=+1.230) | MAE baseA=0.234 | n=1
#   win_shuffle    | MAE ours=0.128 (Δ=-3.385) | MAE baseA=0.234 | n=1
# [Fold  6] Test=subject6 | BaseA mean_rate(TRIAL)=0.9825 reps/s
#   block_shuffle  | MAE ours=0.712 (Δ=+0.027) | MAE baseA=0.878 | n=1
#   orig           | MAE ours=0.685 (Δ=+0.000) | MAE baseA=0.878 | n=1
#   phase_randomize | MAE ours=1.801 (Δ=+1.115) | MAE baseA=0.878 | n=1
#   reverse        | MAE ours=2.675 (Δ=+1.989) | MAE baseA=0.878 | n=1
#   win_shuffle    | MAE ours=0.009 (Δ=-0.677) | MAE baseA=0.878 | n=1
# [Fold  7] Test=subject7 | BaseA mean_rate(TRIAL)=0.9934 reps/s
#   block_shuffle  | MAE ours=0.473 (Δ=+0.410) | MAE baseA=1.345 | n=1
#   orig           | MAE ours=0.063 (Δ=+0.000) | MAE baseA=1.345 | n=1
#   phase_randomize | MAE ours=3.135 (Δ=+3.072) | MAE baseA=1.345 | n=1
#   reverse        | MAE ours=1.396 (Δ=+1.333) | MAE baseA=1.345 | n=1
#   win_shuffle    | MAE ours=1.656 (Δ=+1.593) | MAE baseA=1.345 | n=1
# [Fold  8] Test=subject8 | BaseA mean_rate(TRIAL)=0.9880 reps/s
#   block_shuffle  | MAE ours=0.385 (Δ=+0.265) | MAE baseA=0.234 | n=1
#   orig           | MAE ours=0.120 (Δ=+0.000) | MAE baseA=0.234 | n=1
#   phase_randomize | MAE ours=2.930 (Δ=+2.810) | MAE baseA=0.234 | n=1
#   reverse        | MAE ours=0.905 (Δ=+0.784) | MAE baseA=0.234 | n=1
#   win_shuffle    | MAE ours=3.005 (Δ=+2.885) | MAE baseA=0.234 | n=1
# [Fold  9] Test=subject9 | BaseA mean_rate(TRIAL)=0.9931 reps/s
#   block_shuffle  | MAE ours=0.255 (Δ=-0.593) | MAE baseA=1.352 | n=1
#   orig           | MAE ours=0.848 (Δ=+0.000) | MAE baseA=1.352 | n=1
#   phase_randomize | MAE ours=1.172 (Δ=+0.325) | MAE baseA=1.352 | n=1
#   reverse        | MAE ours=3.331 (Δ=+2.483) | MAE baseA=1.352 | n=1
#   win_shuffle    | MAE ours=0.424 (Δ=-0.424) | MAE baseA=1.352 | n=1
# [Fold 10] Test=subject10 | BaseA mean_rate(TRIAL)=0.9880 reps/s
#   block_shuffle  | MAE ours=1.397 (Δ=-0.464) | MAE baseA=0.234 | n=1
#   orig           | MAE ours=1.861 (Δ=+0.000) | MAE baseA=0.234 | n=1
#   phase_randomize | MAE ours=1.507 (Δ=-0.353) | MAE baseA=0.234 | n=1
#   reverse        | MAE ours=1.112 (Δ=-0.749) | MAE baseA=0.234 | n=1
#   win_shuffle    | MAE ours=0.460 (Δ=-1.401) | MAE baseA=0.234 | n=1
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# [Single] Activity: Jogging (id=10)
# --------------------------------------------------------------------------------------------------------------------------------------------
# [Fold  1] Test=subject1 | BaseA mean_rate(TRIAL)=2.5680 reps/s
#   block_shuffle  | MAE ours=5.826 (Δ=+3.637) | MAE baseA=0.778 | n=1
#   orig           | MAE ours=2.188 (Δ=+0.000) | MAE baseA=0.778 | n=1
#   phase_randomize | MAE ours=7.918 (Δ=+5.730) | MAE baseA=0.778 | n=1
#   reverse        | MAE ours=2.732 (Δ=+0.543) | MAE baseA=0.778 | n=1
#   win_shuffle    | MAE ours=5.574 (Δ=+3.385) | MAE baseA=0.778 | n=1
# [Fold  2] Test=subject2 | BaseA mean_rate(TRIAL)=2.5608 reps/s
#   block_shuffle  | MAE ours=10.494 (Δ=+5.507) | MAE baseA=3.667 | n=1
#   orig           | MAE ours=4.987 (Δ=+0.000) | MAE baseA=3.667 | n=1
#   phase_randomize | MAE ours=10.668 (Δ=+5.681) | MAE baseA=3.667 | n=1
#   reverse        | MAE ours=28.905 (Δ=+23.919) | MAE baseA=3.667 | n=1
#   win_shuffle    | MAE ours=31.925 (Δ=+26.938) | MAE baseA=3.667 | n=1
# [Fold  3] Test=subject3 | BaseA mean_rate(TRIAL)=2.5734 reps/s
#   block_shuffle  | MAE ours=5.087 (Δ=-0.149) | MAE baseA=4.111 | n=1
#   orig           | MAE ours=5.236 (Δ=+0.000) | MAE baseA=4.111 | n=1
#   phase_randomize | MAE ours=5.047 (Δ=-0.189) | MAE baseA=4.111 | n=1
#   reverse        | MAE ours=6.622 (Δ=+1.385) | MAE baseA=4.111 | n=1
#   win_shuffle    | MAE ours=1.974 (Δ=-3.262) | MAE baseA=4.111 | n=1
# [Fold  4] Test=subject4 | BaseA mean_rate(TRIAL)=2.5734 reps/s
#   block_shuffle  | MAE ours=4.369 (Δ=+0.618) | MAE baseA=4.111 | n=1
#   orig           | MAE ours=3.751 (Δ=+0.000) | MAE baseA=4.111 | n=1
#   phase_randomize | MAE ours=21.457 (Δ=+17.706) | MAE baseA=4.111 | n=1
#   reverse        | MAE ours=0.042 (Δ=-3.708) | MAE baseA=4.111 | n=1
#   win_shuffle    | MAE ours=2.796 (Δ=-0.955) | MAE baseA=4.111 | n=1
# [Fold  5] Test=subject5 | BaseA mean_rate(TRIAL)=2.5626 reps/s
#   block_shuffle  | MAE ours=2.502 (Δ=+0.903) | MAE baseA=2.556 | n=1
#   orig           | MAE ours=1.599 (Δ=+0.000) | MAE baseA=2.556 | n=1
#   phase_randomize | MAE ours=16.076 (Δ=+14.477) | MAE baseA=2.556 | n=1
#   reverse        | MAE ours=9.216 (Δ=+7.617) | MAE baseA=2.556 | n=1
#   win_shuffle    | MAE ours=1.000 (Δ=-0.599) | MAE baseA=2.556 | n=1
# [Fold  6] Test=subject6 | BaseA mean_rate(TRIAL)=2.5698 reps/s
#   block_shuffle  | MAE ours=37.569 (Δ=-0.325) | MAE baseA=1.889 | n=1
#   orig           | MAE ours=37.894 (Δ=+0.000) | MAE baseA=1.889 | n=1
#   phase_randomize | MAE ours=16.607 (Δ=-21.287) | MAE baseA=1.889 | n=1
#   reverse        | MAE ours=8.389 (Δ=-29.506) | MAE baseA=1.889 | n=1
#   win_shuffle    | MAE ours=29.039 (Δ=-8.855) | MAE baseA=1.889 | n=1
# [Fold  7] Test=subject7 | BaseA mean_rate(TRIAL)=2.5752 reps/s
#   block_shuffle  | MAE ours=9.267 (Δ=-0.170) | MAE baseA=5.222 | n=1
#   orig           | MAE ours=9.437 (Δ=+0.000) | MAE baseA=5.222 | n=1
#   phase_randomize | MAE ours=13.210 (Δ=+3.773) | MAE baseA=5.222 | n=1
#   reverse        | MAE ours=5.656 (Δ=-3.781) | MAE baseA=5.222 | n=1
#   win_shuffle    | MAE ours=3.262 (Δ=-6.175) | MAE baseA=5.222 | n=1
# [Fold  8] Test=subject8 | BaseA mean_rate(TRIAL)=2.5626 reps/s
#   block_shuffle  | MAE ours=14.257 (Δ=-0.047) | MAE baseA=2.556 | n=1
#   orig           | MAE ours=14.304 (Δ=+0.000) | MAE baseA=2.556 | n=1
#   phase_randomize | MAE ours=6.846 (Δ=-7.458) | MAE baseA=2.556 | n=1
#   reverse        | MAE ours=16.283 (Δ=+1.979) | MAE baseA=2.556 | n=1
#   win_shuffle    | MAE ours=4.921 (Δ=-9.384) | MAE baseA=2.556 | n=1
# [Fold  9] Test=subject9 | BaseA mean_rate(TRIAL)=2.5517 reps/s
#   block_shuffle  | MAE ours=5.083 (Δ=-0.981) | MAE baseA=9.222 | n=1
#   orig           | MAE ours=6.064 (Δ=+0.000) | MAE baseA=9.222 | n=1
#   phase_randomize | MAE ours=3.189 (Δ=-2.875) | MAE baseA=9.222 | n=1
#   reverse        | MAE ours=4.632 (Δ=-1.432) | MAE baseA=9.222 | n=1
#   win_shuffle    | MAE ours=3.843 (Δ=-2.221) | MAE baseA=9.222 | n=1
# [Fold 10] Test=subject10 | BaseA mean_rate(TRIAL)=2.5698 reps/s
#   block_shuffle  | MAE ours=5.724 (Δ=-1.325) | MAE baseA=1.889 | n=1
#   orig           | MAE ours=7.049 (Δ=+0.000) | MAE baseA=1.889 | n=1
#   phase_randomize | MAE ours=24.441 (Δ=+17.392) | MAE baseA=1.889 | n=1
#   reverse        | MAE ours=4.177 (Δ=-2.873) | MAE baseA=1.889 | n=1
#   win_shuffle    | MAE ours=5.062 (Δ=-1.988) | MAE baseA=1.889 | n=1
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# [Single] Activity: Running (id=11)
# --------------------------------------------------------------------------------------------------------------------------------------------
# [Fold  1] Test=subject1 | BaseA mean_rate(TRIAL)=2.6855 reps/s
#   block_shuffle  | MAE ours=1.012 (Δ=-0.577) | MAE baseA=0.000 | n=1
#   orig           | MAE ours=1.589 (Δ=+0.000) | MAE baseA=0.000 | n=1
#   phase_randomize | MAE ours=20.481 (Δ=+18.891) | MAE baseA=0.000 | n=1
#   reverse        | MAE ours=3.087 (Δ=+1.498) | MAE baseA=0.000 | n=1
#   win_shuffle    | MAE ours=37.593 (Δ=+36.004) | MAE baseA=0.000 | n=1
# [Fold  2] Test=subject2 | BaseA mean_rate(TRIAL)=2.6982 reps/s
#   block_shuffle  | MAE ours=16.934 (Δ=+3.188) | MAE baseA=7.778 | n=1
#   orig           | MAE ours=13.746 (Δ=+0.000) | MAE baseA=7.778 | n=1
#   phase_randomize | MAE ours=16.975 (Δ=+3.229) | MAE baseA=7.778 | n=1
#   reverse        | MAE ours=15.045 (Δ=+1.299) | MAE baseA=7.778 | n=1
#   win_shuffle    | MAE ours=35.854 (Δ=+22.108) | MAE baseA=7.778 | n=1
# [Fold  3] Test=subject3 | BaseA mean_rate(TRIAL)=2.6693 reps/s
#   block_shuffle  | MAE ours=19.579 (Δ=-2.222) | MAE baseA=10.000 | n=1
#   orig           | MAE ours=21.801 (Δ=+0.000) | MAE baseA=10.000 | n=1
#   phase_randomize | MAE ours=11.848 (Δ=-9.953) | MAE baseA=10.000 | n=1
#   reverse        | MAE ours=4.555 (Δ=-17.246) | MAE baseA=10.000 | n=1
#   win_shuffle    | MAE ours=1.375 (Δ=-20.426) | MAE baseA=10.000 | n=1
# [Fold  4] Test=subject4 | BaseA mean_rate(TRIAL)=2.6892 reps/s
#   block_shuffle  | MAE ours=20.112 (Δ=+2.278) | MAE baseA=2.222 | n=1
#   orig           | MAE ours=17.834 (Δ=+0.000) | MAE baseA=2.222 | n=1
#   phase_randomize | MAE ours=25.052 (Δ=+7.217) | MAE baseA=2.222 | n=1
#   reverse        | MAE ours=7.145 (Δ=-10.689) | MAE baseA=2.222 | n=1
#   win_shuffle    | MAE ours=27.982 (Δ=+10.148) | MAE baseA=2.222 | n=1
# [Fold  5] Test=subject5 | BaseA mean_rate(TRIAL)=2.7000 reps/s
#   block_shuffle  | MAE ours=4.028 (Δ=+2.721) | MAE baseA=8.889 | n=1
#   orig           | MAE ours=1.306 (Δ=+0.000) | MAE baseA=8.889 | n=1
#   phase_randomize | MAE ours=20.205 (Δ=+18.899) | MAE baseA=8.889 | n=1
#   reverse        | MAE ours=19.461 (Δ=+18.155) | MAE baseA=8.889 | n=1
#   win_shuffle    | MAE ours=39.451 (Δ=+38.145) | MAE baseA=8.889 | n=1
# [Fold  6] Test=subject6 | BaseA mean_rate(TRIAL)=2.6729 reps/s
#   block_shuffle  | MAE ours=23.930 (Δ=-1.053) | MAE baseA=7.778 | n=1
#   orig           | MAE ours=24.983 (Δ=+0.000) | MAE baseA=7.778 | n=1
#   phase_randomize | MAE ours=7.984 (Δ=-16.999) | MAE baseA=7.778 | n=1
#   reverse        | MAE ours=25.903 (Δ=+0.920) | MAE baseA=7.778 | n=1
#   win_shuffle    | MAE ours=0.576 (Δ=-24.406) | MAE baseA=7.778 | n=1
# [Fold  7] Test=subject7 | BaseA mean_rate(TRIAL)=2.7145 reps/s
#   block_shuffle  | MAE ours=20.985 (Δ=+2.775) | MAE baseA=17.778 | n=1
#   orig           | MAE ours=18.210 (Δ=+0.000) | MAE baseA=17.778 | n=1
#   phase_randomize | MAE ours=26.645 (Δ=+8.435) | MAE baseA=17.778 | n=1
#   reverse        | MAE ours=24.386 (Δ=+6.176) | MAE baseA=17.778 | n=1
#   win_shuffle    | MAE ours=48.102 (Δ=+29.893) | MAE baseA=17.778 | n=1
# [Fold  8] Test=subject8 | BaseA mean_rate(TRIAL)=2.6837 reps/s
#   block_shuffle  | MAE ours=5.354 (Δ=-3.549) | MAE baseA=1.111 | n=1
#   orig           | MAE ours=8.902 (Δ=+0.000) | MAE baseA=1.111 | n=1
#   phase_randomize | MAE ours=1.450 (Δ=-7.452) | MAE baseA=1.111 | n=1
#   reverse        | MAE ours=11.533 (Δ=+2.630) | MAE baseA=1.111 | n=1
#   win_shuffle    | MAE ours=21.209 (Δ=+12.307) | MAE baseA=1.111 | n=1
# [Fold  9] Test=subject9 | BaseA mean_rate(TRIAL)=2.6693 reps/s
#   block_shuffle  | MAE ours=18.049 (Δ=+0.911) | MAE baseA=10.000 | n=1
#   orig           | MAE ours=17.138 (Δ=+0.000) | MAE baseA=10.000 | n=1
#   phase_randomize | MAE ours=30.245 (Δ=+13.107) | MAE baseA=10.000 | n=1
#   reverse        | MAE ours=8.378 (Δ=-8.760) | MAE baseA=10.000 | n=1
#   win_shuffle    | MAE ours=27.025 (Δ=+9.887) | MAE baseA=10.000 | n=1
# [Fold 10] Test=subject10 | BaseA mean_rate(TRIAL)=2.6729 reps/s
#   block_shuffle  | MAE ours=18.503 (Δ=-2.998) | MAE baseA=7.778 | n=1
#   orig           | MAE ours=21.501 (Δ=+0.000) | MAE baseA=7.778 | n=1
#   phase_randomize | MAE ours=3.407 (Δ=-18.094) | MAE baseA=7.778 | n=1
#   reverse        | MAE ours=8.023 (Δ=-13.478) | MAE baseA=7.778 | n=1
#   win_shuffle    | MAE ours=17.880 (Δ=-3.621) | MAE baseA=7.778 | n=1
#
# ============================================================================================================================================
# [OVERALL SUMMARY]  (Δ = MAE(mode) - MAE(orig))
#            mode  n  MAE_ours  MAE_baseA  entropy     effK    k_hat  baseA_rate_trial  dMAE_vs_orig
#   block_shuffle 60  6.245428   3.229856 0.333780 1.500757 1.500758          1.217073      0.107992
#            orig 60  6.137436   3.229856 0.333627 1.507193 1.507194          1.217073      0.000000
# phase_randomize 60  7.281895   3.229856 0.350380 1.426110 1.426111          1.217073      1.144459
#         reverse 60  5.955805   3.229856 0.348675 1.511962 1.511963          1.217073     -0.181631
#     win_shuffle 60  7.914681   3.229856 0.330863 1.382241 1.382241          1.217073      1.777245
#
# ============================================================================================================================================
# [PER-ACTIVITY SUMMARY]  (Δ = MAE(mode) - MAE(orig within activity))
#  act_id                  act_name            mode  n  MAE_ours  MAE_baseA  entropy     effK    k_hat  baseA_rate_trial  dMAE_vs_orig
#       6       Waist bends forward   block_shuffle 10  4.978921   2.981647 0.089790 1.042661 1.042665          0.366960      0.084198
#       6       Waist bends forward            orig 10  4.894723   2.981647 0.091007 1.043673 1.043676          0.366960      0.000000
#       6       Waist bends forward phase_randomize 10  6.727323   2.981647 0.091858 1.043253 1.043256          0.366960      1.832600
#       6       Waist bends forward         reverse 10  4.955011   2.981647 0.083920 1.038624 1.038628          0.366960      0.060288
#       6       Waist bends forward     win_shuffle 10  6.616964   2.981647 0.076716 1.035169 1.035171          0.366960      1.722241
#       7 Frontal elevation of arms   block_shuffle 10  2.186466   2.200025 0.100428 1.063169 1.063170          0.342135     -0.064264
#       7 Frontal elevation of arms            orig 10  2.250730   2.200025 0.101088 1.066225 1.066227          0.342135      0.000000
#       7 Frontal elevation of arms phase_randomize 10  2.912453   2.200025 0.096047 1.045661 1.045662          0.342135      0.661722
#       7 Frontal elevation of arms         reverse 10  2.386707   2.200025 0.101859 1.066173 1.066174          0.342135      0.135976
#       7 Frontal elevation of arms     win_shuffle 10  1.839143   2.200025 0.079448 1.035075 1.035076          0.342135     -0.411587
#       8             Knees bending   block_shuffle 10  4.264200   2.327064 0.176878 1.173302 1.173305          0.354238     -0.322461
#       8             Knees bending            orig 10  4.586662   2.327064 0.175059 1.172010 1.172013          0.354238      0.000000
#       8             Knees bending phase_randomize 10  3.337135   2.327064 0.236395 1.211470 1.211470          0.354238     -1.249527
#       8             Knees bending         reverse 10  5.012638   2.327064 0.175220 1.172895 1.172897          0.354238      0.425976
#       8             Knees bending     win_shuffle 10  3.078080   2.327064 0.224784 1.193037 1.193036          0.354238     -1.508582
#      10                   Jogging   block_shuffle 10 10.017920   3.600000 0.403484 1.546315 1.546316          2.566732      0.766941
#      10                   Jogging            orig 10  9.250979   3.600000 0.402768 1.551753 1.551753          2.566732      0.000000
#      10                   Jogging phase_randomize 10 12.545957   3.600000 0.417409 1.427028 1.427030          2.566732      3.294978
#      10                   Jogging         reverse 10  8.665303   3.600000 0.435512 1.505792 1.505791          2.566732     -0.585676
#      10                   Jogging     win_shuffle 10  8.939610   3.600000 0.393222 1.349152 1.349152          2.566732     -0.311369
#      11                   Running   block_shuffle 10 14.848506   7.333333 0.334350 1.546291 1.546291          2.685547      0.147366
#      11                   Running            orig 10 14.701140   7.333333 0.333735 1.564268 1.564269          2.685547      0.000000
#      11                   Running phase_randomize 10 16.429135   7.333333 0.337221 1.385158 1.385158          2.685547      1.727995
#      11                   Running         reverse 10 12.751743   7.333333 0.377118 1.531128 1.531129          2.685547     -1.949396
#      11                   Running     win_shuffle 10 25.704992   7.333333 0.310358 1.322892 1.322893          2.685547     11.003853
#      12         Jump front & back   block_shuffle 10  1.176555   0.937066 0.897749 2.632802 2.632802          0.986828      0.036173
#      12         Jump front & back            orig 10  1.140382   0.937066 0.898104 2.645226 2.645226          0.986828      0.000000
#      12         Jump front & back phase_randomize 10  1.739367   0.937066 0.923348 2.444091 2.444090          0.986828      0.598985
#      12         Jump front & back         reverse 10  1.963428   0.937066 0.918424 2.757159 2.757159          0.986828      0.823046
#      12         Jump front & back     win_shuffle 10  1.309296   0.937066 0.900648 2.358120 2.358121          0.986828      0.168914
# ============================================================================================================================================

# %%
# =========================
# ✅ SINGLE-ACTIVITY LOSO ONLY (CSV 저장 X) — OURS + Baseline-E2 only
#
# - Activity loop
# - For each activity and each fold:
#   - Train OURS on that activity from 9 subjects (windows)
#   - Test on held-out subject (full trial)
#
# Integrator-defense modes:
#   orig / reverse / win_shuffle / block_shuffle / phase_randomize
#
# ✅ Baseline-E2 (ACT-ONLY + TRIAL-BASED; "textbook integrator" flavor)
#   - Full-trial energy integral on RAW (non-zscored) after DC removal:
#       E = (1/fs) * sum_t sum_c x_dc(t,c)^2
#   - Linear calibration with beta=0:
#       count ≈ alpha * E
#   - Uses RAW signal (transformed per mode for consistency)
# =========================

import os
import glob
import random
import zlib
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader


# ---------------------------------------------------------------------
# 1) Strict Seeding
# ---------------------------------------------------------------------
def set_strict_seed(seed: int):
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


# ---------------------------------------------------------------------
# 2) Stable RNG helpers
# ---------------------------------------------------------------------
def _stable_seed_from_text(text: str, base_seed: int = 0) -> int:
    h = zlib.adler32(text.encode("utf-8"))
    return int((base_seed + h) % (2**31 - 1))


# ---------------------------------------------------------------------
# 3) Transformations (integrator-defense modes)
# ---------------------------------------------------------------------
def transform_reverse(x_np: np.ndarray) -> np.ndarray:
    return x_np[::-1].copy()


def transform_block_shuffle(x_np: np.ndarray, block_len: int, rng: np.random.RandomState) -> np.ndarray:
    """
    Split time into blocks, shuffle block order (keeps within-block local structure).
    x_np: (T,C)
    """
    x = np.asarray(x_np, dtype=np.float32)
    T, C = x.shape
    if block_len <= 1 or T <= block_len:
        return x.copy()

    n_blocks = int(np.ceil(T / block_len))
    blocks = []
    for bi in range(n_blocks):
        st = bi * block_len
        ed = min((bi + 1) * block_len, T)
        blocks.append(x[st:ed])

    perm = rng.permutation(len(blocks))
    out = np.concatenate([blocks[i] for i in perm], axis=0)

    if out.shape[0] != T:
        out = out[:T]
    return out.astype(np.float32, copy=False)


def transform_phase_randomize(x_np: np.ndarray, rng: np.random.RandomState) -> np.ndarray:
    """
    Phase randomization per channel:
    - preserve FFT magnitude
    - randomize phase (except DC & Nyquist), reconstruct real signal
    """
    x = np.asarray(x_np, dtype=np.float32)
    T, C = x.shape
    out = np.zeros_like(x)

    for c in range(C):
        sig = x[:, c].astype(np.float64)

        X = np.fft.rfft(sig)
        mag = np.abs(X)
        phase = np.angle(X)
        n = len(X)

        if n <= 2:
            rec = np.fft.irfft(X, n=T)
            out[:, c] = rec.astype(np.float32)
            continue

        rand_phase = rng.uniform(-np.pi, np.pi, size=n)
        rand_phase[0] = phase[0]
        rand_phase[-1] = phase[-1]

        newX = mag * (np.cos(rand_phase) + 1j * np.sin(rand_phase))
        rec = np.fft.irfft(newX, n=T)
        out[:, c] = rec.astype(np.float32)

    return out


# ---------------------------------------------------------------------
# 4) Data Loading
# ---------------------------------------------------------------------
def load_mhealth_dataset(data_dir, target_activities_map, column_names):
    full_dataset = {}
    file_list = sorted(glob.glob(os.path.join(data_dir, "mHealth_subject*.log")))

    if not file_list:
        print(f"[Warning] No mHealth logs found in {data_dir}")
        return {}

    print(f"Loading {len(file_list)} subjects from {data_dir}...")

    for file_path in file_list:
        file_name = os.path.basename(file_path)
        subj_part = file_name.split('.')[0]
        try:
            subj_id_num = int(''.join(filter(str.isdigit, subj_part)))
            subj_key = f"subject{subj_id_num}"
        except:
            subj_key = subj_part

        try:
            df = pd.read_csv(file_path, sep="\t", header=None)
            df = df.iloc[:, :len(column_names)]
            df.columns = column_names

            subj_data = {}
            for label_code, activity_name in target_activities_map.items():
                activity_df = df[df['activity_id'] == label_code].copy()
                if not activity_df.empty:
                    subj_data[activity_name] = activity_df.drop(columns=['activity_id'])

            full_dataset[subj_key] = subj_data
        except Exception as e:
            print(f"Error loading {file_name}: {e}")
            pass

    return full_dataset


def prepare_trial_list(label_config, full_data, target_map, feature_map):
    """
    label_config: list of (subj, act_id, gt_count)
    returns list of dict:
      data: (T,C) normalized per trial  (for model)
      raw : (T,C) raw float32           (for baseline integrator)
      count: float
      subj, act_id, act_name, meta
    """
    trial_list = []
    for subj, act_id, gt_count in label_config:
        act_id = int(act_id)
        act_name = target_map.get(act_id)
        feats = feature_map.get(act_id)

        if subj in full_data and act_name in full_data[subj]:
            raw_df = full_data[subj][act_name][feats]
            raw_np = raw_df.values.astype(np.float32)

            # trial-wise z-score (MODEL INPUT)
            mean = raw_np.mean(axis=0)
            std = raw_np.std(axis=0) + 1e-6
            norm_np = (raw_np - mean) / std

            trial_list.append({
                "data": norm_np,
                "raw": raw_np,
                "count": float(gt_count),
                "subj": subj,
                "act_id": act_id,
                "act_name": act_name,
                "meta": f"{subj}_{act_name}",
            })
        else:
            print(f"[Skip] Missing data for {subj} - act_id={act_id} ({act_name})")

    return trial_list


# ---------------------------------------------------------------------
# 5) Windowing (TRAIN) — for OURS model
# ---------------------------------------------------------------------
def trial_list_to_windows(trial_list, fs, win_sec=8.0, stride_sec=4.0, drop_last=True):
    """
    TRAIN: trial -> windows
    window label = trial avg rate * window duration
    """
    win_len = int(round(win_sec * fs))
    stride = int(round(stride_sec * fs))
    assert win_len > 0 and stride > 0

    windows = []
    for item in trial_list:
        x = item["data"]  # (T,C)
        T = x.shape[0]
        total_count = float(item["count"])
        meta = item["meta"]

        total_dur = max(T / float(fs), 1e-6)
        rate_trial = total_count / total_dur

        if T < win_len:
            win_dur = T / float(fs)
            windows.append({
                "data": x,
                "count": rate_trial * win_dur,
                "meta": f"{meta}__win[0:{T}]",
                "subj": item["subj"],
                "act_id": item["act_id"],
                "act_name": item["act_name"],
            })
            continue

        last_start = T - win_len
        starts = list(range(0, last_start + 1, stride))

        for st in starts:
            ed = st + win_len
            win_dur = win_len / float(fs)
            windows.append({
                "data": x[st:ed],
                "count": rate_trial * win_dur,
                "meta": f"{meta}__win[{st}:{ed}]",
                "subj": item["subj"],
                "act_id": item["act_id"],
                "act_name": item["act_name"],
            })

        if not drop_last:
            last_st = starts[-1] + stride
            if last_st < T:
                ed = T
                win_dur = (ed - last_st) / float(fs)
                windows.append({
                    "data": x[last_st:ed],
                    "count": rate_trial * win_dur,
                    "meta": f"{meta}__win[{last_st}:{ed}]",
                    "subj": item["subj"],
                    "act_id": item["act_id"],
                    "act_name": item["act_name"],
                })

    return windows


# ---------------------------------------------------------------------
# 6) Windowing inference (TEST) + win_shuffle (OURS)
# ---------------------------------------------------------------------
def predict_count_by_windowing(
    model, x_np, fs, win_sec, stride_sec, device,
    tau=1.0, batch_size=64,
    win_shuffle=False, rng: np.random.RandomState = None
):
    """
    TEST: trial -> windows inference -> mean rate -> total count
    win_shuffle=True: shuffle time indices inside each window.
    """
    win_len = int(round(win_sec * fs))
    stride = int(round(stride_sec * fs))
    T = x_np.shape[0]
    total_dur = T / float(fs)

    if T <= win_len:
        x_tensor = torch.tensor(x_np, dtype=torch.float32).transpose(0, 1).unsqueeze(0).to(device)  # (1,C,T)
        with torch.no_grad():
            rate_hat, _, _, _ = model(x_tensor, mask=None, tau=tau)
        pred_count = float(rate_hat.item() * total_dur)
        return pred_count, np.array([float(rate_hat.item())], dtype=np.float32)

    starts = list(range(0, T - win_len + 1, stride))
    windows = np.stack([x_np[st:st + win_len] for st in starts], axis=0)  # (N,W,C)

    if win_shuffle:
        assert rng is not None
        N, W, C = windows.shape
        for i in range(N):
            perm = rng.permutation(W)
            windows[i] = windows[i, perm, :]

    xw = torch.tensor(windows, dtype=torch.float32).permute(0, 2, 1).to(device)  # (N,C,W)

    rates = []
    model.eval()
    with torch.no_grad():
        for i in range(0, xw.shape[0], batch_size):
            xb = xw[i:i + batch_size]
            r_hat, _, _, _ = model(xb, mask=None, tau=tau)
            rates.append(r_hat.detach().cpu().numpy())

    rates = np.concatenate(rates, axis=0)
    rate_mean = float(rates.mean())
    pred_count = rate_mean * total_dur
    return float(pred_count), rates


# ---------------------------------------------------------------------
# 7) Dataset / Collate
# ---------------------------------------------------------------------
class TrialDataset(Dataset):
    def __init__(self, trial_list):
        self.trials = trial_list

    def __len__(self):
        return len(self.trials)

    def __getitem__(self, idx):
        item = self.trials[idx]
        data = torch.tensor(item['data'], dtype=torch.float32).transpose(0, 1)  # (C,T)
        count = torch.tensor(item['count'], dtype=torch.float32)
        return data, count, item['meta']


def collate_variable_length(batch):
    max_len = max([x[0].shape[1] for x in batch])
    C = batch[0][0].shape[0]

    padded_data, masks, counts, metas, lengths = [], [], [], [], []
    for data, count, meta in batch:
        T = data.shape[1]
        lengths.append(T)

        pad_size = max_len - T
        if pad_size > 0:
            pad = torch.zeros(C, pad_size)
            d_padded = torch.cat([data, pad], dim=1)
            mask = torch.cat([torch.ones(T), torch.zeros(pad_size)], dim=0)
        else:
            d_padded = data
            mask = torch.ones(T)

        padded_data.append(d_padded)
        masks.append(mask)
        counts.append(count)
        metas.append(meta)

    return {
        "data": torch.stack(padded_data),
        "mask": torch.stack(masks),
        "count": torch.stack(counts),
        "length": torch.tensor(lengths, dtype=torch.float32),
        "meta": metas
    }


# ---------------------------------------------------------------------
# 8) Model
# ---------------------------------------------------------------------
class ManifoldEncoder(nn.Module):
    def __init__(self, input_ch, hidden_dim=128, latent_dim=16):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv1d(input_ch, hidden_dim, 5, padding=2),
            nn.ReLU(),
            nn.Conv1d(hidden_dim, hidden_dim, 5, padding=2),
            nn.ReLU(),
            nn.Conv1d(hidden_dim, latent_dim, 1)
        )

    def forward(self, x):
        z = self.net(x)            # (B,D,T)
        z = z.transpose(1, 2)      # (B,T,D)
        return z


class ManifoldDecoder(nn.Module):
    def __init__(self, latent_dim, hidden_dim, out_ch):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv1d(latent_dim, hidden_dim, 5, padding=2),
            nn.ReLU(),
            nn.Conv1d(hidden_dim, hidden_dim, 5, padding=2),
            nn.ReLU(),
            nn.Conv1d(hidden_dim, out_ch, 1)
        )

    def forward(self, z):
        zt = z.transpose(1, 2)     # (B,D,T)
        x_hat = self.net(zt)       # (B,C,T)
        return x_hat


class MultiRateHead(nn.Module):
    def __init__(self, latent_dim=16, hidden=64, K_max=6):
        super().__init__()
        self.K_max = K_max
        self.net = nn.Sequential(
            nn.Linear(latent_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1 + K_max)  # [amp | phase_logits...]
        )

    def forward(self, z, tau=1.0):
        out = self.net(z)                     # (B,T,1+K)
        amp = F.softplus(out[..., 0])         # (B,T) >=0
        phase_logits = out[..., 1:]           # (B,T,K)
        phase = F.softmax(phase_logits / tau, dim=-1)
        return amp, phase, phase_logits


class KAutoCountModel(nn.Module):
    def __init__(self, input_ch, hidden_dim=128, latent_dim=16, K_max=6):
        super().__init__()
        self.encoder = ManifoldEncoder(input_ch, hidden_dim, latent_dim)
        self.decoder = ManifoldDecoder(latent_dim, hidden_dim, input_ch)
        self.rate_head = MultiRateHead(latent_dim, hidden=hidden_dim, K_max=K_max)
        self._init_weights()

    def _init_weights(self):
        for m in self.modules():
            if isinstance(m, (nn.Conv1d, nn.Linear)):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
        with torch.no_grad():
            b = self.rate_head.net[-1].bias
            b.zero_()
            b[0].fill_(-2.0)  # amp bias

    @staticmethod
    def _masked_mean_time(x, mask=None, eps=1e-6):
        if mask is None:
            return x.mean(dim=1)
        if x.dim() == 2:
            m = mask.to(dtype=x.dtype, device=x.device)
            return (x * m).sum(dim=1) / (m.sum(dim=1) + eps)
        elif x.dim() == 3:
            m = mask.to(dtype=x.dtype, device=x.device).unsqueeze(-1)
            return (x * m).sum(dim=1) / (m.sum(dim=1) + eps)
        else:
            raise ValueError(f"Unsupported dim for masked mean: {x.dim()}")

    def forward(self, x, mask=None, tau=1.0):
        z = self.encoder(x)              # (B,T,D)
        x_hat = self.decoder(z)          # (B,C,T)

        amp_t, phase_p, _ = self.rate_head(z, tau=tau)
        micro_rate_t = amp_t             # (B,T)

        p_bar = self._masked_mean_time(phase_p, mask)           # (B,K)
        k_hat = 1.0 / (p_bar.pow(2).sum(dim=1) + 1e-6)          # (B,)

        rep_rate_t = micro_rate_t / (k_hat.unsqueeze(1) + 1e-6) # (B,T)
        if mask is not None:
            rep_rate_t = rep_rate_t * mask

        if mask is None:
            avg_rep_rate = rep_rate_t.mean(dim=1)
        else:
            avg_rep_rate = (rep_rate_t * mask).sum(dim=1) / (mask.sum(dim=1) + 1e-6)

        aux = {
            "phase_p": phase_p,          # (B,T,K)
            "rep_rate_t": rep_rate_t,    # (B,T)
            "k_hat": k_hat,              # (B,)
        }
        return avg_rep_rate, z, x_hat, aux


# ---------------------------------------------------------------------
# 9) Loss utils
# ---------------------------------------------------------------------
def masked_recon_mse(x_hat, x, mask, eps=1e-6):
    mask = mask.to(dtype=x.dtype, device=x.device)
    mask_bc = mask.unsqueeze(1)              # (B,1,T)
    se = (x_hat - x) ** 2                    # (B,C,T)
    se = se * mask_bc
    denom = (mask.sum() * x.shape[1]) + eps
    return se.sum() / denom


def temporal_smoothness(v, mask=None, eps=1e-6):
    dv = torch.abs(v[:, 1:] - v[:, :-1])
    if mask is None:
        return dv.mean()
    m = mask[:, 1:] * mask[:, :-1]
    m = m.to(dtype=dv.dtype, device=dv.device)
    return (dv * m).sum() / (m.sum() + eps)


def phase_entropy_loss(phase_p, mask=None, eps=1e-8):
    ent = -(phase_p * (phase_p + eps).log()).sum(dim=-1)  # (B,T)
    if mask is None:
        return ent.mean()
    ent = ent * mask
    return ent.sum() / (mask.sum() + eps)


def effK_usage_loss(phase_p, mask=None, eps=1e-6):
    if mask is None:
        p_bar = phase_p.mean(dim=1)
    else:
        m = mask.to(dtype=phase_p.dtype, device=phase_p.device).unsqueeze(-1)
        p_bar = (phase_p * m).sum(dim=1) / (m.sum(dim=1) + eps)
    effK = 1.0 / (p_bar.pow(2).sum(dim=1) + eps)
    return effK.mean()


# ---------------------------------------------------------------------
# 10) Train
# ---------------------------------------------------------------------
def train_one_epoch(model, loader, optimizer, config, device):
    model.train()
    fs = config["fs"]
    tau = config.get("tau", 1.0)

    lam_recon = config.get("lambda_recon", 1.0)
    lam_smooth = config.get("lambda_smooth", 0.05)
    lam_phase_ent = config.get("lambda_phase_ent", 0.01)
    lam_effk = config.get("lambda_effk", 0.0075)

    for batch in loader:
        x = batch["data"].to(device)
        mask = batch["mask"].to(device)
        y_count = batch["count"].to(device)
        length = batch["length"].to(device)

        duration = torch.clamp(length / fs, min=1e-6)
        y_rate = y_count / duration

        optimizer.zero_grad()
        rate_hat, _, x_hat, aux = model(x, mask, tau=tau)

        loss_rate = F.mse_loss(rate_hat, y_rate)
        loss_recon = masked_recon_mse(x_hat, x, mask)
        loss_smooth = temporal_smoothness(aux["rep_rate_t"], mask)
        loss_phase_ent = phase_entropy_loss(aux["phase_p"], mask)
        loss_effk = effK_usage_loss(aux["phase_p"], mask)

        loss = (loss_rate
                + lam_recon * loss_recon
                + lam_smooth * loss_smooth
                + lam_phase_ent * loss_phase_ent
                + lam_effk * loss_effk)

        loss.backward()
        optimizer.step()


# ---------------------------------------------------------------------
# 11) Metrics helpers (entropy / effK)
# ---------------------------------------------------------------------
def compute_phase_entropy_mean(phase_p_np, eps=1e-8):
    phase_p_np = np.asarray(phase_p_np, dtype=np.float32)  # (T,K)
    ent_t = -(phase_p_np * np.log(phase_p_np + eps)).sum(axis=1)
    return float(ent_t.mean())


def compute_effK_from_phase_mean(phase_p_np, eps=1e-6):
    phase_p_np = np.asarray(phase_p_np, dtype=np.float32)  # (T,K)
    p_bar = phase_p_np.mean(axis=0)
    effK = 1.0 / (np.sum(p_bar ** 2) + eps)
    return float(effK)


# ---------------------------------------------------------------------
# 12) ✅ Baseline-E2: FULL-TRIAL energy integrator (RAW) + calibration (beta=0)
# ---------------------------------------------------------------------
def compute_energy_integral_raw(x_raw: np.ndarray, fs: int, eps=1e-12) -> float:
    """
    x_raw: (T,C) raw float32
    - DC removal (per-channel mean subtraction)
    - energy integral: (1/fs) * sum_t sum_c (x_dc^2)
    """
    x = np.asarray(x_raw, dtype=np.float32)
    x = x - x.mean(axis=0, keepdims=True)
    E = float(np.sum(x * x) / max(float(fs), eps))
    return E


def fit_linear_energy_calibrator_alpha_only(train_trials, fs: int, ridge: float = 1e-8):
    """
    Fit alpha with beta=0: y ≈ alpha*E
    alpha = (E^T y) / (E^T E + ridge)
    """
    if len(train_trials) == 0:
        return 0.0

    Es, ys = [], []
    for tr in train_trials:
        E = compute_energy_integral_raw(tr["raw"], fs=fs)
        Es.append(E)
        ys.append(float(tr["count"]))

    Es = np.asarray(Es, dtype=np.float64)
    ys = np.asarray(ys, dtype=np.float64)

    num = float(np.sum(Es * ys))
    den = float(np.sum(Es * Es) + ridge)
    return float(num / den)


def baselineE2_predict_count(alpha_only: float, x_raw: np.ndarray, fs: int) -> float:
    E = compute_energy_integral_raw(x_raw, fs=fs)
    return float(alpha_only * E)


# ---------------------------------------------------------------------
# 13) Core evaluator for ONE trial (OURS + E2)
# ---------------------------------------------------------------------
def eval_one_trial_all_modes(
    model, CONFIG, device, item,
    baseE2_alpha,
    fold_idx, track_name="single"
):
    MODES = ["orig", "reverse", "win_shuffle", "block_shuffle", "phase_randomize"]

    x_np_orig = item["data"]   # normalized (for model)
    x_raw_orig = item["raw"]   # raw (for baseline)

    T = x_np_orig.shape[0]
    gt = float(item["count"])
    act_id = int(item["act_id"])
    act_name = item["act_name"]
    meta = item["meta"]
    test_subj = item["subj"]

    base_seed = int(CONFIG["seed"] + (fold_idx + 1) * 100000)
    rng_wshf  = np.random.RandomState(_stable_seed_from_text(meta + "__win_shuffle", base_seed))
    rng_bshf  = np.random.RandomState(_stable_seed_from_text(meta + "__block_shuffle", base_seed))
    rng_ph    = np.random.RandomState(_stable_seed_from_text(meta + "__phase_rand", base_seed))

    rows = []
    for mode in MODES:
        # -------------------------
        # model input transform (normalized) + baseline raw transform
        # -------------------------
        if mode == "orig":
            x_for_pred = x_np_orig
            win_shuffle = False
            rng = None
            x_for_aux = x_np_orig
            x_raw_for_base = x_raw_orig

        elif mode == "reverse":
            x_for_pred = transform_reverse(x_np_orig)
            win_shuffle = False
            rng = None
            x_for_aux = x_for_pred
            x_raw_for_base = transform_reverse(x_raw_orig)

        elif mode == "win_shuffle":
            x_for_pred = x_np_orig
            win_shuffle = True
            rng = rng_wshf

            perm_full = rng_wshf.permutation(x_np_orig.shape[0])
            x_for_aux = x_np_orig[perm_full].copy()
            x_raw_for_base = x_raw_orig[perm_full].copy()  # (E2는 순서불변이라 값은 사실 동일)

        elif mode == "block_shuffle":
            block_len = int(round(CONFIG["block_sec"] * CONFIG["fs"]))
            x_for_pred = transform_block_shuffle(x_np_orig, block_len=block_len, rng=rng_bshf)
            win_shuffle = False
            rng = None
            x_for_aux = x_for_pred
            x_raw_for_base = transform_block_shuffle(x_raw_orig, block_len=block_len, rng=rng_bshf)

        elif mode == "phase_randomize":
            x_for_pred = transform_phase_randomize(x_np_orig, rng=rng_ph)
            win_shuffle = False
            rng = None
            x_for_aux = x_for_pred
            x_raw_for_base = transform_phase_randomize(x_raw_orig, rng=rng_ph)

        else:
            raise ValueError(mode)

        # -------------------------
        # OURS prediction
        # -------------------------
        pred_ours, _ = predict_count_by_windowing(
            model,
            x_np=x_for_pred,
            fs=CONFIG["fs"],
            win_sec=CONFIG["win_sec"],
            stride_sec=CONFIG["stride_sec"],
            device=device,
            tau=CONFIG.get("tau", 1.0),
            batch_size=CONFIG.get("batch_size", 64),
            win_shuffle=win_shuffle,
            rng=rng
        )

        # aux (k_hat / entropy / effK) — full-trial 1회 forward
        x_tensor = torch.tensor(x_for_aux, dtype=torch.float32).transpose(0, 1).unsqueeze(0).to(device)
        with torch.no_grad():
            _, _, _, aux = model(x_tensor, mask=None, tau=CONFIG.get("tau", 1.0))
        k_hat = float(aux["k_hat"].item())
        phase_p = aux["phase_p"].squeeze(0).detach().cpu().numpy()  # (T,K)
        ent = compute_phase_entropy_mean(phase_p)
        effK = compute_effK_from_phase_mean(phase_p)

        dur = T / float(CONFIG["fs"])
        pred_rate = pred_ours / max(dur, 1e-6)
        gt_rate = gt / max(dur, 1e-6)

        abs_err = abs(pred_ours - gt)
        mape = abs_err / (abs(gt) + 1e-6) * 100.0
        bias = pred_ours - gt

        # -------------------------
        # Baseline-E2 prediction
        # -------------------------
        pred_baseE2 = baselineE2_predict_count(baseE2_alpha, x_raw_for_base, fs=int(CONFIG["fs"]))
        abs_err_b = abs(pred_baseE2 - gt)
        mape_b = abs_err_b / (abs(gt) + 1e-6) * 100.0
        bias_b = pred_baseE2 - gt

        rows.append({
            "track": track_name,
            "fold": fold_idx + 1,
            "test_subj": test_subj,
            "act_id": act_id,
            "act_name": act_name,
            "mode": mode,
            "T": int(T),
            "duration_sec": float(dur),
            "GT": float(gt),

            "Pred_ours": float(pred_ours),
            "MAE_ours": float(abs_err),
            "MAPE_ours": float(mape),
            "Bias_ours": float(bias),
            "GT_rate": float(gt_rate),
            "Pred_rate": float(pred_rate),
            "k_hat": float(k_hat),
            "entropy": float(ent),
            "effK": float(effK),

            "Pred_baseE2": float(pred_baseE2),
            "MAE_baseE2": float(abs_err_b),
            "MAPE_baseE2": float(mape_b),
            "Bias_baseE2": float(bias_b),
            "baseE2_alpha": float(baseE2_alpha),
        })

    return rows


# ---------------------------------------------------------------------
# 14) SINGLE-ACTIVITY LOSO (activity loop) ONLY
# ---------------------------------------------------------------------
def run_single_activity_loso_only(CONFIG, full_data, device, activity_specs):
    subjects = [f"subject{i}" for i in range(1, 11)]
    out_rows = []

    print("\n" + "=" * 140)
    print(" >>> SINGLE-ACTIVITY LOSO ONLY")
    print(" >>> Baseline: E2(full-trial energy integrator, beta=0) | OURS(window-stabilized rate learning)")
    print("=" * 140)

    for spec in activity_specs:
        act_id = int(spec["act_id"])
        act_name = spec["act_name"]
        labels = spec["labels"]

        print("\n" + "-" * 140)
        print(f"[Single] Activity: {act_name} (id={act_id})")
        print("-" * 140)

        for fold_idx, test_subj in enumerate(subjects):
            set_strict_seed(CONFIG["seed"])

            train_labels = [t for t in labels if t[0] != test_subj]
            test_labels  = [t for t in labels if t[0] == test_subj]

            # Restrict maps to that activity only
            target_map_one = {act_id: act_name}
            feat_map_one   = {act_id: CONFIG["ACT_FEATURE_MAP"][act_id]}

            train_trials = prepare_trial_list(train_labels, full_data, target_map_one, feat_map_one)
            test_trials  = prepare_trial_list(test_labels,  full_data, target_map_one, feat_map_one)

            if len(train_trials) == 0 or len(test_trials) == 0:
                print(f"[Skip] Fold {fold_idx+1}: train_trials={len(train_trials)}, test_trials={len(test_trials)}")
                continue

            # ✅ OURS Train windows
            train_windows = trial_list_to_windows(
                train_trials, fs=CONFIG["fs"],
                win_sec=CONFIG["win_sec"], stride_sec=CONFIG["stride_sec"],
                drop_last=CONFIG["drop_last"]
            )

            # ✅ Baseline-E2: fit on TRAIN TRIALS only
            baseE2_alpha = fit_linear_energy_calibrator_alpha_only(train_trials, fs=int(CONFIG["fs"]))

            g = torch.Generator()
            g.manual_seed(CONFIG["seed"])

            train_loader = DataLoader(
                TrialDataset(train_windows),
                batch_size=CONFIG["batch_size"],
                shuffle=True,
                collate_fn=collate_variable_length,
                generator=g,
                num_workers=0
            )

            input_ch = train_windows[0]["data"].shape[1]
            model = KAutoCountModel(
                input_ch=input_ch,
                hidden_dim=CONFIG["hidden_dim"],
                latent_dim=CONFIG["latent_dim"],
                K_max=CONFIG["K_max"]
            ).to(device)

            optimizer = torch.optim.Adam(model.parameters(), lr=CONFIG["lr"])
            scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.5)

            for epoch in range(CONFIG["epochs"]):
                train_one_epoch(model, train_loader, optimizer, CONFIG, device)
                scheduler.step()

            model.eval()

            fold_rows = []
            for item in test_trials:
                fold_rows.extend(eval_one_trial_all_modes(
                    model=model, CONFIG=CONFIG, device=device,
                    item=item,
                    baseE2_alpha=baseE2_alpha,
                    fold_idx=fold_idx, track_name="single"
                ))
            out_rows.extend(fold_rows)

            # Fold quick summary
            df_fold = pd.DataFrame(fold_rows)
            gsum = (df_fold.groupby("mode")
                    .agg(
                        n=("MAE_ours", "count"),
                        MAE_ours=("MAE_ours", "mean"),
                        MAE_baseE2=("MAE_baseE2", "mean"),
                    )
                    .reset_index())

            mae0 = float(gsum[gsum["mode"] == "orig"]["MAE_ours"].values[0]) if (gsum["mode"] == "orig").any() else float("nan")
            print(f"[Fold {fold_idx+1:2d}] Test={test_subj} | E2(alpha={baseE2_alpha:.3g}, beta=0)")
            for _, rr in gsum.iterrows():
                d = float(rr["MAE_ours"]) - mae0 if np.isfinite(mae0) else float("nan")
                print(f"  {rr['mode']:14s} | MAE ours={rr['MAE_ours']:.3f} (Δ={d:+.3f}) | MAE E2={rr['MAE_baseE2']:.3f} | n={int(rr['n'])}")

    return pd.DataFrame(out_rows)


# ---------------------------------------------------------------------
# 15) Print-only summaries (NO CSV saving)
# ---------------------------------------------------------------------
def print_summaries(df_all: pd.DataFrame):
    if df_all is None or len(df_all) == 0:
        print("[Warn] No rows to summarize.")
        return

    # Overall by mode
    g_all = (df_all.groupby(["mode"])
             .agg(
                n=("MAE_ours", "count"),
                MAE_ours=("MAE_ours", "mean"),
                MAE_baseE2=("MAE_baseE2", "mean"),
                entropy=("entropy", "mean"),
                effK=("effK", "mean"),
                k_hat=("k_hat", "mean"),
                baseE2_alpha=("baseE2_alpha", "mean"),
             )
             .reset_index())

    if (g_all["mode"] == "orig").any():
        mae0 = float(g_all[g_all["mode"] == "orig"]["MAE_ours"].values[0])
        g_all["dMAE_vs_orig"] = g_all["MAE_ours"] - mae0
    else:
        g_all["dMAE_vs_orig"] = np.nan

    print("\n" + "=" * 140)
    print("[OVERALL SUMMARY]  (Δ = MAE(mode) - MAE(orig))")
    with pd.option_context('display.max_rows', 200, 'display.max_columns', 80, 'display.width', 220):
        print(g_all.sort_values("mode").to_string(index=False))

    # Per-activity, per-mode
    g_act = (df_all.groupby(["act_id", "act_name", "mode"])
             .agg(
                n=("MAE_ours", "count"),
                MAE_ours=("MAE_ours", "mean"),
                MAE_baseE2=("MAE_baseE2", "mean"),
                entropy=("entropy", "mean"),
                effK=("effK", "mean"),
                k_hat=("k_hat", "mean"),
             )
             .reset_index())

    blocks = []
    for (aid, aname), sdf in g_act.groupby(["act_id", "act_name"], sort=False):
        base = sdf[sdf["mode"] == "orig"]
        mae0 = float(base["MAE_ours"].values[0]) if len(base) > 0 else np.nan
        tmp = sdf.copy()
        tmp["dMAE_vs_orig"] = tmp["MAE_ours"] - mae0
        blocks.append(tmp)
    g_act2 = pd.concat(blocks, axis=0).reset_index(drop=True)

    print("\n" + "=" * 140)
    print("[PER-ACTIVITY SUMMARY]  (Δ = MAE(mode) - MAE(orig within activity))")
    with pd.option_context('display.max_rows', 999, 'display.max_columns', 80, 'display.width', 240):
        print(g_act2.sort_values(["act_id", "mode"]).to_string(index=False))
    print("=" * 140)


# ---------------------------------------------------------------------
# 16) Main
# ---------------------------------------------------------------------
def main():
    BASE_CONFIG = {
        "seed": 42,
        "data_dir": "/content/drive/MyDrive/Colab Notebooks/HAR_data/MHEALTHDATASET",

        "COLUMN_NAMES": [
            'acc_chest_x', 'acc_chest_y', 'acc_chest_z',
            'ecg_1', 'ecg_2',
            'acc_ankle_x', 'acc_ankle_y', 'acc_ankle_z',
            'gyro_ankle_x', 'gyro_ankle_y', 'gyro_ankle_z',
            'mag_ankle_x', 'mag_ankle_y', 'mag_ankle_z',
            'acc_arm_x', 'acc_arm_y', 'acc_arm_z',
            'gyro_arm_x', 'gyro_arm_y', 'gyro_arm_z',
            'mag_arm_x', 'mag_arm_y', 'mag_arm_z',
            'activity_id'
        ],

        # training
        "epochs": 50,
        "lr": 5e-4,
        "batch_size": 64,
        "fs": 50,

        # windowing (OURS)
        "win_sec": 8.0,
        "stride_sec": 4.0,
        "drop_last": True,

        # model
        "hidden_dim": 128,
        "latent_dim": 16,
        "K_max": 6,

        # loss weights
        "lambda_recon": 1.0,
        "lambda_smooth": 0.05,
        "lambda_phase_ent": 0.01,
        "lambda_effk": 0.0075,

        "tau": 1.0,

        # defense config
        "block_sec": 0.8,
    }

    DEFAULT_FEATS = [
        'acc_chest_x', 'acc_chest_y', 'acc_chest_z',
        'acc_ankle_x', 'acc_ankle_y', 'acc_ankle_z',
        'gyro_ankle_x', 'gyro_ankle_y', 'gyro_ankle_z',
        'acc_arm_x', 'acc_arm_y', 'acc_arm_z',
        'gyro_arm_x', 'gyro_arm_y', 'gyro_arm_z'
    ]

    ACTIVITY_SPECS = [
        {"act_id": 6,  "act_name": "Waist bends forward",       "labels": [
            ("subject1", 6, 21), ("subject2", 6, 19), ("subject3", 6, 21), ("subject4", 6, 20), ("subject5", 6, 20),
            ("subject6", 6, 20), ("subject7", 6, 20), ("subject8", 6, 21), ("subject9", 6, 21), ("subject10", 6, 20),
        ]},
        {"act_id": 7,  "act_name": "Frontal elevation of arms", "labels": [
            ("subject1", 7, 20), ("subject2", 7, 20), ("subject3", 7, 20), ("subject4", 7, 20), ("subject5", 7, 20),
            ("subject6", 7, 20), ("subject7", 7, 20), ("subject8", 7, 19), ("subject9", 7, 19), ("subject10", 7, 20),
        ]},
        {"act_id": 8,  "act_name": "Knees bending",             "labels": [
            ("subject1", 8, 20), ("subject2", 8, 21), ("subject3", 8, 21), ("subject4", 8, 19), ("subject5", 8, 20),
            ("subject6", 8, 20), ("subject7", 8, 21), ("subject8", 8, 21), ("subject9", 8, 21), ("subject10", 8, 21),
        ]},
        {"act_id": 12, "act_name": "Jump front & back",         "labels": [
            ("subject1", 12, 20), ("subject2", 12, 22), ("subject3", 12, 21), ("subject4", 12, 21), ("subject5", 12, 20),
            ("subject6", 12, 21), ("subject7", 12, 19), ("subject8", 12, 20), ("subject9", 12, 20), ("subject10", 12, 20),
        ]},
        {"act_id": 10, "act_name": "Jogging",                   "labels": [
            ("subject1", 10, 157), ("subject2", 10, 161), ("subject3", 10, 154), ("subject4", 10, 154), ("subject5", 10, 160),
            ("subject6", 10, 156), ("subject7", 10, 153), ("subject8", 10, 160), ("subject9", 10, 166), ("subject10", 10, 156),
        ]},
        {"act_id": 11, "act_name": "Running",                   "labels": [
            ("subject1", 11, 165), ("subject2", 11, 158), ("subject3", 11, 174), ("subject4", 11, 163), ("subject5", 11, 157),
            ("subject6", 11, 172), ("subject7", 11, 149), ("subject8", 11, 166), ("subject9", 11, 174), ("subject10", 11, 172),
        ]},
    ]

    target_map = {int(s["act_id"]): s["act_name"] for s in ACTIVITY_SPECS}
    feat_map = {int(s["act_id"]): DEFAULT_FEATS for s in ACTIVITY_SPECS}

    CONFIG = dict(BASE_CONFIG)
    CONFIG["TARGET_ACTIVITIES_MAP"] = target_map
    CONFIG["ACT_FEATURE_MAP"] = feat_map

    set_strict_seed(CONFIG["seed"])
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Device: {device}")

    full_data = load_mhealth_dataset(CONFIG["data_dir"], CONFIG["TARGET_ACTIVITIES_MAP"], CONFIG["COLUMN_NAMES"])
    if not full_data:
        return

    df_all = run_single_activity_loso_only(CONFIG, full_data, device, ACTIVITY_SPECS)
    print_summaries(df_all)


if __name__ == "__main__":
    main()
# Out:
# Device: cuda
# Loading 10 subjects from /content/drive/MyDrive/Colab Notebooks/HAR_data/MHEALTHDATASET...
#
# ============================================================================================================================================
#  >>> SINGLE-ACTIVITY LOSO ONLY
#  >>> Baseline: E2(full-trial energy integrator, beta=0) | OURS(window-stabilized rate learning)
# ============================================================================================================================================
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# [Single] Activity: Waist bends forward (id=6)
# --------------------------------------------------------------------------------------------------------------------------------------------
# [Fold  1] Test=subject1 | E2(alpha=0.00643, beta=0)
#   block_shuffle  | MAE ours=1.820 (Δ=-0.318) | MAE E2=3.376 | n=1
#   orig           | MAE ours=2.139 (Δ=+0.000) | MAE E2=3.376 | n=1
#   phase_randomize | MAE ours=6.618 (Δ=+4.480) | MAE E2=3.376 | n=1
#   reverse        | MAE ours=1.730 (Δ=-0.408) | MAE E2=3.376 | n=1
#   win_shuffle    | MAE ours=3.910 (Δ=+1.771) | MAE E2=3.376 | n=1
# [Fold  2] Test=subject2 | E2(alpha=0.00625, beta=0)
#   block_shuffle  | MAE ours=5.833 (Δ=+0.664) | MAE E2=1.455 | n=1
#   orig           | MAE ours=5.169 (Δ=+0.000) | MAE E2=1.455 | n=1
#   phase_randomize | MAE ours=12.286 (Δ=+7.117) | MAE E2=1.455 | n=1
#   reverse        | MAE ours=5.836 (Δ=+0.667) | MAE E2=1.455 | n=1
#   win_shuffle    | MAE ours=10.337 (Δ=+5.168) | MAE E2=1.455 | n=1
# [Fold  3] Test=subject3 | E2(alpha=0.00631, beta=0)
#   block_shuffle  | MAE ours=8.680 (Δ=+0.234) | MAE E2=0.481 | n=1
#   orig           | MAE ours=8.446 (Δ=+0.000) | MAE E2=0.481 | n=1
#   phase_randomize | MAE ours=13.453 (Δ=+5.006) | MAE E2=0.481 | n=1
#   reverse        | MAE ours=8.613 (Δ=+0.166) | MAE E2=0.481 | n=1
#   win_shuffle    | MAE ours=11.863 (Δ=+3.417) | MAE E2=0.481 | n=1
# [Fold  4] Test=subject4 | E2(alpha=0.00641, beta=0)
#   block_shuffle  | MAE ours=3.335 (Δ=+0.185) | MAE E2=3.070 | n=1
#   orig           | MAE ours=3.151 (Δ=+0.000) | MAE E2=3.070 | n=1
#   phase_randomize | MAE ours=12.055 (Δ=+8.904) | MAE E2=3.070 | n=1
#   reverse        | MAE ours=3.152 (Δ=+0.001) | MAE E2=3.070 | n=1
#   win_shuffle    | MAE ours=10.537 (Δ=+7.386) | MAE E2=3.070 | n=1
# [Fold  5] Test=subject5 | E2(alpha=0.00671, beta=0)
#   block_shuffle  | MAE ours=6.113 (Δ=+0.582) | MAE E2=9.260 | n=1
#   orig           | MAE ours=5.531 (Δ=+0.000) | MAE E2=9.260 | n=1
#   phase_randomize | MAE ours=8.550 (Δ=+3.019) | MAE E2=9.260 | n=1
#   reverse        | MAE ours=5.047 (Δ=-0.484) | MAE E2=9.260 | n=1
#   win_shuffle    | MAE ours=5.801 (Δ=+0.270) | MAE E2=9.260 | n=1
# [Fold  6] Test=subject6 | E2(alpha=0.00615, beta=0)
#   block_shuffle  | MAE ours=6.303 (Δ=-0.523) | MAE E2=6.510 | n=1
#   orig           | MAE ours=6.826 (Δ=+0.000) | MAE E2=6.510 | n=1
#   phase_randomize | MAE ours=1.871 (Δ=-4.955) | MAE E2=6.510 | n=1
#   reverse        | MAE ours=5.751 (Δ=-1.075) | MAE E2=6.510 | n=1
#   win_shuffle    | MAE ours=1.975 (Δ=-4.851) | MAE E2=6.510 | n=1
# [Fold  7] Test=subject7 | E2(alpha=0.00624, beta=0)
#   block_shuffle  | MAE ours=4.771 (Δ=+0.276) | MAE E2=1.805 | n=1
#   orig           | MAE ours=4.495 (Δ=+0.000) | MAE E2=1.805 | n=1
#   phase_randomize | MAE ours=6.346 (Δ=+1.851) | MAE E2=1.805 | n=1
#   reverse        | MAE ours=5.665 (Δ=+1.171) | MAE E2=1.805 | n=1
#   win_shuffle    | MAE ours=8.700 (Δ=+4.205) | MAE E2=1.805 | n=1
# [Fold  8] Test=subject8 | E2(alpha=0.00614, beta=0)
#   block_shuffle  | MAE ours=4.765 (Δ=+0.151) | MAE E2=6.563 | n=1
#   orig           | MAE ours=4.615 (Δ=+0.000) | MAE E2=6.563 | n=1
#   phase_randomize | MAE ours=2.865 (Δ=-1.750) | MAE E2=6.563 | n=1
#   reverse        | MAE ours=5.117 (Δ=+0.502) | MAE E2=6.563 | n=1
#   win_shuffle    | MAE ours=2.574 (Δ=-2.040) | MAE E2=6.563 | n=1
# [Fold  9] Test=subject9 | E2(alpha=0.00627, beta=0)
#   block_shuffle  | MAE ours=7.974 (Δ=+0.062) | MAE E2=0.729 | n=1
#   orig           | MAE ours=7.911 (Δ=+0.000) | MAE E2=0.729 | n=1
#   phase_randomize | MAE ours=2.406 (Δ=-5.505) | MAE E2=0.729 | n=1
#   reverse        | MAE ours=7.759 (Δ=-0.152) | MAE E2=0.729 | n=1
#   win_shuffle    | MAE ours=8.382 (Δ=+0.470) | MAE E2=0.729 | n=1
# [Fold 10] Test=subject10 | E2(alpha=0.00613, beta=0)
#   block_shuffle  | MAE ours=0.194 (Δ=-0.471) | MAE E2=9.259 | n=1
#   orig           | MAE ours=0.665 (Δ=+0.000) | MAE E2=9.259 | n=1
#   phase_randomize | MAE ours=0.823 (Δ=+0.158) | MAE E2=9.259 | n=1
#   reverse        | MAE ours=0.879 (Δ=+0.214) | MAE E2=9.259 | n=1
#   win_shuffle    | MAE ours=2.091 (Δ=+1.426) | MAE E2=9.259 | n=1
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# [Single] Activity: Frontal elevation of arms (id=7)
# --------------------------------------------------------------------------------------------------------------------------------------------
# [Fold  1] Test=subject1 | E2(alpha=0.00433, beta=0)
#   block_shuffle  | MAE ours=0.050 (Δ=+0.032) | MAE E2=0.593 | n=1
#   orig           | MAE ours=0.018 (Δ=+0.000) | MAE E2=0.593 | n=1
#   phase_randomize | MAE ours=5.832 (Δ=+5.814) | MAE E2=0.593 | n=1
#   reverse        | MAE ours=0.037 (Δ=+0.019) | MAE E2=0.593 | n=1
#   win_shuffle    | MAE ours=1.937 (Δ=+1.919) | MAE E2=0.593 | n=1
# [Fold  2] Test=subject2 | E2(alpha=0.00425, beta=0)
#   block_shuffle  | MAE ours=1.940 (Δ=-0.698) | MAE E2=5.196 | n=1
#   orig           | MAE ours=2.638 (Δ=+0.000) | MAE E2=5.196 | n=1
#   phase_randomize | MAE ours=5.597 (Δ=+2.959) | MAE E2=5.196 | n=1
#   reverse        | MAE ours=2.931 (Δ=+0.293) | MAE E2=5.196 | n=1
#   win_shuffle    | MAE ours=1.568 (Δ=-1.069) | MAE E2=5.196 | n=1
# [Fold  3] Test=subject3 | E2(alpha=0.00447, beta=0)
#   block_shuffle  | MAE ours=4.912 (Δ=+0.454) | MAE E2=4.324 | n=1
#   orig           | MAE ours=4.458 (Δ=+0.000) | MAE E2=4.324 | n=1
#   phase_randomize | MAE ours=3.593 (Δ=-0.865) | MAE E2=4.324 | n=1
#   reverse        | MAE ours=4.866 (Δ=+0.408) | MAE E2=4.324 | n=1
#   win_shuffle    | MAE ours=1.928 (Δ=-2.530) | MAE E2=4.324 | n=1
# [Fold  4] Test=subject4 | E2(alpha=0.00439, beta=0)
#   block_shuffle  | MAE ours=1.273 (Δ=+0.202) | MAE E2=1.717 | n=1
#   orig           | MAE ours=1.071 (Δ=+0.000) | MAE E2=1.717 | n=1
#   phase_randomize | MAE ours=3.316 (Δ=+2.245) | MAE E2=1.717 | n=1
#   reverse        | MAE ours=0.804 (Δ=-0.267) | MAE E2=1.717 | n=1
#   win_shuffle    | MAE ours=2.394 (Δ=+1.323) | MAE E2=1.717 | n=1
# [Fold  5] Test=subject5 | E2(alpha=0.00456, beta=0)
#   block_shuffle  | MAE ours=1.223 (Δ=-0.110) | MAE E2=7.041 | n=1
#   orig           | MAE ours=1.332 (Δ=+0.000) | MAE E2=7.041 | n=1
#   phase_randomize | MAE ours=0.025 (Δ=-1.308) | MAE E2=7.041 | n=1
#   reverse        | MAE ours=1.778 (Δ=+0.445) | MAE E2=7.041 | n=1
#   win_shuffle    | MAE ours=0.206 (Δ=-1.126) | MAE E2=7.041 | n=1
# [Fold  6] Test=subject6 | E2(alpha=0.00423, beta=0)
#   block_shuffle  | MAE ours=6.548 (Δ=-0.207) | MAE E2=9.835 | n=1
#   orig           | MAE ours=6.754 (Δ=+0.000) | MAE E2=9.835 | n=1
#   phase_randomize | MAE ours=5.864 (Δ=-0.890) | MAE E2=9.835 | n=1
#   reverse        | MAE ours=6.882 (Δ=+0.128) | MAE E2=9.835 | n=1
#   win_shuffle    | MAE ours=7.277 (Δ=+0.523) | MAE E2=9.835 | n=1
# [Fold  7] Test=subject7 | E2(alpha=0.00427, beta=0)
#   block_shuffle  | MAE ours=0.278 (Δ=-0.276) | MAE E2=4.155 | n=1
#   orig           | MAE ours=0.555 (Δ=+0.000) | MAE E2=4.155 | n=1
#   phase_randomize | MAE ours=0.683 (Δ=+0.129) | MAE E2=4.155 | n=1
#   reverse        | MAE ours=0.356 (Δ=-0.198) | MAE E2=4.155 | n=1
#   win_shuffle    | MAE ours=0.650 (Δ=+0.096) | MAE E2=4.155 | n=1
# [Fold  8] Test=subject8 | E2(alpha=0.00451, beta=0)
#   block_shuffle  | MAE ours=3.313 (Δ=-0.069) | MAE E2=5.625 | n=1
#   orig           | MAE ours=3.382 (Δ=+0.000) | MAE E2=5.625 | n=1
#   phase_randomize | MAE ours=2.238 (Δ=-1.144) | MAE E2=5.625 | n=1
#   reverse        | MAE ours=3.498 (Δ=+0.116) | MAE E2=5.625 | n=1
#   win_shuffle    | MAE ours=0.743 (Δ=-2.639) | MAE E2=5.625 | n=1
# [Fold  9] Test=subject9 | E2(alpha=0.0043, beta=0)
#   block_shuffle  | MAE ours=0.865 (Δ=-0.065) | MAE E2=2.688 | n=1
#   orig           | MAE ours=0.930 (Δ=+0.000) | MAE E2=2.688 | n=1
#   phase_randomize | MAE ours=1.741 (Δ=+0.811) | MAE E2=2.688 | n=1
#   reverse        | MAE ours=1.342 (Δ=+0.412) | MAE E2=2.688 | n=1
#   win_shuffle    | MAE ours=0.132 (Δ=-0.798) | MAE E2=2.688 | n=1
# [Fold 10] Test=subject10 | E2(alpha=0.00423, beta=0)
#   block_shuffle  | MAE ours=1.463 (Δ=+0.093) | MAE E2=7.732 | n=1
#   orig           | MAE ours=1.370 (Δ=+0.000) | MAE E2=7.732 | n=1
#   phase_randomize | MAE ours=0.235 (Δ=-1.135) | MAE E2=7.732 | n=1
#   reverse        | MAE ours=1.374 (Δ=+0.004) | MAE E2=7.732 | n=1
#   win_shuffle    | MAE ours=1.557 (Δ=+0.186) | MAE E2=7.732 | n=1
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# [Single] Activity: Knees bending (id=8)
# --------------------------------------------------------------------------------------------------------------------------------------------
# [Fold  1] Test=subject1 | E2(alpha=0.00811, beta=0)
#   block_shuffle  | MAE ours=12.999 (Δ=-0.598) | MAE E2=1.065 | n=1
#   orig           | MAE ours=13.597 (Δ=+0.000) | MAE E2=1.065 | n=1
#   phase_randomize | MAE ours=4.438 (Δ=-9.160) | MAE E2=1.065 | n=1
#   reverse        | MAE ours=14.305 (Δ=+0.708) | MAE E2=1.065 | n=1
#   win_shuffle    | MAE ours=8.610 (Δ=-4.988) | MAE E2=1.065 | n=1
# [Fold  2] Test=subject2 | E2(alpha=0.00843, beta=0)
#   block_shuffle  | MAE ours=1.032 (Δ=-0.070) | MAE E2=6.889 | n=1
#   orig           | MAE ours=1.102 (Δ=+0.000) | MAE E2=6.889 | n=1
#   phase_randomize | MAE ours=7.584 (Δ=+6.481) | MAE E2=6.889 | n=1
#   reverse        | MAE ours=1.053 (Δ=-0.049) | MAE E2=6.889 | n=1
#   win_shuffle    | MAE ours=2.911 (Δ=+1.808) | MAE E2=6.889 | n=1
# [Fold  3] Test=subject3 | E2(alpha=0.00817, beta=0)
#   block_shuffle  | MAE ours=4.770 (Δ=-0.612) | MAE E2=2.290 | n=1
#   orig           | MAE ours=5.382 (Δ=+0.000) | MAE E2=2.290 | n=1
#   phase_randomize | MAE ours=2.964 (Δ=-2.418) | MAE E2=2.290 | n=1
#   reverse        | MAE ours=4.464 (Δ=-0.918) | MAE E2=2.290 | n=1
#   win_shuffle    | MAE ours=2.405 (Δ=-2.977) | MAE E2=2.290 | n=1
# [Fold  4] Test=subject4 | E2(alpha=0.00824, beta=0)
#   block_shuffle  | MAE ours=6.229 (Δ=+0.034) | MAE E2=3.953 | n=1
#   orig           | MAE ours=6.195 (Δ=+0.000) | MAE E2=3.953 | n=1
#   phase_randomize | MAE ours=2.934 (Δ=-3.262) | MAE E2=3.953 | n=1
#   reverse        | MAE ours=6.111 (Δ=-0.084) | MAE E2=3.953 | n=1
#   win_shuffle    | MAE ours=0.565 (Δ=-5.631) | MAE E2=3.953 | n=1
# [Fold  5] Test=subject5 | E2(alpha=0.00822, beta=0)
#   block_shuffle  | MAE ours=2.272 (Δ=-0.117) | MAE E2=3.405 | n=1
#   orig           | MAE ours=2.389 (Δ=+0.000) | MAE E2=3.405 | n=1
#   phase_randomize | MAE ours=0.614 (Δ=-1.775) | MAE E2=3.405 | n=1
#   reverse        | MAE ours=2.551 (Δ=+0.162) | MAE E2=3.405 | n=1
#   win_shuffle    | MAE ours=1.793 (Δ=-0.596) | MAE E2=3.405 | n=1
# [Fold  6] Test=subject6 | E2(alpha=0.00799, beta=0)
#   block_shuffle  | MAE ours=4.921 (Δ=+0.347) | MAE E2=2.054 | n=1
#   orig           | MAE ours=4.574 (Δ=+0.000) | MAE E2=2.054 | n=1
#   phase_randomize | MAE ours=4.987 (Δ=+0.412) | MAE E2=2.054 | n=1
#   reverse        | MAE ours=4.783 (Δ=+0.208) | MAE E2=2.054 | n=1
#   win_shuffle    | MAE ours=5.071 (Δ=+0.496) | MAE E2=2.054 | n=1
# [Fold  7] Test=subject7 | E2(alpha=0.00784, beta=0)
#   block_shuffle  | MAE ours=1.899 (Δ=-0.656) | MAE E2=8.254 | n=1
#   orig           | MAE ours=2.555 (Δ=+0.000) | MAE E2=8.254 | n=1
#   phase_randomize | MAE ours=1.515 (Δ=-1.040) | MAE E2=8.254 | n=1
#   reverse        | MAE ours=3.420 (Δ=+0.864) | MAE E2=8.254 | n=1
#   win_shuffle    | MAE ours=1.906 (Δ=-0.649) | MAE E2=8.254 | n=1
# [Fold  8] Test=subject8 | E2(alpha=0.0079, beta=0)
#   block_shuffle  | MAE ours=1.925 (Δ=-1.333) | MAE E2=4.968 | n=1
#   orig           | MAE ours=3.257 (Δ=+0.000) | MAE E2=4.968 | n=1
#   phase_randomize | MAE ours=4.046 (Δ=+0.789) | MAE E2=4.968 | n=1
#   reverse        | MAE ours=5.495 (Δ=+2.237) | MAE E2=4.968 | n=1
#   win_shuffle    | MAE ours=5.910 (Δ=+2.653) | MAE E2=4.968 | n=1
# [Fold  9] Test=subject9 | E2(alpha=0.00797, beta=0)
#   block_shuffle  | MAE ours=4.038 (Δ=-0.251) | MAE E2=2.442 | n=1
#   orig           | MAE ours=4.289 (Δ=+0.000) | MAE E2=2.442 | n=1
#   phase_randomize | MAE ours=3.327 (Δ=-0.963) | MAE E2=2.442 | n=1
#   reverse        | MAE ours=4.488 (Δ=+0.199) | MAE E2=2.442 | n=1
#   win_shuffle    | MAE ours=0.216 (Δ=-4.074) | MAE E2=2.442 | n=1
# [Fold 10] Test=subject10 | E2(alpha=0.00784, beta=0)
#   block_shuffle  | MAE ours=2.556 (Δ=+0.032) | MAE E2=8.910 | n=1
#   orig           | MAE ours=2.524 (Δ=+0.000) | MAE E2=8.910 | n=1
#   phase_randomize | MAE ours=0.964 (Δ=-1.560) | MAE E2=8.910 | n=1
#   reverse        | MAE ours=3.456 (Δ=+0.932) | MAE E2=8.910 | n=1
#   win_shuffle    | MAE ours=1.396 (Δ=-1.128) | MAE E2=8.910 | n=1
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# [Single] Activity: Jump front & back (id=12)
# --------------------------------------------------------------------------------------------------------------------------------------------
# [Fold  1] Test=subject1 | E2(alpha=0.00168, beta=0)
#   block_shuffle  | MAE ours=0.837 (Δ=-0.172) | MAE E2=0.574 | n=1
#   orig           | MAE ours=1.008 (Δ=+0.000) | MAE E2=0.574 | n=1
#   phase_randomize | MAE ours=2.224 (Δ=+1.216) | MAE E2=0.574 | n=1
#   reverse        | MAE ours=0.393 (Δ=-0.616) | MAE E2=0.574 | n=1
#   win_shuffle    | MAE ours=3.306 (Δ=+2.298) | MAE E2=0.574 | n=1
# [Fold  2] Test=subject2 | E2(alpha=0.00164, beta=0)
#   block_shuffle  | MAE ours=1.416 (Δ=+1.027) | MAE E2=6.583 | n=1
#   orig           | MAE ours=0.389 (Δ=+0.000) | MAE E2=6.583 | n=1
#   phase_randomize | MAE ours=0.602 (Δ=+0.213) | MAE E2=6.583 | n=1
#   reverse        | MAE ours=0.939 (Δ=+0.551) | MAE E2=6.583 | n=1
#   win_shuffle    | MAE ours=0.809 (Δ=+0.420) | MAE E2=6.583 | n=1
# [Fold  3] Test=subject3 | E2(alpha=0.00171, beta=0)
#   block_shuffle  | MAE ours=1.233 (Δ=+0.395) | MAE E2=2.840 | n=1
#   orig           | MAE ours=0.838 (Δ=+0.000) | MAE E2=2.840 | n=1
#   phase_randomize | MAE ours=0.395 (Δ=-0.444) | MAE E2=2.840 | n=1
#   reverse        | MAE ours=4.095 (Δ=+3.257) | MAE E2=2.840 | n=1
#   win_shuffle    | MAE ours=0.461 (Δ=-0.377) | MAE E2=2.840 | n=1
# [Fold  4] Test=subject4 | E2(alpha=0.00172, beta=0)
#   block_shuffle  | MAE ours=2.089 (Δ=+0.011) | MAE E2=3.596 | n=1
#   orig           | MAE ours=2.078 (Δ=+0.000) | MAE E2=3.596 | n=1
#   phase_randomize | MAE ours=0.895 (Δ=-1.183) | MAE E2=3.596 | n=1
#   reverse        | MAE ours=0.046 (Δ=-2.032) | MAE E2=3.596 | n=1
#   win_shuffle    | MAE ours=2.836 (Δ=+0.758) | MAE E2=3.596 | n=1
# [Fold  5] Test=subject5 | E2(alpha=0.0017, beta=0)
#   block_shuffle  | MAE ours=2.968 (Δ=-0.545) | MAE E2=1.905 | n=1
#   orig           | MAE ours=3.513 (Δ=+0.000) | MAE E2=1.905 | n=1
#   phase_randomize | MAE ours=2.732 (Δ=-0.781) | MAE E2=1.905 | n=1
#   reverse        | MAE ours=4.743 (Δ=+1.230) | MAE E2=1.905 | n=1
#   win_shuffle    | MAE ours=0.128 (Δ=-3.385) | MAE E2=1.905 | n=1
# [Fold  6] Test=subject6 | E2(alpha=0.00167, beta=0)
#   block_shuffle  | MAE ours=0.712 (Δ=+0.027) | MAE E2=1.649 | n=1
#   orig           | MAE ours=0.685 (Δ=+0.000) | MAE E2=1.649 | n=1
#   phase_randomize | MAE ours=1.801 (Δ=+1.115) | MAE E2=1.649 | n=1
#   reverse        | MAE ours=2.675 (Δ=+1.989) | MAE E2=1.649 | n=1
#   win_shuffle    | MAE ours=0.009 (Δ=-0.677) | MAE E2=1.649 | n=1
# [Fold  7] Test=subject7 | E2(alpha=0.00167, beta=0)
#   block_shuffle  | MAE ours=0.473 (Δ=+0.410) | MAE E2=2.285 | n=1
#   orig           | MAE ours=0.063 (Δ=+0.000) | MAE E2=2.285 | n=1
#   phase_randomize | MAE ours=3.135 (Δ=+3.072) | MAE E2=2.285 | n=1
#   reverse        | MAE ours=1.396 (Δ=+1.333) | MAE E2=2.285 | n=1
#   win_shuffle    | MAE ours=1.656 (Δ=+1.593) | MAE E2=2.285 | n=1
# [Fold  8] Test=subject8 | E2(alpha=0.00169, beta=0)
#   block_shuffle  | MAE ours=0.385 (Δ=+0.265) | MAE E2=0.932 | n=1
#   orig           | MAE ours=0.120 (Δ=+0.000) | MAE E2=0.932 | n=1
#   phase_randomize | MAE ours=2.930 (Δ=+2.810) | MAE E2=0.932 | n=1
#   reverse        | MAE ours=0.905 (Δ=+0.784) | MAE E2=0.932 | n=1
#   win_shuffle    | MAE ours=3.005 (Δ=+2.885) | MAE E2=0.932 | n=1
# [Fold  9] Test=subject9 | E2(alpha=0.0017, beta=0)
#   block_shuffle  | MAE ours=0.255 (Δ=-0.593) | MAE E2=1.476 | n=1
#   orig           | MAE ours=0.848 (Δ=+0.000) | MAE E2=1.476 | n=1
#   phase_randomize | MAE ours=1.172 (Δ=+0.325) | MAE E2=1.476 | n=1
#   reverse        | MAE ours=3.331 (Δ=+2.483) | MAE E2=1.476 | n=1
#   win_shuffle    | MAE ours=0.424 (Δ=-0.424) | MAE E2=1.476 | n=1
# [Fold 10] Test=subject10 | E2(alpha=0.00166, beta=0)
#   block_shuffle  | MAE ours=1.397 (Δ=-0.464) | MAE E2=2.507 | n=1
#   orig           | MAE ours=1.861 (Δ=+0.000) | MAE E2=2.507 | n=1
#   phase_randomize | MAE ours=1.507 (Δ=-0.353) | MAE E2=2.507 | n=1
#   reverse        | MAE ours=1.112 (Δ=-0.749) | MAE E2=2.507 | n=1
#   win_shuffle    | MAE ours=0.460 (Δ=-1.401) | MAE E2=2.507 | n=1
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# [Single] Activity: Jogging (id=10)
# --------------------------------------------------------------------------------------------------------------------------------------------
# [Fold  1] Test=subject1 | E2(alpha=0.00563, beta=0)
#   block_shuffle  | MAE ours=5.826 (Δ=+3.637) | MAE E2=5.956 | n=1
#   orig           | MAE ours=2.188 (Δ=+0.000) | MAE E2=5.956 | n=1
#   phase_randomize | MAE ours=7.918 (Δ=+5.730) | MAE E2=5.956 | n=1
#   reverse        | MAE ours=2.732 (Δ=+0.543) | MAE E2=5.956 | n=1
#   win_shuffle    | MAE ours=5.574 (Δ=+3.385) | MAE E2=5.956 | n=1
# [Fold  2] Test=subject2 | E2(alpha=0.0057, beta=0)
#   block_shuffle  | MAE ours=10.494 (Δ=+5.507) | MAE E2=13.545 | n=1
#   orig           | MAE ours=4.987 (Δ=+0.000) | MAE E2=13.545 | n=1
#   phase_randomize | MAE ours=10.668 (Δ=+5.681) | MAE E2=13.545 | n=1
#   reverse        | MAE ours=28.905 (Δ=+23.919) | MAE E2=13.545 | n=1
#   win_shuffle    | MAE ours=31.925 (Δ=+26.938) | MAE E2=13.545 | n=1
# [Fold  3] Test=subject3 | E2(alpha=0.00574, beta=0)
#   block_shuffle  | MAE ours=5.087 (Δ=-0.149) | MAE E2=21.777 | n=1
#   orig           | MAE ours=5.236 (Δ=+0.000) | MAE E2=21.777 | n=1
#   phase_randomize | MAE ours=5.047 (Δ=-0.189) | MAE E2=21.777 | n=1
#   reverse        | MAE ours=6.622 (Δ=+1.385) | MAE E2=21.777 | n=1
#   win_shuffle    | MAE ours=1.974 (Δ=-3.262) | MAE E2=21.777 | n=1
# [Fold  4] Test=subject4 | E2(alpha=0.00563, beta=0)
#   block_shuffle  | MAE ours=4.369 (Δ=+0.618) | MAE E2=4.831 | n=1
#   orig           | MAE ours=3.751 (Δ=+0.000) | MAE E2=4.831 | n=1
#   phase_randomize | MAE ours=21.457 (Δ=+17.706) | MAE E2=4.831 | n=1
#   reverse        | MAE ours=0.042 (Δ=-3.708) | MAE E2=4.831 | n=1
#   win_shuffle    | MAE ours=2.796 (Δ=-0.955) | MAE E2=4.831 | n=1
# [Fold  5] Test=subject5 | E2(alpha=0.00562, beta=0)
#   block_shuffle  | MAE ours=2.502 (Δ=+0.903) | MAE E2=9.544 | n=1
#   orig           | MAE ours=1.599 (Δ=+0.000) | MAE E2=9.544 | n=1
#   phase_randomize | MAE ours=16.076 (Δ=+14.477) | MAE E2=9.544 | n=1
#   reverse        | MAE ours=9.216 (Δ=+7.617) | MAE E2=9.544 | n=1
#   win_shuffle    | MAE ours=1.000 (Δ=-0.599) | MAE E2=9.544 | n=1
# [Fold  6] Test=subject6 | E2(alpha=0.00579, beta=0)
#   block_shuffle  | MAE ours=37.569 (Δ=-0.325) | MAE E2=33.447 | n=1
#   orig           | MAE ours=37.894 (Δ=+0.000) | MAE E2=33.447 | n=1
#   phase_randomize | MAE ours=16.607 (Δ=-21.287) | MAE E2=33.447 | n=1
#   reverse        | MAE ours=8.389 (Δ=-29.506) | MAE E2=33.447 | n=1
#   win_shuffle    | MAE ours=29.039 (Δ=-8.855) | MAE E2=33.447 | n=1
# [Fold  7] Test=subject7 | E2(alpha=0.00567, beta=0)
#   block_shuffle  | MAE ours=9.267 (Δ=-0.170) | MAE E2=4.941 | n=1
#   orig           | MAE ours=9.437 (Δ=+0.000) | MAE E2=4.941 | n=1
#   phase_randomize | MAE ours=13.210 (Δ=+3.773) | MAE E2=4.941 | n=1
#   reverse        | MAE ours=5.656 (Δ=-3.781) | MAE E2=4.941 | n=1
#   win_shuffle    | MAE ours=3.262 (Δ=-6.175) | MAE E2=4.941 | n=1
# [Fold  8] Test=subject8 | E2(alpha=0.00555, beta=0)
#   block_shuffle  | MAE ours=14.257 (Δ=-0.047) | MAE E2=35.543 | n=1
#   orig           | MAE ours=14.304 (Δ=+0.000) | MAE E2=35.543 | n=1
#   phase_randomize | MAE ours=6.846 (Δ=-7.458) | MAE E2=35.543 | n=1
#   reverse        | MAE ours=16.283 (Δ=+1.979) | MAE E2=35.543 | n=1
#   win_shuffle    | MAE ours=4.921 (Δ=-9.384) | MAE E2=35.543 | n=1
# [Fold  9] Test=subject9 | E2(alpha=0.0056, beta=0)
#   block_shuffle  | MAE ours=5.083 (Δ=-0.981) | MAE E2=13.198 | n=1
#   orig           | MAE ours=6.064 (Δ=+0.000) | MAE E2=13.198 | n=1
#   phase_randomize | MAE ours=3.189 (Δ=-2.875) | MAE E2=13.198 | n=1
#   reverse        | MAE ours=4.632 (Δ=-1.432) | MAE E2=13.198 | n=1
#   win_shuffle    | MAE ours=3.843 (Δ=-2.221) | MAE E2=13.198 | n=1
# [Fold 10] Test=subject10 | E2(alpha=0.00559, beta=0)
#   block_shuffle  | MAE ours=5.724 (Δ=-1.325) | MAE E2=20.145 | n=1
#   orig           | MAE ours=7.049 (Δ=+0.000) | MAE E2=20.145 | n=1
#   phase_randomize | MAE ours=24.441 (Δ=+17.392) | MAE E2=20.145 | n=1
#   reverse        | MAE ours=4.177 (Δ=-2.873) | MAE E2=20.145 | n=1
#   win_shuffle    | MAE ours=5.062 (Δ=-1.988) | MAE E2=20.145 | n=1
#
# --------------------------------------------------------------------------------------------------------------------------------------------
# [Single] Activity: Running (id=11)
# --------------------------------------------------------------------------------------------------------------------------------------------
# [Fold  1] Test=subject1 | E2(alpha=0.00351, beta=0)
#   block_shuffle  | MAE ours=1.012 (Δ=-0.577) | MAE E2=11.322 | n=1
#   orig           | MAE ours=1.589 (Δ=+0.000) | MAE E2=11.322 | n=1
#   phase_randomize | MAE ours=20.481 (Δ=+18.891) | MAE E2=11.322 | n=1
#   reverse        | MAE ours=3.087 (Δ=+1.498) | MAE E2=11.322 | n=1
#   win_shuffle    | MAE ours=37.593 (Δ=+36.004) | MAE E2=11.322 | n=1
# [Fold  2] Test=subject2 | E2(alpha=0.00348, beta=0)
#   block_shuffle  | MAE ours=16.934 (Δ=+3.188) | MAE E2=29.402 | n=1
#   orig           | MAE ours=13.746 (Δ=+0.000) | MAE E2=29.402 | n=1
#   phase_randomize | MAE ours=16.975 (Δ=+3.229) | MAE E2=29.402 | n=1
#   reverse        | MAE ours=15.045 (Δ=+1.299) | MAE E2=29.402 | n=1
#   win_shuffle    | MAE ours=35.854 (Δ=+22.108) | MAE E2=29.402 | n=1
# [Fold  3] Test=subject3 | E2(alpha=0.00364, beta=0)
#   block_shuffle  | MAE ours=19.579 (Δ=-2.222) | MAE E2=38.676 | n=1
#   orig           | MAE ours=21.801 (Δ=+0.000) | MAE E2=38.676 | n=1
#   phase_randomize | MAE ours=11.848 (Δ=-9.953) | MAE E2=38.676 | n=1
#   reverse        | MAE ours=4.555 (Δ=-17.246) | MAE E2=38.676 | n=1
#   win_shuffle    | MAE ours=1.375 (Δ=-20.426) | MAE E2=38.676 | n=1
# [Fold  4] Test=subject4 | E2(alpha=0.00346, beta=0)
#   block_shuffle  | MAE ours=20.112 (Δ=+2.278) | MAE E2=46.819 | n=1
#   orig           | MAE ours=17.834 (Δ=+0.000) | MAE E2=46.819 | n=1
#   phase_randomize | MAE ours=25.052 (Δ=+7.217) | MAE E2=46.819 | n=1
#   reverse        | MAE ours=7.145 (Δ=-10.689) | MAE E2=46.819 | n=1
#   win_shuffle    | MAE ours=27.982 (Δ=+10.148) | MAE E2=46.818 | n=1
# [Fold  5] Test=subject5 | E2(alpha=0.00352, beta=0)
#   block_shuffle  | MAE ours=4.028 (Δ=+2.721) | MAE E2=4.833 | n=1
#   orig           | MAE ours=1.306 (Δ=+0.000) | MAE E2=4.834 | n=1
#   phase_randomize | MAE ours=20.205 (Δ=+18.899) | MAE E2=4.833 | n=1
#   reverse        | MAE ours=19.461 (Δ=+18.155) | MAE E2=4.833 | n=1
#   win_shuffle    | MAE ours=39.451 (Δ=+38.145) | MAE E2=4.833 | n=1
# [Fold  6] Test=subject6 | E2(alpha=0.0036, beta=0)
#   block_shuffle  | MAE ours=23.930 (Δ=-1.053) | MAE E2=24.616 | n=1
#   orig           | MAE ours=24.983 (Δ=+0.000) | MAE E2=24.616 | n=1
#   phase_randomize | MAE ours=7.984 (Δ=-16.999) | MAE E2=24.616 | n=1
#   reverse        | MAE ours=25.903 (Δ=+0.920) | MAE E2=24.616 | n=1
#   win_shuffle    | MAE ours=0.576 (Δ=-24.406) | MAE E2=24.616 | n=1
# [Fold  7] Test=subject7 | E2(alpha=0.00353, beta=0)
#   block_shuffle  | MAE ours=20.985 (Δ=+2.775) | MAE E2=1.464 | n=1
#   orig           | MAE ours=18.210 (Δ=+0.000) | MAE E2=1.464 | n=1
#   phase_randomize | MAE ours=26.645 (Δ=+8.435) | MAE E2=1.464 | n=1
#   reverse        | MAE ours=24.386 (Δ=+6.176) | MAE E2=1.464 | n=1
#   win_shuffle    | MAE ours=48.102 (Δ=+29.893) | MAE E2=1.464 | n=1
# [Fold  8] Test=subject8 | E2(alpha=0.00357, beta=0)
#   block_shuffle  | MAE ours=5.354 (Δ=-3.549) | MAE E2=16.999 | n=1
#   orig           | MAE ours=8.902 (Δ=+0.000) | MAE E2=16.999 | n=1
#   phase_randomize | MAE ours=1.450 (Δ=-7.452) | MAE E2=16.999 | n=1
#   reverse        | MAE ours=11.533 (Δ=+2.630) | MAE E2=16.999 | n=1
#   win_shuffle    | MAE ours=21.209 (Δ=+12.307) | MAE E2=16.999 | n=1
# [Fold  9] Test=subject9 | E2(alpha=0.00353, beta=0)
#   block_shuffle  | MAE ours=18.049 (Δ=+0.911) | MAE E2=0.681 | n=1
#   orig           | MAE ours=17.138 (Δ=+0.000) | MAE E2=0.681 | n=1
#   phase_randomize | MAE ours=30.245 (Δ=+13.107) | MAE E2=0.681 | n=1
#   reverse        | MAE ours=8.378 (Δ=-8.760) | MAE E2=0.681 | n=1
#   win_shuffle    | MAE ours=27.025 (Δ=+9.887) | MAE E2=0.681 | n=1
# [Fold 10] Test=subject10 | E2(alpha=0.0035, beta=0)
#   block_shuffle  | MAE ours=18.503 (Δ=-2.998) | MAE E2=14.474 | n=1
#   orig           | MAE ours=21.501 (Δ=+0.000) | MAE E2=14.474 | n=1
#   phase_randomize | MAE ours=3.407 (Δ=-18.094) | MAE E2=14.475 | n=1
#   reverse        | MAE ours=8.023 (Δ=-13.478) | MAE E2=14.475 | n=1
#   win_shuffle    | MAE ours=17.880 (Δ=-3.621) | MAE E2=14.474 | n=1
#
# ============================================================================================================================================
# [OVERALL SUMMARY]  (Δ = MAE(mode) - MAE(orig))
#            mode  n  MAE_ours  MAE_baseE2  entropy     effK    k_hat  baseE2_alpha  dMAE_vs_orig
#   block_shuffle 60  6.245428    8.536735 0.333780 1.500757 1.500758      0.004933      0.107992
#            orig 60  6.137436    8.536735 0.333627 1.507193 1.507194      0.004933      0.000000
# phase_randomize 60  7.281895    8.536737 0.350380 1.426110 1.426111      0.004933      1.144459
#         reverse 60  5.955805    8.536736 0.348675 1.511962 1.511963      0.004933     -0.181631
#     win_shuffle 60  7.914681    8.536736 0.330863 1.382241 1.382241      0.004933      1.777245
#
# ============================================================================================================================================
# [PER-ACTIVITY SUMMARY]  (Δ = MAE(mode) - MAE(orig within activity))
#  act_id                  act_name            mode  n  MAE_ours  MAE_baseE2  entropy     effK    k_hat  dMAE_vs_orig
#       6       Waist bends forward   block_shuffle 10  4.978921    4.250822 0.089790 1.042661 1.042665      0.084198
#       6       Waist bends forward            orig 10  4.894723    4.250823 0.091007 1.043673 1.043676      0.000000
#       6       Waist bends forward phase_randomize 10  6.727323    4.250823 0.091858 1.043253 1.043256      1.832600
#       6       Waist bends forward         reverse 10  4.955011    4.250823 0.083920 1.038624 1.038628      0.060288
#       6       Waist bends forward     win_shuffle 10  6.616964    4.250822 0.076716 1.035169 1.035171      1.722241
#       7 Frontal elevation of arms   block_shuffle 10  2.186466    4.890671 0.100428 1.063169 1.063170     -0.064264
#       7 Frontal elevation of arms            orig 10  2.250730    4.890670 0.101088 1.066225 1.066227      0.000000
#       7 Frontal elevation of arms phase_randomize 10  2.912453    4.890671 0.096047 1.045661 1.045662      0.661722
#       7 Frontal elevation of arms         reverse 10  2.386707    4.890671 0.101859 1.066173 1.066174      0.135976
#       7 Frontal elevation of arms     win_shuffle 10  1.839143    4.890671 0.079448 1.035075 1.035076     -0.411587
#       8             Knees bending   block_shuffle 10  4.264200    4.422995 0.176878 1.173302 1.173305     -0.322461
#       8             Knees bending            orig 10  4.586662    4.422995 0.175059 1.172010 1.172013      0.000000
#       8             Knees bending phase_randomize 10  3.337135    4.422995 0.236395 1.211470 1.211470     -1.249527
#       8             Knees bending         reverse 10  5.012638    4.422996 0.175220 1.172895 1.172897      0.425976
#       8             Knees bending     win_shuffle 10  3.078080    4.422995 0.224784 1.193037 1.193036     -1.508582
#      10                   Jogging   block_shuffle 10 10.017920   16.292618 0.403484 1.546315 1.546316      0.766941
#      10                   Jogging            orig 10  9.250979   16.292621 0.402768 1.551753 1.551753      0.000000
#      10                   Jogging phase_randomize 10 12.545957   16.292625 0.417409 1.427028 1.427030      3.294978
#      10                   Jogging         reverse 10  8.665303   16.292620 0.435512 1.505792 1.505791     -0.585676
#      10                   Jogging     win_shuffle 10  8.939610   16.292624 0.393222 1.349152 1.349152     -0.311369
#      11                   Running   block_shuffle 10 14.848506   18.928688 0.334350 1.546291 1.546291      0.147366
#      11                   Running            orig 10 14.701140   18.928683 0.333735 1.564268 1.564269      0.000000
#      11                   Running phase_randomize 10 16.429135   18.928691 0.337221 1.385158 1.385158      1.727995
#      11                   Running         reverse 10 12.751743   18.928691 0.377118 1.531128 1.531129     -1.949396
#      11                   Running     win_shuffle 10 25.704992   18.928686 0.310358 1.322892 1.322893     11.003853
#      12         Jump front & back   block_shuffle 10  1.176555    2.434618 0.897749 2.632802 2.632802      0.036173
#      12         Jump front & back            orig 10  1.140382    2.434618 0.898104 2.645226 2.645226      0.000000
#      12         Jump front & back phase_randomize 10  1.739367    2.434618 0.923348 2.444091 2.444090      0.598985
#      12         Jump front & back         reverse 10  1.963428    2.434619 0.918424 2.757159 2.757159      0.823046
#      12         Jump front & back     win_shuffle 10  1.309296    2.434619 0.900648 2.358120 2.358121      0.168914
# ============================================================================================================================================
